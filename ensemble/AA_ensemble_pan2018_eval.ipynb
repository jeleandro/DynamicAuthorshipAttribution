# %% [markdown]
# # AA PAN-EVAL 2018

# %%
# %matplotlib inline

# %%
#python basic libs
import os;
from os.path import join as pathjoin;
import re;
import random;
import json;
from collections import defaultdict;
from pprint import pprint
from time import time

# %%
#data analysis libs
import numpy as np;
import pandas as pd;
import seaborn as sns;
import matplotlib.pyplot as plt;

# %%
#machine learning libs
#feature extraction
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn import feature_selection;

#preprocessing and transformation
from sklearn import preprocessing;
from sklearn.preprocessing import MaxAbsScaler;
from sklearn.decomposition import PCA;

from sklearn.base import BaseEstimator, ClassifierMixin

#classifiers
from sklearn.linear_model import LogisticRegression

#
from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import Pipeline

#model valuation
from sklearn.metrics import f1_score, precision_score, recall_score, accuracy_score;

# %% [markdown]
# NLP libraries

# %%
# !pip install spacy=='2.3' gensim
# Out:
# Collecting spacy==2.3
#   Downloading https://files.pythonhosted.org/packages/31/c7/e66e2af1cfa418c3a3917c116c4e00ccffa546f18f59e6acd7953d833c5c/spacy-2.3.0-cp36-cp36m-manylinux1_x86_64.whl (10.0MB)
#      |████████████████████████████████| 10.0MB 2.7MB/s
# Requirement already satisfied: gensim in /usr/local/lib/python3.6/dist-packages (3.6.0)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from spacy==2.3) (0.4.1)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.6/dist-packages (from spacy==2.3) (1.18.5)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.6/dist-packages (from spacy==2.3) (4.41.1)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /usr/local/lib/python3.6/dist-packages (from spacy==2.3) (1.1.3)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.6/dist-packages (from spacy==2.3) (2.23.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy==2.3) (3.0.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from spacy==2.3) (50.3.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.6/dist-packages (from spacy==2.3) (1.0.2)
# Collecting thinc==7.4.1
#   Downloading https://files.pythonhosted.org/packages/10/ae/ef3ae5e93639c0ef8e3eb32e3c18341e511b3c515fcfc603f4b808087651/thinc-7.4.1-cp36-cp36m-manylinux1_x86_64.whl (2.1MB)
#      |████████████████████████████████| 2.1MB 45.2MB/s
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy==2.3) (2.0.3)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy==2.3) (1.0.2)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /usr/local/lib/python3.6/dist-packages (from spacy==2.3) (1.0.0)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from spacy==2.3) (0.8.0)
# Requirement already satisfied: smart-open>=1.2.1 in /usr/local/lib/python3.6/dist-packages (from gensim) (3.0.0)
# Requirement already satisfied: scipy>=0.18.1 in /usr/local/lib/python3.6/dist-packages (from gensim) (1.4.1)
# Requirement already satisfied: six>=1.5.0 in /usr/local/lib/python3.6/dist-packages (from gensim) (1.15.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy==2.3) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy==2.3) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy==2.3) (2020.6.20)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy==2.3) (1.24.3)
# Requirement already satisfied: importlib-metadata>=0.20; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from catalogue<1.1.0,>=0.0.7->spacy==2.3) (2.0.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata>=0.20; python_version < "3.8"->catalogue<1.1.0,>=0.0.7->spacy==2.3) (3.3.1)
# Installing collected packages: thinc, spacy
#   Found existing installation: thinc 7.4.0
#     Uninstalling thinc-7.4.0:
#       Successfully uninstalled thinc-7.4.0
#   Found existing installation: spacy 2.2.4
#     Uninstalling spacy-2.2.4:
#       Successfully uninstalled spacy-2.2.4
# Successfully installed spacy-2.3.0 thinc-7.4.1

# %%
# !python -m spacy download pt  
# !python -m spacy download es
# !python -m spacy download it
# !python -m spacy download en
# !python -m spacy download fr
# Out:
# Collecting pt_core_news_sm==2.3.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/pt_core_news_sm-2.3.0/pt_core_news_sm-2.3.0.tar.gz (19.6MB)
#      |████████████████████████████████| 19.6MB 3.8MB/s
# Requirement already satisfied: spacy<2.4.0,>=2.3.0 in /usr/local/lib/python3.6/dist-packages (from pt_core_news_sm==2.3.0) (2.3.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->pt_core_news_sm==2.3.0) (2.23.0)
# Requirement already satisfied: thinc==7.4.1 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->pt_core_news_sm==2.3.0) (7.4.1)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->pt_core_news_sm==2.3.0) (3.0.2)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->pt_core_news_sm==2.3.0) (1.0.2)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->pt_core_news_sm==2.3.0) (1.18.5)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->pt_core_news_sm==2.3.0) (2.0.3)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->pt_core_news_sm==2.3.0) (1.1.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->pt_core_news_sm==2.3.0) (50.3.0)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->pt_core_news_sm==2.3.0) (0.8.0)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->pt_core_news_sm==2.3.0) (1.0.0)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->pt_core_news_sm==2.3.0) (1.0.2)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->pt_core_news_sm==2.3.0) (0.4.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->pt_core_news_sm==2.3.0) (4.41.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0,>=2.3.0->pt_core_news_sm==2.3.0) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0,>=2.3.0->pt_core_news_sm==2.3.0) (2020.6.20)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0,>=2.3.0->pt_core_news_sm==2.3.0) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0,>=2.3.0->pt_core_news_sm==2.3.0) (3.0.4)
# Requirement already satisfied: importlib-metadata>=0.20; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from catalogue<1.1.0,>=0.0.7->spacy<2.4.0,>=2.3.0->pt_core_news_sm==2.3.0) (2.0.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata>=0.20; python_version < "3.8"->catalogue<1.1.0,>=0.0.7->spacy<2.4.0,>=2.3.0->pt_core_news_sm==2.3.0) (3.3.1)
# Building wheels for collected packages: pt-core-news-sm
#   Building wheel for pt-core-news-sm (setup.py) ... done
#   Created wheel for pt-core-news-sm: filename=pt_core_news_sm-2.3.0-cp36-none-any.whl size=19557499 sha256=16037e7121a4e7ebc397a412f2fec7f561f145e18b58f67cff8c7acab91424bd
#   Stored in directory: /tmp/pip-ephem-wheel-cache-uqsk8s3r/wheels/f6/43/f6/949b5e2b48df37aa3ed81fc3f4af4154afa276518cc004b990
# Successfully built pt-core-news-sm
# Installing collected packages: pt-core-news-sm
# Successfully installed pt-core-news-sm-2.3.0
# ✔ Download and installation successful
# You can now load the model via spacy.load('pt_core_news_sm')
# ✔ Linking successful
# /usr/local/lib/python3.6/dist-packages/pt_core_news_sm -->
# /usr/local/lib/python3.6/dist-packages/spacy/data/pt
# You can now load the model via spacy.load('pt')
# Collecting es_core_news_sm==2.3.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/es_core_news_sm-2.3.1/es_core_news_sm-2.3.1.tar.gz (16.2MB)
#      |████████████████████████████████| 16.2MB 3.7MB/s
# Requirement already satisfied: spacy<2.4.0,>=2.3.0 in /usr/local/lib/python3.6/dist-packages (from es_core_news_sm==2.3.1) (2.3.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->es_core_news_sm==2.3.1) (3.0.2)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->es_core_news_sm==2.3.1) (1.1.3)
# Requirement already satisfied: thinc==7.4.1 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->es_core_news_sm==2.3.1) (7.4.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->es_core_news_sm==2.3.1) (2.23.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->es_core_news_sm==2.3.1) (50.3.0)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->es_core_news_sm==2.3.1) (0.4.1)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->es_core_news_sm==2.3.1) (1.0.2)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->es_core_news_sm==2.3.1) (2.0.3)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->es_core_news_sm==2.3.1) (0.8.0)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->es_core_news_sm==2.3.1) (1.0.2)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->es_core_news_sm==2.3.1) (4.41.1)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->es_core_news_sm==2.3.1) (1.0.0)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->es_core_news_sm==2.3.1) (1.18.5)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0,>=2.3.0->es_core_news_sm==2.3.1) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0,>=2.3.0->es_core_news_sm==2.3.1) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0,>=2.3.0->es_core_news_sm==2.3.1) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0,>=2.3.0->es_core_news_sm==2.3.1) (2020.6.20)
# Requirement already satisfied: importlib-metadata>=0.20; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from catalogue<1.1.0,>=0.0.7->spacy<2.4.0,>=2.3.0->es_core_news_sm==2.3.1) (2.0.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata>=0.20; python_version < "3.8"->catalogue<1.1.0,>=0.0.7->spacy<2.4.0,>=2.3.0->es_core_news_sm==2.3.1) (3.3.1)
# Building wheels for collected packages: es-core-news-sm
#   Building wheel for es-core-news-sm (setup.py) ... done
#   Created wheel for es-core-news-sm: filename=es_core_news_sm-2.3.1-cp36-none-any.whl size=16217000 sha256=d3b3084d88ecbccb39df88b249d92b3be0b705b9f1d011f60d084718dcf5515c
#   Stored in directory: /tmp/pip-ephem-wheel-cache-nnhoopcs/wheels/75/be/34/88bac54b4d3f462835c1802813139afc469f01a6540d7bdc51
# Successfully built es-core-news-sm
# Installing collected packages: es-core-news-sm
# Successfully installed es-core-news-sm-2.3.1
# ✔ Download and installation successful
# You can now load the model via spacy.load('es_core_news_sm')
# ✔ Linking successful
# /usr/local/lib/python3.6/dist-packages/es_core_news_sm -->
# /usr/local/lib/python3.6/dist-packages/spacy/data/es
# You can now load the model via spacy.load('es')
# Collecting it_core_news_sm==2.3.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/it_core_news_sm-2.3.0/it_core_news_sm-2.3.0.tar.gz (14.5MB)
#      |████████████████████████████████| 14.5MB 3.7MB/s
# Requirement already satisfied: spacy<2.4.0,>=2.3.0 in /usr/local/lib/python3.6/dist-packages (from it_core_news_sm==2.3.0) (2.3.0)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->it_core_news_sm==2.3.0) (1.0.0)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->it_core_news_sm==2.3.0) (0.8.0)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->it_core_news_sm==2.3.0) (1.1.3)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->it_core_news_sm==2.3.0) (0.4.1)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->it_core_news_sm==2.3.0) (2.0.3)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->it_core_news_sm==2.3.0) (2.23.0)
# Requirement already satisfied: thinc==7.4.1 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->it_core_news_sm==2.3.0) (7.4.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->it_core_news_sm==2.3.0) (4.41.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->it_core_news_sm==2.3.0) (50.3.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->it_core_news_sm==2.3.0) (3.0.2)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->it_core_news_sm==2.3.0) (1.0.2)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->it_core_news_sm==2.3.0) (1.18.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->it_core_news_sm==2.3.0) (1.0.2)
# Requirement already satisfied: importlib-metadata>=0.20; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from catalogue<1.1.0,>=0.0.7->spacy<2.4.0,>=2.3.0->it_core_news_sm==2.3.0) (2.0.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0,>=2.3.0->it_core_news_sm==2.3.0) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0,>=2.3.0->it_core_news_sm==2.3.0) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0,>=2.3.0->it_core_news_sm==2.3.0) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0,>=2.3.0->it_core_news_sm==2.3.0) (2020.6.20)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata>=0.20; python_version < "3.8"->catalogue<1.1.0,>=0.0.7->spacy<2.4.0,>=2.3.0->it_core_news_sm==2.3.0) (3.3.1)
# Building wheels for collected packages: it-core-news-sm
#   Building wheel for it-core-news-sm (setup.py) ... done
#   Created wheel for it-core-news-sm: filename=it_core_news_sm-2.3.0-cp36-none-any.whl size=14502462 sha256=fb7f60c67e45ec3866833584366cb5ba83591dce2933231d60709051ba4f7724
#   Stored in directory: /tmp/pip-ephem-wheel-cache-y7z12z84/wheels/4b/ba/ff/a127270808d2351d5ff858061d24c4fe7599f45d0920145900
# Successfully built it-core-news-sm
# Installing collected packages: it-core-news-sm
# Successfully installed it-core-news-sm-2.3.0
# ✔ Download and installation successful
# You can now load the model via spacy.load('it_core_news_sm')
# ✔ Linking successful
# /usr/local/lib/python3.6/dist-packages/it_core_news_sm -->
# /usr/local/lib/python3.6/dist-packages/spacy/data/it
# You can now load the model via spacy.load('it')
# Collecting en_core_web_sm==2.3.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.3.0/en_core_web_sm-2.3.0.tar.gz (12.0MB)
#      |████████████████████████████████| 12.1MB 2.7MB/s
# Requirement already satisfied: spacy<2.4.0,>=2.3.0 in /usr/local/lib/python3.6/dist-packages (from en_core_web_sm==2.3.0) (2.3.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.0) (2.0.3)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.0) (1.18.5)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.0) (1.0.2)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.0) (0.8.0)
# Requirement already satisfied: thinc==7.4.1 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.0) (7.4.1)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.0) (1.0.2)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.0) (0.4.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.0) (50.3.0)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.0) (1.1.3)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.0) (3.0.2)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.0) (4.41.1)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.0) (1.0.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.0) (2.23.0)
# Requirement already satisfied: importlib-metadata>=0.20; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from catalogue<1.1.0,>=0.0.7->spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.0) (2.0.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.0) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.0) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.0) (2020.6.20)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.0) (1.24.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata>=0.20; python_version < "3.8"->catalogue<1.1.0,>=0.0.7->spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.0) (3.3.1)
# Building wheels for collected packages: en-core-web-sm
#   Building wheel for en-core-web-sm (setup.py) ... done
#   Created wheel for en-core-web-sm: filename=en_core_web_sm-2.3.0-cp36-none-any.whl size=12048610 sha256=a98d33a5d60bd20dbbcea9f920f791e621effb3d8f58a21086915f5c75823f5a
#   Stored in directory: /tmp/pip-ephem-wheel-cache-k4_ln8vs/wheels/be/ec/e4/29a68c7de525fcfa2d898cc27d2b945fe7cd966feeb2d85e0b
# Successfully built en-core-web-sm
# Installing collected packages: en-core-web-sm
#   Found existing installation: en-core-web-sm 2.2.5
#     Uninstalling en-core-web-sm-2.2.5:
#       Successfully uninstalled en-core-web-sm-2.2.5
# Successfully installed en-core-web-sm-2.3.0
# ✔ Download and installation successful
# You can now load the model via spacy.load('en_core_web_sm')
# ✔ Linking successful
# /usr/local/lib/python3.6/dist-packages/en_core_web_sm -->
# /usr/local/lib/python3.6/dist-packages/spacy/data/en
# You can now load the model via spacy.load('en')
# Collecting fr_core_news_sm==2.3.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/fr_core_news_sm-2.3.0/fr_core_news_sm-2.3.0.tar.gz (14.7MB)
#      |████████████████████████████████| 14.7MB 3.5MB/s
# Requirement already satisfied: spacy<2.4.0,>=2.3.0 in /usr/local/lib/python3.6/dist-packages (from fr_core_news_sm==2.3.0) (2.3.0)
# Requirement already satisfied: thinc==7.4.1 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->fr_core_news_sm==2.3.0) (7.4.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->fr_core_news_sm==2.3.0) (4.41.1)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->fr_core_news_sm==2.3.0) (1.0.2)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->fr_core_news_sm==2.3.0) (1.18.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->fr_core_news_sm==2.3.0) (1.0.2)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->fr_core_news_sm==2.3.0) (2.0.3)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->fr_core_news_sm==2.3.0) (1.0.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->fr_core_news_sm==2.3.0) (3.0.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->fr_core_news_sm==2.3.0) (2.23.0)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->fr_core_news_sm==2.3.0) (1.1.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->fr_core_news_sm==2.3.0) (50.3.0)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->fr_core_news_sm==2.3.0) (0.8.0)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->fr_core_news_sm==2.3.0) (0.4.1)
# Requirement already satisfied: importlib-metadata>=0.20; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from catalogue<1.1.0,>=0.0.7->spacy<2.4.0,>=2.3.0->fr_core_news_sm==2.3.0) (2.0.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0,>=2.3.0->fr_core_news_sm==2.3.0) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0,>=2.3.0->fr_core_news_sm==2.3.0) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0,>=2.3.0->fr_core_news_sm==2.3.0) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0,>=2.3.0->fr_core_news_sm==2.3.0) (2020.6.20)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata>=0.20; python_version < "3.8"->catalogue<1.1.0,>=0.0.7->spacy<2.4.0,>=2.3.0->fr_core_news_sm==2.3.0) (3.3.1)
# Building wheels for collected packages: fr-core-news-sm
#   Building wheel for fr-core-news-sm (setup.py) ... done
#   Created wheel for fr-core-news-sm: filename=fr_core_news_sm-2.3.0-cp36-none-any.whl size=14718368 sha256=d996c84cbf8078a8d1d8ae2cf5db4b53b5091ecc5dffd774cc67954ddc622567
#   Stored in directory: /tmp/pip-ephem-wheel-cache-jgyd925c/wheels/f4/29/3c/11e2201c8f61d231f09aa32ae3fe885cb0f9d9c0d3a609eea0
# Successfully built fr-core-news-sm
# Installing collected packages: fr-core-news-sm
# Successfully installed fr-core-news-sm-2.3.0
# ✔ Download and installation successful
# You can now load the model via spacy.load('fr_core_news_sm')
# ✔ Linking successful
# /usr/local/lib/python3.6/dist-packages/fr_core_news_sm -->
# /usr/local/lib/python3.6/dist-packages/spacy/data/fr
# You can now load the model via spacy.load('fr')

# %%
import spacy;
import gensim
import logging
from gensim.models import KeyedVectors
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.CRITICAL)

# %%
from IPython.display import Markdown, display, HTML

# %% [markdown]
# libraries configurations

# %%
import warnings
from sklearn.exceptions import UndefinedMetricWarning
warnings.simplefilter(action='ignore', category=UndefinedMetricWarning)
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
np.set_printoptions(precision=4)
pd.options.display.float_format = '{:,.4f}'.format
sns.set(color_codes=True);

# %%
import platform;
import sklearn;
import scipy;

Markdown(
    "|%-15s|%-65s|\n"%("PACK","VERSION") +
    "|%-15s|%-65s|\n"%('-'*15,'-'*65) +
    ('\n'.join(
    "|%-15s|%-45s| " % (pack, version.strip())
    for pack, version in
    zip(['SO','NumPy','SciPy','Scikit-Learn','Seaborn','Spacy','Gensim'],
        [platform.platform(), np.__version__, scipy.__version__,
         sklearn.__version__, spacy.__version__, gensim.__version__])

)))
# Out:
# |PACK           |VERSION                                                          |
# |---------------|-----------------------------------------------------------------|
# |SO             |Linux-4.19.112+-x86_64-with-Ubuntu-18.04-bionic|
# |NumPy          |1.18.5                                       |
# |SciPy          |1.4.1                                        |
# |Scikit-Learn   |0.22.2.post1                                 |
# |Seaborn        |2.3.0                                        |
# |Spacy          |3.6.0                                        |

# %% [markdown]
# ### on google

# %%
from google.colab import drive, files
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
currentCorpus = 'pan18_eval';

# %%
baseDir = '/content/gdrive/My Drive/Colab Notebooks/AA'
outputDir= pathjoin(baseDir,'ensemble','output_ensemble');

os.makedirs(outputDir, exist_ok=True)

def transferCode(filename):
    with open(os.path.join(baseDir,'ensemble',filename)) as fin:
        with open(filename,'w') as fout:
            fout.write(fin.read());
transferCode('pan.py')
transferCode('sklearnExtensions.py')

# %%
import pan
import sklearnExtensions
from sklearnExtensions import DenseTransformer, POSTagTransformer,FilterTagTransformer;

# %% [markdown]
# ## Data Ingestion

# %%
datasets = pd.read_json(baseDir+'/data/AllDS.json.zip', orient='records', compression='gzip')
datasets['row_index'] = np.arange(len(datasets));
datasets = datasets[['row_index','dataset','problem','language','set','filename','text','label']]
print(datasets['dataset'].unique())
# Out:
# ['pan18_train' 'pan18_eval' 'lyrics' 'socialaa']

# %%
df = datasets.query(f'dataset == "{currentCorpus}"').copy()

# %% [markdown]
# # Caching embeddings and POS Tagging

# %% [markdown]
# ### Linguistic anotations

# %%
postaggers = {
    l:POSTagTransformer(language=m)
    for l,m in {'en':'en', 'fr':'fr', 'it':'it', 'sp':'es'}.items()
}

# %% [markdown]
# the POSTagTransformer returns a sequence of tokens and its annotations
# 1. Text
# 2. tag
# 3. pos
# 4. dep

# %%
def cachePOS(row):
    if row['language'] == 'pl':
        return [];
    else:
        return postaggers[row['language']].fit_transform([row['text']])[0]

df['POS']=df.apply(cachePOS,axis=1)

# %%
df
# Out:
#       row_index  ...                                                POS
# 1496       1496  ...  [(hairdryer, NNP, PROPN, nsubj), (currently, R...
# 1497       1497  ...  [(., ., PUNCT, ROOT), (\n\n            , _SP, ...
# 1498       1498  ...  [(drop, VB, VERB, ROOT), (from, IN, ADP, prep)...
# 1499       1499  ...  [(there, EX, PRON, expl), ('d, VBD, AUX, aux),...
# 1500       1500  ...  [(., ., PUNCT, ROOT), (\n\n, _SP, SPACE, ), (Y...
# ...         ...  ...                                                ...
# 4556       4556  ...  [(¡, PUNCT__PunctSide=Ini|PunctType=Excl, PUNC...
# 4557       4557  ...  [(Blaise, PROPN, PROPN, nsubj), (se, PRON__Cas...
# 4558       4558  ...  [(que, SCONJ, SCONJ, mark), (ni, CCONJ, CCONJ,...
# 4559       4559  ...  [(personal, ADJ__Number=Sing, ADJ, ROOT), (,, ...
# 4560       4560  ...  [(apartar, VERB__VerbForm=Inf, VERB, ROOT), (l...
#
# [3065 rows x 9 columns]

# %% [markdown]
# ### Embeddings

# %%
def loadEmbeddings(lang):
    if lang == 'sp':
        lang = 'es';
    model = KeyedVectors.load_word2vec_format(os.path.join(baseDir,'data','embedding_cache','w2v_'+lang+'.txt.gz'), binary=False, unicode_errors='replace')
    return model;

# %%
def problemDoc(df,problem, column='text'):
    df = df.query(f"problem == '{problem}'")

    train = df[df['set'] =='known']
    X_train = np.array([c for c in train[column]])
    y_train = train['label'].values
    index_train = train['row_index'].values

    # The test set is actually the validation set and should not be used in the training processing
    test = df[df['set'] =='unknown']
    X_test = np.array([c for c in test[column]])
    y_test = test['label'].values
    index_test = test['row_index'].values

    return X_train, y_train, index_train, X_test, y_test, index_test;

# %% [markdown]
# It was used embeddings processed by Nordic Language Processing Laboratry
# and availabe on http://vectors.nlpl.eu/repository/. This website was visted in  jan 01 2019

# %%
def fitPipeline(df, problem,language, pipe,params,caching):
    print ("Problem: %s,  language: %s, " %(problem,language), end=' ');
    
    column = 'text';
    if caching == 'POS':
        column = 'POS';
    
    train_docs, train_labels, index_train, test_docs, test_labels,index_test = problemDoc(df, problem,column);
    if caching == 'POS':
        if language == 'pl':
            print("POS tagger not found")
            return {
                'problem':problem,
                'language':language,
                'n_authors': 0,
                'f1'       : 0,
                'precision': 0,
                'recall'   : 0,
                'accuracy' : 0,
            }, [[],[],[],[],[],[]], {};
    elif caching == 'w2v':
        global embeddingsCacheLanguage;
        global embeddingsCache;
        #yes it is uggly to use global var ... but it saved a lot of memory
        if embeddingsCacheLanguage != language:
            embeddingsCache = loadEmbeddings(language);
            embeddingsCacheLanguage = language;
        
    
    #using language specific params
    if language in params:
        pipe.set_params(**params[language])
        
    t0 = time()
    pipe.fit(train_docs, train_labels)
    print("Fitted in %0.3fs" % (time() - t0), end=' ');
    
    t0 = time()
    train_pred=pipe.predict(train_docs);
    train_prob=pipe.predict_proba(train_docs);

    test_pred=pipe.predict(test_docs);
    test_prob=pipe.predict_proba(test_docs);
    print("Predicted in %0.3fs" % (time() - t0));
    
    f1,precision,recall,accuracy = pan.eval_measures2019(test_labels,test_pred)
    
    return {
        'problem':problem,
        'language':language,
        'n_authors':len(set(train_labels)),
        'f1'       : round(f1,3),
        'precision': round(precision,3),
        'recall'   : round(recall,3),
        'accuracy' : round(accuracy,3),
    }, [train_pred, train_prob,index_train, test_pred,  test_prob,index_test], pipe.get_params();

# %% [markdown]
# # Model 1: Character

# %%
pipelineChar = Pipeline([
    ('vect',   TfidfVectorizer(analyzer='char',
                               min_df=0.01,
                               max_df=1.0,
                               norm='l2',
                               ngram_range=(2, 5),
                               sublinear_tf=True,
                               lowercase =False)),
    ('scaler', preprocessing.MaxAbsScaler()),
    ('dense',  DenseTransformer()),
    ('transf', PCA(0.999)),
    ('clf', LogisticRegression(random_state=0,multi_class='multinomial', solver='newton-cg')),
])

# %%
pipelineCharParams= {
    'it':{
        'vect__ngram_range': (3, 5),
    },
    'pl':{
        'vect__ngram_range': (2, 3),
    }
}

# %% [markdown]
# # Model 2: Word

# %%
pipelineWord = Pipeline([
    ('vect',   TfidfVectorizer(analyzer='word',
                               norm='l1',
                               min_df=2,
                               max_df=1.0,
                               ngram_range=(1, 2),
                               smooth_idf=True,
                               lowercase =True,
                               sublinear_tf=True)),
    ('dense',  DenseTransformer()),
    ('scaler', preprocessing.MaxAbsScaler()),
    ('transf', PCA(0.999)),
    ('clf', LogisticRegression(random_state=0,multi_class='multinomial', solver='newton-cg')),
])

# %%
pipelineWordParams= {
    'en':{
        'vect__ngram_range': (1, 3),
        'vect__norm': 'l2',
    },

    'pl':{
        'vect__norm': 'l2',
     },
}

# %% [markdown]
# # Model 3: distortions

# %%
distortions = [
    (r"[A-Z]"          ,'U','Upcase '),
    (r"[a-z]"          ,'l','lowercase'),
    (r"[À-ÿĄ-ż]"       ,'d','Diacrit'),
    (r"\d"             ,'D','Digits'),
    (r"[\n\r\t]"       ,'E','Paragraph control'),
    (r"\–|\-|\_|\—"    ,'H','Hyphen'),
    (r"\"|\'|’|[“”]"   ,'Q','quotation'),
    (r"\s"             ,'S','Spaces'),
    (r"\(|\)|\[|\]\{|\}|\«|\»",'G','Groups'),
    (r"…",'','...'),
    (r"\.|\,|[?]|\!|\:|\;|\„|\*|\/"   ,'P','Punctuation'),
    (r"[^aUldDEHQSGP]", 'X','Unkown'),
]

distortions = [(re.compile(d[0]), d[1],d[2]) for d in distortions]

# %%
class DistortionTransformer(BaseEstimator):
    def __init__(self,verbose=False):
        self.verbose = verbose;
        
    def _distortion(self,doc):
        for d in distortions:
            doc = d[0].sub(d[1],doc);
        return doc;

    def transform(self, X, y=None):
        t0 = time()
        if self.verbose:
            print('filtered in', end=' ')

        X = [self._distortion(doc) for doc in X]
        
        if self.verbose:
            print(" %0.3fs" % (time() - t0))
        return np.array(X);       

    def fit(self, X, y=None):
        self.is_fitted = True
        return self

    def fit_transform(self, X, y=None):
        return self.transform(X=X, y=y)

# %%
pipelineDistortion = Pipeline([
    ('filter',DistortionTransformer()),
    ('vect', TfidfVectorizer(
            analyzer='char',
            min_df=0.01,
            lowercase=False,
            norm='l2',
            sublinear_tf=True,
            ngram_range=(1, 5),
            )
    ),
    ('scaler', MaxAbsScaler()),
    ('dense',  DenseTransformer()),
    ('transf', PCA(0.999)),
    ('clf', LogisticRegression(random_state=0,C=1,multi_class='multinomial', solver='newton-cg')),
])

# %%
pipelineDistortionsParams = {
    'en':{
        'clf__C': 0.1,
        'vect__norm': 'l1',        
    },
    'fr':{
        'vect__norm': 'l1',
        'vect__ngram_range': (2, 5),
    },
    'it':{
        'clf__C': 0.1,
    },
    'sp':{
        'vect__norm': 'l1',
    }
}

# %% [markdown]
# # Model 4: POS

# %%
#train_docs, train_labels, test_docs, test_filename = cachingPOSTAG(problem)

pipelinePOS = Pipeline([
    ('filter',FilterTagTransformer(token='POS')),
    ('vect', TfidfVectorizer(
                        min_df=0.01,
                        lowercase=False,
                        use_idf=True,
                        norm='l1',
                        sublinear_tf=False,
                        ngram_range=(1, 5)
            )),
    ('scaler', MaxAbsScaler()),
    ('dense',  DenseTransformer()),
    ('transf', PCA(0.999)),
    ('clf', LogisticRegression(random_state=0,multi_class='multinomial', solver='newton-cg')),
])

# %% [markdown]
# O parametro sublinear_tf=True apresentou performance ruim em todos os casos de teste exceto o melhor.
# Como o melhor caso não é garantido nos conjuntos de avaliação, foi decidido que ele seria mantido como False.
#
# O parametro L1 apresentou performance melhor nos conjuntos com 5 candidatos. No entendo, o conjunto de validação conterá de 5 a 20 e portanto foi escolhido manter o valor l2

# %% [markdown]
# # Model 5: TAG  (granular POS)

# %%
def spaceTokenizer(x):
    return x.split(" ");

# %%
pipelineTag = Pipeline([
    ('filter',FilterTagTransformer(token='TAG')),
    ('vect', TfidfVectorizer(
                               tokenizer=spaceTokenizer,
                               min_df=0.01,
                               lowercase=False,
                               sublinear_tf=True,
                               use_idf=True,
                               norm='l2',
                                ngram_range=(1,3),
                              )),
    ('scaler', MaxAbsScaler()),
    ('dense',  DenseTransformer()),
    ('transf', PCA(0.999)),
    ('clf', LogisticRegression(random_state=0,C=0.1,multi_class='multinomial', solver='newton-cg')),
])

# %%
pipelineTagParams = {
    'fr':{
        'vect__ngram_range' :(1,5),
    },
    'sp':{
        'vect__ngram_range' :(1,5),
        'clf__C':1,
    }
}

# %% [markdown]
# # Model 6: Sintatic Dependency

# %%
pipelineDEP = Pipeline([
    ('filter',FilterTagTransformer(token='DEP')),
    ('vect', TfidfVectorizer(
                    analyzer='word',
                    min_df=0.01,
                    lowercase=False,
                    use_idf=True,
                    norm='l2',
                    ngram_range=(1,5),
            )),
    ('scaler', MaxAbsScaler()),
    ('dense',  DenseTransformer()),
    ('transf', PCA(0.999)),
    ('clf', LogisticRegression(random_state=0,C=1,multi_class='multinomial', solver='newton-cg')),
])

# %%
pipelineDEPParams = {
    'en':{
        'clf__C':0.1,
    },
    'fr':{
        'clf__C':0.1,
    },
    'it':{
        'vect__ngram_range' :(1,3),
    },
}

# %% [markdown]
# # Model 7: Word Embeddings

# %%
embeddingsCacheLanguage = None;
embeddingsCache = None;

# %%
from scipy import sparse
from sklearn.utils import assert_all_finite

class EmbeddingVectorizer(BaseEstimator):
    def __init__(self,norm=None,analyzer='word',min_df=1,lowercase=False,sublinear_tf=True,use_idf=True,binary=False):
        self.norm        = norm;
        self.analyzer    = analyzer;
        self.min_df      = min_df;
        self.lowercase   = lowercase;
        self.sublinear_tf= sublinear_tf;
        self.use_idf     = use_idf;
        self.binary      = binary;
        
    def fit(self, X, y=None):
        self.dim_ = len(embeddingsCache.vectors[0]);
        #self.dim_ = len(embeddingsCache[list(embeddingsCache.keys())[0]])
        self.vect = TfidfVectorizer(**self.get_params())
        self.vect.fit(X,y);
        self.word_vectors_ = np.zeros((len(self.vect.vocabulary_), self.dim_));
        
        #this arrays says if a word in the vocab has 
        self.missingWord_  = np.zeros(len(self.vect.vocabulary_),dtype=np.int8);
        
        blank = np.zeros(self.dim_);

        for  word, index in self.vect.vocabulary_.items():
            temp = blank.copy();
            for w in [word, word.lower(), word.capitalize()]:
                if w in embeddingsCache:
                    temp = embeddingsCache[w];
                    break;
            if temp.sum() == 0 :
                self.missingWord_[index] = 1;
            self.word_vectors_[index,:] = temp;
        return self
    
    def transform(self, X):
        import gc;
        gc.collect()
        X = self.vect.transform(X);
        
        X = sparse.csc_matrix(X);
        V = sparse.csc_matrix(self.word_vectors_);
        M = sparse.csc_matrix(self.missingWord_).T;
        
        missing = preprocessing.normalize((X>0).dot(M),norm='l1');
        missing = sparse.csc_matrix(missing.reshape(-1,1));
        
        #memory friendly dot product
        X  = preprocessing.normalize(X.dot(V),norm='l1');
        
        #last columns will contain the embedding coverage
        X = sparse.hstack([X,missing]);
        
        return X;
    
    def fit_transform(self, X, y=None):
        self.fit(X,y);
        return self.transform(X)
    
    def get_feature_names():
        return self.vect.get_feature_names();

# %%
pipelineEmbeddings = Pipeline([
    ('vect', EmbeddingVectorizer(
            analyzer='word',
            min_df=0.01,
            lowercase=False,
            sublinear_tf=False,
            norm='l1',
            use_idf=False
            )
    ),
    ('scaler',preprocessing.MaxAbsScaler()),
    ('dense',DenseTransformer()),
    ('pca',PCA(0.999)),
    ('clf', LogisticRegression(random_state=0,C=1,multi_class='multinomial', solver='newton-cg')),
])

# %%
pipelineEmbeddingsParams = {
    'fr':{
        'vect__sublinear_tf': True,
        'vect__use_idf': True,
    },

    'it':{
        'vect__use_idf': True,
    },

    'pl':{
        'clf__C': 0.1,
        'vect__use_idf': False,
        'vect__sublinear_tf': True,
    },
    'sp':{
        'vect__sublinear_tf': True,
        'vect__use_idf': True,
    },
}

# %% [markdown]
# # Applying models

# %%
models =[
    ('char',pipelineChar,pipelineCharParams,None),
    ('word',pipelineWord,pipelineWordParams,None),
    ('dist',pipelineDistortion,pipelineDistortionsParams,None),
    ('pos',pipelinePOS,{},'POS'),
    ('tag',pipelineTag,pipelineTagParams,'POS'),
    ('dep',pipelineDEP,pipelineDEPParams,'POS'),
    ('w2v',pipelineEmbeddings,pipelineEmbeddingsParams,'w2v'),
]

results = {};

for model in models:
    if model[0] in results:
        continue;
    print(('_'*100)+'\n'+model[0]+'\n'+('_'*100))
    result= {
        'metric':[],
        'pred_train':[],
        'pred_test':[],
        'prob_train':[],
        'prob_test':[],
        'index_train':[],
        'index_test':[],
        'params':[],
    }
    for problem in np.sort(df['problem'].unique()):
        language = df.query(f'problem =="{problem}"')['language'].unique()[0]
        metric, vects, params = fitPipeline(df, problem, language, model[1], model[2], caching=model[3]);
        result['metric'].append(metric);

        result['pred_train'].append(vects[0]);
        result['prob_train'].append(vects[1]);
        result['index_train'].append(vects[2]);

        result['pred_test'].append(vects[3]);
        result['prob_test'].append(vects[4]);
        result['index_test'].append(vects[5]);
        result['params'].append(params);
    results[model[0]]=result;
# Out:
# ____________________________________________________________________________________________________
# char
# ____________________________________________________________________________________________________
# Problem: problem00001,  language: en,  Fitted in 6.727s Predicted in 6.746s
# Problem: problem00002,  language: en,  Fitted in 4.211s Predicted in 5.090s
# Problem: problem00003,  language: en,  Fitted in 3.705s Predicted in 3.551s
# Problem: problem00004,  language: en,  Fitted in 1.180s Predicted in 1.618s
# Problem: problem00005,  language: fr,  Fitted in 6.370s Predicted in 7.244s
# Problem: problem00006,  language: fr,  Fitted in 4.220s Predicted in 5.564s
# Problem: problem00007,  language: fr,  Fitted in 3.545s Predicted in 3.873s
# Problem: problem00008,  language: fr,  Fitted in 1.257s Predicted in 1.763s
# Problem: problem00009,  language: it,  Fitted in 6.457s Predicted in 6.558s
# Problem: problem00010,  language: it,  Fitted in 4.066s Predicted in 4.717s
# Problem: problem00011,  language: it,  Fitted in 3.262s Predicted in 3.169s
# Problem: problem00012,  language: it,  Fitted in 1.093s Predicted in 2.003s
# Problem: problem00013,  language: pl,  Fitted in 1.232s Predicted in 3.387s
# Problem: problem00014,  language: pl,  Fitted in 0.893s Predicted in 2.653s
# Problem: problem00015,  language: pl,  Fitted in 0.697s Predicted in 1.519s
# Problem: problem00016,  language: pl,  Fitted in 0.316s Predicted in 1.006s
# Problem: problem00017,  language: sp,  Fitted in 1.009s Predicted in 3.008s
# Problem: problem00018,  language: sp,  Fitted in 0.747s Predicted in 2.289s
# Problem: problem00019,  language: sp,  Fitted in 0.511s Predicted in 1.653s
# Problem: problem00020,  language: sp,  Fitted in 0.270s Predicted in 0.793s
# ____________________________________________________________________________________________________
# word
# ____________________________________________________________________________________________________
# Problem: problem00001,  language: en,  Fitted in 1.651s Predicted in 1.198s
# Problem: problem00002,  language: en,  Fitted in 1.042s Predicted in 0.926s
# Problem: problem00003,  language: en,  Fitted in 0.639s Predicted in 0.618s
# Problem: problem00004,  language: en,  Fitted in 0.298s Predicted in 0.322s
# Problem: problem00005,  language: fr,  Fitted in 1.608s Predicted in 1.251s
# Problem: problem00006,  language: fr,  Fitted in 1.046s Predicted in 0.937s
# Problem: problem00007,  language: fr,  Fitted in 0.625s Predicted in 0.635s
# Problem: problem00008,  language: fr,  Fitted in 0.294s Predicted in 0.325s
# Problem: problem00009,  language: it,  Fitted in 1.609s Predicted in 1.252s
# Problem: problem00010,  language: it,  Fitted in 1.050s Predicted in 0.892s
# Problem: problem00011,  language: it,  Fitted in 0.644s Predicted in 0.564s
# Problem: problem00012,  language: it,  Fitted in 0.305s Predicted in 0.440s
# Problem: problem00013,  language: pl,  Fitted in 1.682s Predicted in 1.366s
# Problem: problem00014,  language: pl,  Fitted in 1.116s Predicted in 1.019s
# Problem: problem00015,  language: pl,  Fitted in 0.659s Predicted in 0.624s
# Problem: problem00016,  language: pl,  Fitted in 0.317s Predicted in 0.404s
# Problem: problem00017,  language: sp,  Fitted in 1.743s Predicted in 1.470s
# Problem: problem00018,  language: sp,  Fitted in 1.117s Predicted in 1.076s
# Problem: problem00019,  language: sp,  Fitted in 0.649s Predicted in 0.756s
# Problem: problem00020,  language: sp,  Fitted in 0.323s Predicted in 0.374s
# ____________________________________________________________________________________________________
# dist
# ____________________________________________________________________________________________________
# Problem: problem00001,  language: en,  Fitted in 1.272s Predicted in 4.538s
# Problem: problem00002,  language: en,  Fitted in 0.989s Predicted in 3.725s
# Problem: problem00003,  language: en,  Fitted in 0.686s Predicted in 2.370s
# Problem: problem00004,  language: en,  Fitted in 0.370s Predicted in 1.178s
# Problem: problem00005,  language: fr,  Fitted in 1.180s Predicted in 4.408s
# Problem: problem00006,  language: fr,  Fitted in 0.925s Predicted in 3.483s
# Problem: problem00007,  language: fr,  Fitted in 0.649s Predicted in 2.300s
# Problem: problem00008,  language: fr,  Fitted in 0.356s Predicted in 1.132s
# Problem: problem00009,  language: it,  Fitted in 1.314s Predicted in 4.806s
# Problem: problem00010,  language: it,  Fitted in 0.999s Predicted in 3.629s
# Problem: problem00011,  language: it,  Fitted in 0.710s Predicted in 2.201s
# Problem: problem00012,  language: it,  Fitted in 0.378s Predicted in 1.632s
# Problem: problem00013,  language: pl,  Fitted in 1.397s Predicted in 5.809s
# Problem: problem00014,  language: pl,  Fitted in 1.058s Predicted in 4.583s
# Problem: problem00015,  language: pl,  Fitted in 0.741s Predicted in 2.537s
# Problem: problem00016,  language: pl,  Fitted in 0.381s Predicted in 1.637s
# Problem: problem00017,  language: sp,  Fitted in 1.306s Predicted in 5.453s
# Problem: problem00018,  language: sp,  Fitted in 0.994s Predicted in 4.197s
# Problem: problem00019,  language: sp,  Fitted in 0.683s Predicted in 2.866s
# Problem: problem00020,  language: sp,  Fitted in 0.385s Predicted in 1.357s
# ____________________________________________________________________________________________________
# pos
# ____________________________________________________________________________________________________
# Problem: problem00001,  language: en,  Fitted in 2.054s Predicted in 2.259s
# Problem: problem00002,  language: en,  Fitted in 1.138s Predicted in 1.679s
# Problem: problem00003,  language: en,  Fitted in 0.929s Predicted in 1.197s
# Problem: problem00004,  language: en,  Fitted in 0.343s Predicted in 0.568s
# Problem: problem00005,  language: fr,  Fitted in 1.599s Predicted in 2.075s
# Problem: problem00006,  language: fr,  Fitted in 1.007s Predicted in 1.623s
# Problem: problem00007,  language: fr,  Fitted in 0.849s Predicted in 1.204s
# Problem: problem00008,  language: fr,  Fitted in 0.341s Predicted in 0.575s
# Problem: problem00009,  language: it,  Fitted in 1.668s Predicted in 2.198s
# Problem: problem00010,  language: it,  Fitted in 0.980s Predicted in 1.595s
# Problem: problem00011,  language: it,  Fitted in 0.838s Predicted in 1.092s
# Problem: problem00012,  language: it,  Fitted in 0.319s Predicted in 0.783s
# Problem: problem00013,  language: pl,  POS tagger not found
# Problem: problem00014,  language: pl,  POS tagger not found
# Problem: problem00015,  language: pl,  POS tagger not found
# Problem: problem00016,  language: pl,  POS tagger not found
# Problem: problem00017,  language: sp,  Fitted in 1.903s Predicted in 2.574s
# Problem: problem00018,  language: sp,  Fitted in 1.178s Predicted in 1.938s
# Problem: problem00019,  language: sp,  Fitted in 0.965s Predicted in 1.465s
# Problem: problem00020,  language: sp,  Fitted in 0.348s Predicted in 0.663s
# ____________________________________________________________________________________________________
# tag
# ____________________________________________________________________________________________________
# Problem: problem00001,  language: en,  Fitted in 0.495s Predicted in 1.095s
# Problem: problem00002,  language: en,  Fitted in 0.361s Predicted in 0.892s
# Problem: problem00003,  language: en,  Fitted in 0.273s Predicted in 0.655s
# Problem: problem00004,  language: en,  Fitted in 0.140s Predicted in 0.349s
# Problem: problem00005,  language: fr,  Fitted in 1.731s Predicted in 2.160s
# Problem: problem00006,  language: fr,  Fitted in 1.007s Predicted in 1.637s
# Problem: problem00007,  language: fr,  Fitted in 0.958s Predicted in 1.226s
# Problem: problem00008,  language: fr,  Fitted in 0.358s Predicted in 0.584s
# Problem: problem00009,  language: it,  Fitted in 2.667s Predicted in 2.444s
# Problem: problem00010,  language: it,  Fitted in 1.534s Predicted in 1.733s
# Problem: problem00011,  language: it,  Fitted in 1.681s Predicted in 1.267s
# Problem: problem00012,  language: it,  Fitted in 0.465s Predicted in 0.844s
# Problem: problem00013,  language: pl,  POS tagger not found
# Problem: problem00014,  language: pl,  POS tagger not found
# Problem: problem00015,  language: pl,  POS tagger not found
# Problem: problem00016,  language: pl,  POS tagger not found
# Problem: problem00017,  language: sp,  Fitted in 1.864s Predicted in 2.635s
# Problem: problem00018,  language: sp,  Fitted in 1.141s Predicted in 1.979s
# Problem: problem00019,  language: sp,  Fitted in 1.028s Predicted in 1.504s
# Problem: problem00020,  language: sp,  Fitted in 0.378s Predicted in 0.668s
# ____________________________________________________________________________________________________
# dep
# ____________________________________________________________________________________________________
# Problem: problem00001,  language: en,  Fitted in 2.287s Predicted in 2.238s
# Problem: problem00002,  language: en,  Fitted in 1.329s Predicted in 1.740s
# Problem: problem00003,  language: en,  Fitted in 1.377s Predicted in 1.294s
# Problem: problem00004,  language: en,  Fitted in 0.428s Predicted in 0.592s
# Problem: problem00005,  language: fr,  Fitted in 2.465s Predicted in 2.461s
# Problem: problem00006,  language: fr,  Fitted in 1.413s Predicted in 1.847s
# Problem: problem00007,  language: fr,  Fitted in 1.587s Predicted in 1.448s
# Problem: problem00008,  language: fr,  Fitted in 0.472s Predicted in 0.659s
# Problem: problem00009,  language: it,  Fitted in 0.444s Predicted in 1.155s
# Problem: problem00010,  language: it,  Fitted in 0.325s Predicted in 0.888s
# Problem: problem00011,  language: it,  Fitted in 0.236s Predicted in 0.599s
# Problem: problem00012,  language: it,  Fitted in 0.144s Predicted in 0.500s
# Problem: problem00013,  language: pl,  POS tagger not found
# Problem: problem00014,  language: pl,  POS tagger not found
# Problem: problem00015,  language: pl,  POS tagger not found
# Problem: problem00016,  language: pl,  POS tagger not found
# Problem: problem00017,  language: sp,  Fitted in 0.451s Predicted in 1.268s
# Problem: problem00018,  language: sp,  Fitted in 0.308s Predicted in 1.004s
# Problem: problem00019,  language: sp,  Fitted in 0.225s Predicted in 0.754s
# Problem: problem00020,  language: sp,  Fitted in 0.135s Predicted in 0.387s
# ____________________________________________________________________________________________________
# w2v
# ____________________________________________________________________________________________________
# Problem: problem00001,  language: en,  Fitted in 0.686s Predicted in 1.842s
# Problem: problem00002,  language: en,  Fitted in 0.633s Predicted in 1.699s
# Problem: problem00003,  language: en,  Fitted in 0.701s Predicted in 1.910s
# Problem: problem00004,  language: en,  Fitted in 0.528s Predicted in 1.534s
# Problem: problem00005,  language: fr,  Fitted in 0.584s Predicted in 1.530s
# Problem: problem00006,  language: fr,  Fitted in 0.557s Predicted in 1.411s
# Problem: problem00007,  language: fr,  Fitted in 0.577s Predicted in 1.439s
# Problem: problem00008,  language: fr,  Fitted in 0.454s Predicted in 1.195s
# Problem: problem00009,  language: it,  Fitted in 0.603s Predicted in 1.552s
# Problem: problem00010,  language: it,  Fitted in 0.579s Predicted in 1.422s
# Problem: problem00011,  language: it,  Fitted in 0.588s Predicted in 1.376s
# Problem: problem00012,  language: it,  Fitted in 0.411s Predicted in 1.196s
# Problem: problem00013,  language: pl,  Fitted in 0.652s Predicted in 1.629s
# Problem: problem00014,  language: pl,  Fitted in 0.664s Predicted in 1.490s
# Problem: problem00015,  language: pl,  Fitted in 0.683s Predicted in 1.500s
# Problem: problem00016,  language: pl,  Fitted in 0.471s Predicted in 1.257s
# Problem: problem00017,  language: sp,  Fitted in 0.585s Predicted in 1.548s
# Problem: problem00018,  language: sp,  Fitted in 0.556s Predicted in 1.448s
# Problem: problem00019,  language: sp,  Fitted in 0.581s Predicted in 1.456s
# Problem: problem00020,  language: sp,  Fitted in 0.459s Predicted in 1.176s

# %%
dfMetric = pd.DataFrame();
for m in results:
    df_temp = pd.DataFrame(results[m]['metric'])[['problem','n_authors','language','f1','precision','recall','accuracy']]
    df_temp['model']=m
    dfMetric= dfMetric.append(df_temp)

with pd.option_context("display.precision", 3):
    display(dfMetric.fillna(value=0) \
        .pivot(index='problem',columns='model',values=['f1','accuracy']).round(3)\
        .style.background_gradient(subset=['f1'], axis=1, cmap=plt.cm.Blues)\
        .background_gradient(subset=['accuracy'], axis=1, cmap=plt.cm.Greens))
# Out:
# <style  type="text/css" >
# #T_4724ef46_193a_11eb_87ba_0242ac1c0002row0_col0,#T_4724ef46_193a_11eb_87ba_0242ac1c0002row1_col0,#T_4724ef46_193a_11eb_87ba_0242ac1c0002row2_col0,#T_4724ef46_193a_11eb_87ba_0242ac1c0002row3_col4,#T_4724ef46_193a_11eb_87ba_0242ac1c0002row4_col0,#T_4724ef46_193a_11eb_87ba_0242ac1c0002row5_col0,#T_4724ef46_193a_11eb_87ba_0242ac1c0002row6_col3,#T_4724ef46_193a_11eb_87ba_0242ac1c0002row7_col0,#T_4724ef46_193a_11eb_87ba_0242ac1c0002row8_col0,#T_4724ef46_193a_11eb_87ba_0242ac1c0002row9_col0,#T_4724ef46_193a_11eb_87ba_0242ac1c0002row10_col0,#T_4724ef46_193a_11eb_87ba_0242ac1c0002row11_col0,#T_4724ef46_193a_11eb_87ba_0242ac1c0002row12_col0,#T_4724ef46_193a_11eb_87ba_0242ac1c0002row13_col0,#T_4724ef46_193a_11eb_87ba_0242ac1c0002row14_col6,#T_4724ef46_193a_11eb_87ba_0242ac1c0002row15_col6,#T_4724ef46_193a_11eb_87ba_0242ac1c0002row16_col2,#T_4724ef46_193a_11eb_87ba_0242ac1c0002row17_col0,#T_4724ef46_193a_11eb_87ba_0242ac1c0002row18_col2,#T_4724ef46_193a_11eb_87ba_0242ac1c0002row19_col3{
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }#T_4724ef46_193a_11eb_87ba_0242ac1c0002row0_col1{
#             background-color:  #d0e2f2;
#             color:  #000000;
#         }#T_4724ef46_193a_11eb_87ba_0242ac1c0002row0_col2{
#             background-color:  #ccdff1;
#             color:  #000000;
#         }#T_4724ef46_193a_11eb_87ba_0242ac1c0002row0_col3,#T_4724ef46_193a_11eb_87ba_0242ac1c0002row13_col5{
#             background-color:  #bfd8ed;
#             color:  #000000;
#         }#T_4724ef46_193a_11eb_87ba_0242ac1c0002row0_col4,#T_4724ef46_193a_11eb_87ba_0242ac1c0002row2_col3,#T_4724ef46_193a_11eb_87ba_0242ac1c0002row8_col4{
#             background-color:  #a8cee4;
#             color:  #000000;
#         }#T_4724ef46_193a_11eb_87ba_0242ac1c0002row0_col5,#T_4724ef46_193a_11eb_87ba_0242ac1c0002row1_col1,#T_4724ef46_193a_11eb_87ba_0242ac1c0002row2_col5,#T_4724ef46_193a_11eb_87ba_0242ac1c0002row3_col5,#T_4724ef46_193a_11eb_87ba_0242ac1c0002row4_col5,#T_4724ef46_193a_11eb_87ba_0242ac1c0002row5_col5,#T_4724ef46_193a_11eb_87ba_0242ac1c0002row6_col5,#T_4724ef46_193a_11eb_87ba_0242ac1c0002row7_col5,#T_4724ef46_193a_11eb_87ba_0242ac1c0002row8_col5,#T_4724ef46_193a_11eb_87ba_0242ac1c0002row9_col5,#T_4724ef46_193a_11eb_87ba_0242ac1c0002row10_col5,#T_4724ef46_193a_11eb_87ba_0242ac1c0002row11_col5,#T_4724ef46_193a_11eb_87ba_0242ac1c0002row12_col1,#T_4724ef46_193a_11eb_87ba_0242ac1c0002row12_col3,#T_4724ef46_193a_11eb_87ba_0242ac1c0002row12_col4,#T_4724ef46_193a_11eb_87ba_0242ac1c0002row13_col1,#T_4724ef46_193a_11eb_87ba_0242ac1c0002row13_col3,#T_4724ef46_193a_11eb_87ba_0242ac1c0002row13_col4,#T_4724ef46_193a_11eb_87ba_0242ac1c0002row14_col1,#T_4724ef46_193a_11eb_87ba_0242ac1c0002row14_col3,#T_4724ef46_193a_11eb_87ba_0242ac1c0002row14_col4,#T_4724ef46_193a_11eb_87ba_0242ac1c0002row15_col1,#T_4724ef46_193a_11eb_87ba_0242ac1c0002row15_col3,#T_4724ef46_193a_11eb_87ba_0242ac1c0002row15_col4,#T_4724ef46_193a_11eb_87ba_0242ac1c0002row16_col5,#T_4724ef46_193a_11eb_87ba_0242ac1c0002row17_col5,#T_4724ef46_193a_11eb_87ba_0242ac1c0002row18_col5,#T_4724ef46_193a_11eb_87ba_0242ac1c0002row19_col5{
#             background-color:  #f7fbff;
#             color:  #000000;
#         }#T_4724ef46_193a_11eb_87ba_0242ac1c0002row0_col6{
#             background-color:  #6caed6;
#             color:  #000000;
#         }#T_4724ef46_193a_11eb_87ba_0242ac1c0002row0_col7,#T_4724ef46_193a_11eb_87ba_0242ac1c0002row1_col7,#T_4724ef46_193a_11eb_87ba_0242ac1c0002row2_col7,#T_4724ef46_193a_11eb_87ba_0242ac1c0002row3_col11,#T_4724ef46_193a_11eb_87ba_0242ac1c0002row4_col7,#T_4724ef46_193a_11eb_87ba_0242ac1c0002row5_col7,#T_4724ef46_193a_11eb_87ba_0242ac1c0002row6_col7,#T_4724ef46_193a_11eb_87ba_0242ac1c0002row7_col7,#T_4724ef46_193a_11eb_87ba_0242ac1c0002row8_col7,#T_4724ef46_193a_11eb_87ba_0242ac1c0002row9_col7,#T_4724ef46_193a_11eb_87ba_0242ac1c0002row10_col7,#T_4724ef46_193a_11eb_87ba_0242ac1c0002row11_col7,#T_4724ef46_193a_11eb_87ba_0242ac1c0002row12_col7,#T_4724ef46_193a_11eb_87ba_0242ac1c0002row13_col7,#T_4724ef46_193a_11eb_87ba_0242ac1c0002row14_col7,#T_4724ef46_193a_11eb_87ba_0242ac1c0002row14_col12,#T_4724ef46_193a_11eb_87ba_0242ac1c0002row15_col7,#T_4724ef46_193a_11eb_87ba_0242ac1c0002row16_col9,#T_4724ef46_193a_11eb_87ba_0242ac1c0002row17_col11,#T_4724ef46_193a_11eb_87ba_0242ac1c0002row18_col7,#T_4724ef46_193a_11eb_87ba_0242ac1c0002row19_col10{
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }#T_4724ef46_193a_11eb_87ba_0242ac1c0002row0_col8,#T_4724ef46_193a_11eb_87ba_0242ac1c0002row0_col9{
#             background-color:  #c9eac2;
#             color:  #000000;
#         }#T_4724ef46_193a_11eb_87ba_0242ac1c0002row0_col10{
#             background-color:  #90d18d;
#             color:  #000000;
#         }#T_4724ef46_193a_11eb_87ba_0242ac1c0002row0_col11,#T_4724ef46_193a_11eb_87ba_0242ac1c0002row10_col11{
#             background-color:  #62bb6d;
#             color:  #000000;
#         }#T_4724ef46_193a_11eb_87ba_0242ac1c0002row0_col12,#T_4724ef46_193a_11eb_87ba_0242ac1c0002row1_col12,#T_4724ef46_193a_11eb_87ba_0242ac1c0002row2_col12,#T_4724ef46_193a_11eb_87ba_0242ac1c0002row3_col9,#T_4724ef46_193a_11eb_87ba_0242ac1c0002row3_col12,#T_4724ef46_193a_11eb_87ba_0242ac1c0002row4_col12,#T_4724ef46_193a_11eb_87ba_0242ac1c0002row5_col12,#T_4724ef46_193a_11eb_87ba_0242ac1c0002row6_col12,#T_4724ef46_193a_11eb_87ba_0242ac1c0002row7_col12,#T_4724ef46_193a_11eb_87ba_0242ac1c0002row8_col12,#T_4724ef46_193a_11eb_87ba_0242ac1c0002row9_col12,#T_4724ef46_193a_11eb_87ba_0242ac1c0002row10_col8,#T_4724ef46_193a_11eb_87ba_0242ac1c0002row11_col12,#T_4724ef46_193a_11eb_87ba_0242ac1c0002row12_col8,#T_4724ef46_193a_11eb_87ba_0242ac1c0002row12_col10,#T_4724ef46_193a_11eb_87ba_0242ac1c0002row12_col11,#T_4724ef46_193a_11eb_87ba_0242ac1c0002row13_col8,#T_4724ef46_193a_11eb_87ba_0242ac1c0002row13_col10,#T_4724ef46_193a_11eb_87ba_0242ac1c0002row13_col11,#T_4724ef46_193a_11eb_87ba_0242ac1c0002row14_col8,#T_4724ef46_193a_11eb_87ba_0242ac1c0002row14_col10,#T_4724ef46_193a_11eb_87ba_0242ac1c0002row14_col11,#T_4724ef46_193a_11eb_87ba_0242ac1c0002row15_col8,#T_4724ef46_193a_11eb_87ba_0242ac1c0002row15_col10,#T_4724ef46_193a_11eb_87ba_0242ac1c0002row15_col11,#T_4724ef46_193a_11eb_87ba_0242ac1c0002row16_col12,#T_4724ef46_193a_11eb_87ba_0242ac1c0002row17_col12,#T_4724ef46_193a_11eb_87ba_0242ac1c0002row18_col12,#T_4724ef46_193a_11eb_87ba_0242ac1c0002row19_col12{
#             background-color:  #f7fcf5;
#             color:  #000000;
#         }#T_4724ef46_193a_11eb_87ba_0242ac1c0002row0_col13{
#             background-color:  #3ea75a;
#             color:  #000000;
#         }#T_4724ef46_193a_11eb_87ba_0242ac1c0002row1_col2,#T_4724ef46_193a_11eb_87ba_0242ac1c0002row3_col2{
#             background-color:  #cee0f2;
#             color:  #000000;
#         }#T_4724ef46_193a_11eb_87ba_0242ac1c0002row1_col3{
#             background-color:  #cddff1;
#             color:  #000000;
#         }#T_4724ef46_193a_11eb_87ba_0242ac1c0002row1_col4{
#             background-color:  #3585bf;
#             color:  #000000;
#         }#T_4724ef46_193a_11eb_87ba_0242ac1c0002row1_col5{
#             background-color:  #e3eef8;
#             color:  #000000;
#         }#T_4724ef46_193a_11eb_87ba_0242ac1c0002row1_col6,#T_4724ef46_193a_11eb_87ba_0242ac1c0002row16_col4{
#             background-color:  #3383be;
#             color:  #000000;
#         }#T_4724ef46_193a_11eb_87ba_0242ac1c0002row1_col8{
#             background-color:  #e8f6e4;
#             color:  #000000;
#         }#T_4724ef46_193a_11eb_87ba_0242ac1c0002row1_col9{
#             background-color:  #c0e6b9;
#             color:  #000000;
#         }#T_4724ef46_193a_11eb_87ba_0242ac1c0002row1_col10{
#             background-color:  #aadda4;
#             color:  #000000;
#         }#T_4724ef46_193a_11eb_87ba_0242ac1c0002row1_col11{
#             background-color:  #3aa357;
#             color:  #000000;
#         }#T_4724ef46_193a_11eb_87ba_0242ac1c0002row1_col13{
#             background-color:  #43ac5e;
#             color:  #0000

# %% [markdown]
# # Dynamic Ensemble

# %%
def buildClassifier():
    return Pipeline(steps=[
                ('pca',PCA(0.9999)),
                ('clf', LogisticRegression(random_state=0,C=1,max_iter=3000))
            ])

# %%
def concatenatXVectors(results, problemIndex, models):
    x_train = [results[model]['prob_train'][problemIndex] for model in models];
    x_test  = [results[model]['prob_test'][problemIndex] for model in models];
    
    x_train = [x for x in x_train if len(x) > 1];
    x_test  = [x for x in x_test  if len(x) > 1];
    
    if len(x_train) < 1:
        return None,None;
    
    return np.hstack(x_train),  np.hstack(x_test);

# %%
def sortModels(results, problemIndex,models,train_labels, test_labels):
    f1 = [];
    
    for model in models:
        x_train, x_test = concatenatXVectors(results, problemIndex, [model]);
        if x_train is None:
            f1.append(0);
        else:
            pipe = buildClassifier()
            pred_label = pipe.fit(x_train, train_labels).predict(x_test);
            f1.append(f1_score(test_labels, pred_label,average='macro'));
    models = np.array(models);
    f1 = np.array(f1);
    
    models = models[f1 >0];
    f1 = f1[f1 >0]
    
    return list(models[np.argsort(-f1)]);

# %%
resultFinal = []
bestModels = []
predictions = [];
for problemIndex, problem in enumerate(df['problem'].unique()):
    print('\n'+problem)

    train_docs, train_labels, index_train, test_docs, test_labels,index_test = problemDoc(df, problem);

    #forward step: sorting the models by
    models = sortModels(results, problemIndex,list(results.keys()), train_labels, test_labels);

    print("sorted "+str(models))

    #step 0 - train only the best model.
    bestModel =[ models.pop(0)];
    x_train, x_test = concatenatXVectors(results, problemIndex, bestModel);
    pred_label  = buildClassifier().fit(x_train, train_labels).predict(x_test);
    bestF1      = f1_score(test_labels,pred_label,average='macro')
    models = list(set(models)-set(bestModel)); # removing the current model from the list.
    
    improve = True;
    iteration = 0;
    while (improve):
        improve = False;
        iteration +=1 ;
        print("Iteration "+str(iteration)    +" Best model:     %-77s %.4f"%(str(bestModel),bestF1))
        for model in models:
            currentModel = bestModel +[model];
            print("Iteration "+str(iteration)+" current model:  %-75s "%str(currentModel), end=' ')

            x_train, x_test = concatenatXVectors(results, problemIndex, currentModel);

            pipe = buildClassifier()

            pred_label = pipe.fit(x_train, train_labels).predict(x_test);
            currentF1 = f1_score(test_labels,pred_label,average='macro');
            
            print(" %.4f"%currentF1)


            if currentF1/bestF1 > 1.015:
                improve = True;
                bestF1 = currentF1;
                bestModel = currentModel;
        models = list(set(models)-set(currentModel));
    print("Selected Model: "+str(bestModel))
    bestModels.append(bestModel);
    
    x_train, x_test = concatenatXVectors(results, problemIndex, bestModel);
    
    pipelineFinal = Pipeline(steps=[
        ('pca',PCA(0.9999)),
        ('clf', LogisticRegression(random_state=0,C=100000))
    ])

    pipelineFinal.fit(x_train, train_labels);
    pred_train = pipelineFinal.predict(x_train);
    pred_proba_train = pipelineFinal.predict_proba(x_train);
    pred_test = pipelineFinal.predict(x_test);
    pred_proba_test = pipelineFinal.predict_proba(x_test);

    def appendPrediction(predictions,classes_,index, pred,proba):
        for i,p, pr in  zip(index, pred, proba):
            predictions.append(dict(**{
                    'dataset':currentCorpus,
                    'problem':problem,
                    'model':'dymAA',
                    'row_index':i,
                    'pred':p,
                }, **{
                    cc:pr_ for cc,pr_ in zip(classes_, pr)
                })
            )

    appendPrediction(predictions,pipelineFinal.classes_, index_train, pred_train, pred_proba_train)
    appendPrediction(predictions,pipelineFinal.classes_, index_test, pred_test, pred_proba_test)
    

    resultFinal.append({
        'model':'0ensemble',
        'problem':problem,
        'language':df.query(f"problem == '{problem}'")['language'].unique()[0],
        'n_authors': len(set(train_labels)),
        'f1':round(f1_score(test_labels,pred_test,average='macro'),3),
        'accuracy':round(accuracy_score(test_labels,pred_test),3)
    })
# Out:
# problem00001
# sorted ['char', 'word', 'tag', 'pos', 'dist', 'dep', 'w2v']
# Iteration 1 Best model:     ['char']                                                                      0.7564
# Iteration 1 current model:  ['char', 'word']                                                              0.6780
# Iteration 1 current model:  ['char', 'tag']                                                               0.6885
# Iteration 1 current model:  ['char', 'dep']                                                               0.7125
# Iteration 1 current model:  ['char', 'w2v']                                                               0.4719
# Iteration 1 current model:  ['char', 'pos']                                                               0.6609
# Iteration 1 current model:  ['char', 'dist']                                                              0.6901
# Selected Model: ['char']
#
# problem00002
# sorted ['char', 'word', 'tag', 'dist', 'pos', 'w2v', 'dep']
# Iteration 1 Best model:     ['char']                                                                      0.7264
# Iteration 1 current model:  ['char', 'word']                                                              0.7448
# Iteration 1 current model:  ['char', 'word', 'tag']                                                       0.7363
# Iteration 1 current model:  ['char', 'word', 'dep']                                                       0.7208
# Iteration 1 current model:  ['char', 'word', 'w2v']                                                       0.6272
# Iteration 1 current model:  ['char', 'word', 'pos']                                                       0.7110
# Iteration 1 current model:  ['char', 'word', 'dist']                                                      0.6985
# Iteration 2 Best model:     ['char', 'word']                                                              0.7448
# Iteration 2 current model:  ['char', 'word', 'w2v']                                                       0.6272
# Iteration 2 current model:  ['char', 'word', 'tag']                                                       0.7363
# Iteration 2 current model:  ['char', 'word', 'dep']                                                       0.7208
# Iteration 2 current model:  ['char', 'word', 'pos']                                                       0.7110
# Selected Model: ['char', 'word']
#
# problem00003
# sorted ['char', 'tag', 'word', 'dep', 'dist', 'pos', 'w2v']
# Iteration 1 Best model:     ['char']                                                                      0.8089
# Iteration 1 current model:  ['char', 'word']                                                              0.8719
# Iteration 1 current model:  ['char', 'word', 'tag']                                                       0.7560
# Iteration 1 current model:  ['char', 'word', 'dep']                                                       0.6906
# Iteration 1 current model:  ['char', 'word', 'w2v']                                                       0.5019
# Iteration 1 current model:  ['char', 'word', 'pos']                                                       0.7179
# Iteration 1 current model:  ['char', 'word', 'dist']                                                      0.7662
# Iteration 2 Best model:     ['char', 'word']                                                              0.8719
# Iteration 2 current model:  ['char', 'word', 'w2v']                                                       0.5019
# Iteration 2 current model:  ['char', 'word', 'tag']                                                       0.7560
# Iteration 2 current model:  ['char', 'word', 'dep']                                                       0.6906
# Iteration 2 current model:  ['char', 'word', 'pos']                                                       0.7179
# Selected Model: ['char', 'word']
#
# problem00004
# sorted ['tag', 'pos', 'char', 'dep', 'word', 'dist', 'w2v']
# Iteration 1 Best model:     ['tag']                                                                       0.9179
# Iteration 1 current model:  ['tag', 'word']                                                               0.8255
# Iteration 1 current model:  ['tag', 'dep']                                                                0.9179
# Iteration 1 current model:  ['tag', 'w2v']                                                                0.6889
# Iteration 1 current model:  ['tag', 'pos']                                                                0.8846
# Iteration 1 current model:  ['tag', 'char']                                                               0.8667
# Iteration 1 current model:  ['tag', 'dist']                                                               0.8357
# Selected Model: ['tag']
#
# problem00005
# sorted ['char', 'tag', 'dist', 'pos', 'word', 'dep', 'w2v']
# Iteration 1 Best model:     ['char']                                                                      0.5571
# Iteration 1 current model:  ['char', 'word']                                                              0.6269
# Iteration 1 current model:  ['char', 'word', 'tag']                                                       0.6369
# Iteration 1 current model:  ['char', 'word', 'tag', 'dep']                                                0.6391
# Iteration 1 current model:  ['char', 'word', 'tag', 'w2v']                                                0.6115
# Iteration 1 current model:  ['char', 'word', 'tag', 'pos']                                                0.6153
# Iteration 1 current model:  ['char', 'word', 'tag', 'dist']                                               0.6861
# Iteration 2 Best model:     ['char', 'word', 'tag', 'dist']                                               0.6861
# Iteration 2 current model:  ['char', 'word', 'tag', 'dist', 'w2v']                                        0.6367
# Iteration 2 current model:  ['char', 'word', 'tag', 'dist', 'dep']                                        0.6906
# Iteration 2 current model:  ['char', 'word', 'tag', 'dist', 'pos']                                        0.6818
# Selected Model: ['char', 'word', 'tag', 'dist']
#
# problem00006
# sorted ['char', 'word', 'dist', 'pos', 'tag', 'dep', 'w2v']
# Iteration 1 Best model:     ['char']                                                                      0.6824
# Iteration 1 current model:  ['char', 'word']                                                              0.6398
# Iteration 1 current model:  ['char', 'tag']                                                               0.5922
# Iteration 1 current model:  ['char', 'dep']                                                               0.6629
# Iteration 1 current model:  ['char', 'w2v']                                                               0.4612
# Iteration 1 current model:  ['char', 'pos']                                                               0.5793
# Iteration 1 current model:  ['char', 'dist']                                                              0.6519
# Selected Model: ['char']
#
# problem00007
# sorted ['pos', 'dep', 'char', 'tag', 'word', 'dist', 'w2v']
# Iteration 1 Best model:     ['pos']                                                                       0.6445
# Iteration 1 current model:  ['pos', 'word']                                                               0.7484
# Iteration 1 current model:  ['pos', 'word', 'tag']                                                        0.7143
# Iteration 1 current model:  ['pos', 'word', 'dep']                                                        0.7511
# Iteration 1 current model:  ['pos', 'word', 'w2v']                                                        0.5561
# Iteration 1 current model:  ['pos', 'word', 'char']                                                       0.7298
# Iteration 1 current model:  ['pos', 'word', 'dist']                                                       0.7350
# Iteration 2 Best model:     ['pos', 'word']                                                               0.7484
# Iteration 2 current model:  ['pos', 'word', 'w2v']                                                        0.5561
# Iteration 2 current model:  ['pos', 'word', 'tag']                                                        0.7143
# Iteration 2 current model:  ['pos', 'word', 'dep']                                                        0.7511
# Iteration 2 current model:  ['pos', 'word', 'char']                                                       0.7298
# Selected Model: ['pos', 'word']
#
# problem00008
# sorted ['char', 'word', 'tag', 'pos', 'dist', 'dep', 'w2v']
# Iteration 1 Best model:     ['char']                                                                      0.7074
# Iteration 1 current model:  ['char', 'word']                                                              0.7074
# Iteration 1 current model:  ['char', 'tag']                                                               0.7074
# Iteration 1 current model:  ['char', 'dep']                                                               0.7074
# Iteration 1 current model:  ['char', 'w2v']                                                               0.6361
# Iteration 1 current model:  ['char', 'pos']                                                               0.7074
# Iteration 1 current model:  ['char', 'dist']                                                              0.7074
# Selected Model: ['char']
#
# problem00009
# sorted ['char', 'dist', 'word', 'tag', 'pos', 'dep', 'w2v']
# Iteration 1 Best model:     ['char']                                                                      0.6738
# Iteration 1 current model:  ['char', 'word']                                                              0.6791
# Iteration 1 current model:  ['char', 'tag']                                                               0.6752
# Iteration 1 current model:  ['char', 'dep']                                                               0.6431
# Iteration 1 current model:  ['char', 'w2v']                                                               0.6124
# Iteration 1 current model:  ['char', 'pos']                                                               0.6890
# Iteration 1 current model:  ['char', 'pos', 'dist']                                                       0.6373
# Iteration 2 Best model:     ['char', 'pos']                                                               0.6890
# Iteration 2 current model:  ['char', 'pos', 'w2v']                                                        0.6339
# Iteration 2 current model:  ['char', 'pos', 'tag']                                                        0.6721
# Iteration 2 current model:  ['char', 'pos', 'word']                                                       0.6492
# Iteration 2 current model:  ['char', 'pos', 'dep']                                                        0.6463
# Selected Model: ['char', 'pos']
#
# problem00010
# sorted ['char', 'dist', 'word', 'tag', 'pos', 'dep', 'w2v']
# Iteration 1 Best model:     ['char']                                                                      0.6808
# Iteration 1 current model:  ['char', 'word']                                                              0.6701
# Iteration 1 current model:  ['char', 'tag']                                                               0.6105
# Iteration 1 current model:  ['char', 'dep']                                                               0.6278
# Iteration 1 current model:  ['char', 'w2v']                                                               0.5497
# Iteration 1 current model:  ['char', 'pos']                                                               0.6357
# Iteration 1 current model:  ['char', 'dist']                                                              0.6954
# Iteration 2 Best model:     ['char', 'dist']                                                              0.6954
# Iteration 2 current model:  ['char', 'dist', 'word']                                                      0.7001
# Iteration 2 current model:  ['char', 'dist', 'tag']                                                       0.7016
# Iteration 2 current model:  ['char', 'dist', 'dep']                                                       0.7082
# Iteration 2 current model:  ['char', 'dist', 'dep', 'w2v']                                                0.6754
# Iteration 2 current model:  ['char', 'dist', 'dep', 'pos']                                                0.6705
# Iteration 3 Best model:     ['char', 'dist', 'dep']                                                       0.7082
# Iteration 3 current model:  ['char', 'dist', 'dep', 'w2v']                                                0.6754
# Iteration 3 current model:  ['char', 'dist', 'dep', 'tag']                                                0.6971
# Iteration 3 current model:  ['char', 'dist', 'dep', 'word']                                               0.6869
# Selected Model: ['char', 'dist', 'dep']
#
# problem00011
# sorted ['char', 'dist', 'word', 'tag', 'pos', 'dep', 'w2v']
# Iteration 1 Best model:     ['char']                                                                      0.7775
# Iteration 1 current model:  ['char', 'word']                                                              0.7775
# Iteration 1 current model:  ['char', 'tag']                                                               0.7742
# Iteration 1 current model:  ['char', 'dep']                                                               0.8333
# Iteration 1 current model:  ['char', 'dep', 'w2v']                                                        0.7000
# Iteration 1 current model:  ['char', 'dep', 'pos']                                                        0.8389
# Iteration 1 current model:  ['char', 'dep', 'dist']                                                       0.7933
# Iteration 2 Best model:     ['char', 'dep']                                                               0.8333
# Iteration 2 current model:  ['char', 'dep', 'w2v']                                                        0.7000
# Iteration 2 current model:  ['char', 'dep', 'tag']                                                        0.7175
# Iteration 2 current model:  ['char', 'dep', 'word']                                                       0.8800
# Iteration 2 current model:  ['char', 'dep', 'word', 'pos']                                                0.7889
# Iteration 3 Best model:     ['char', 'dep', 'word']                                                       0.8800
# Iteration 3 current model:  ['char', 'dep', 'word', 'w2v']                                                0.7133
# Iteration 3 current model:  ['char', 'dep', 'word', 'tag']                                                0.7633
# Selected Model: ['char', 'dep', 'word']
#
# problem00012
# sorted ['char', 'word', 'tag', 'dist', 'pos', 'dep', 'w2v']
# Iteration 1 Best model:     ['char']                                                                      0.5378
# Iteration 1 current model:  ['char', 'word']                                                              0.5010
# Iteration 1 current model:  ['char', 'tag']                                                               0.5805
# Iteration 1 current model:  ['char', 'tag', 'dep']                                                        0.5075
# Iteration 1 current model:  ['char', 'tag', 'w2v']                                                        0.4230
# Iteration 1 current model:  ['char', 'tag', 'pos']                                                        0.4639
# Iteration 1 current model:  ['char', 'tag', 'dist']                                                       0.5281
# Iteration 2 Best model:     ['char', 'tag']                                                               0.5805
# Iteration 2 current model:  ['char', 'tag', 'w2v']                                                        0.4230
# Iteration 2 current model:  ['char', 'tag', 'word']                                                       0.5413
# Iteration 2 current model:  ['char', 'tag', 'dep']                                                        0.5075
# Iteration 2 current model:  ['char', 'tag', 'pos']                                                        0.4639
# Selected Model: ['char', 'tag']
#
# problem00013
# sorted ['char', 'word', 'dist', 'w2v']
# Iteration 1 Best model:     ['char']                                                                      0.5174
# Iteration 1 current model:  ['char', 'w2v']                                                               0.5174
# Iteration 1 current model:  ['char', 'word']                                                              0.4591
# Iteration 1 current model:  ['char', 'dist']                                                              0.4245
# Selected Model: ['char']
#
# problem00014
# sorted ['char', 'word', 'dist', 'w2v']
# Iteration 1 Best model:     ['char']                                                                      0.5079
# Iteration 1 current model:  ['char', 'w2v']                                                               0.5079
# Iteration 1 current model:  ['char', 'word']                                                              0.4971
# Iteration 1 current model:  ['char', 'dist']                                                              0.4855
# Selected Model: ['char']
#
# problem00015
# sorted ['word', 'char', 'dist', 'w2v']
# Iteration 1 Best model:     ['word']                                                                      0.3417
# Iteration 1 current model:  ['word', 'w2v']                                                               0.3717
# Iteration 1 current model:  ['word', 'w2v', 'dist']                                                       0.3182
# Iteration 1 current model:  ['word', 'w2v', 'char']                                                       0.4335
# Iteration 2 Best model:     ['word', 'w2v', 'char']                                                       0.4335
# Iteration 2 current model:  ['word', 'w2v', 'char', 'dist']                                               0.3547
# Selected Model: ['word', 'w2v', 'char']
#
# problem00016
# sorted ['word', 'dist', 'char', 'w2v']
# Iteration 1 Best model:     ['word']                                                                      0.4230
# Iteration 1 current model:  ['word', 'w2v']                                                               0.4230
# Iteration 1 current model:  ['word', 'dist']                                                              0.4271
# Iteration 1 current model:  ['word', 'char']                                                              0.4197
# Selected Model: ['word']
#
# problem00017
# sorted ['dist', 'char', 'word', 'pos', 'tag', 'dep', 'w2v']
# Iteration 1 Best model:     ['dist']                                                                      0.7230
# Iteration 1 current model:  ['dist', 'word']                                                              0.7587
# Iteration 1 current model:  ['dist', 'word', 'tag']                                                       0.8043
# Iteration 1 current model:  ['dist', 'word', 'tag', 'dep']                                                0.8207
# Iteration 1 current model:  ['dist', 'word', 'tag', 'dep', 'w2v']                                         0.8425
# Iteration 1 current model:  ['dist', 'word', 'tag', 'dep', 'w2v', 'pos']                                  0.7974
# Iteration 1 current model:  ['dist', 'word', 'tag', 'dep', 'w2v', 'char']                                 0.8119
# Iteration 2 Best model:     ['dist', 'word', 'tag', 'dep', 'w2v']                                         0.8425
# Iteration 2 current model:  ['dist', 'word', 'tag', 'dep', 'w2v', 'pos']                                  0.7974
# Selected Model: ['dist', 'word', 'tag', 'dep', 'w2v']
#
# problem00018
# sorted ['char', 'dist', 'tag', 'word', 'pos', 'dep', 'w2v']
# Iteration 1 Best model:     ['char']                                                                      0.7499
# Iteration 1 current model:  ['char', 'word']                                                              0.7758
# Iteration 1 current model:  ['char', 'word', 'tag']                                                       0.8513
# Iteration 1 current model:  ['char', 'word', 'tag', 'dep']                                                0.9008
# Iteration 1 current model:  ['char', 'word', 'tag', 'dep', 'w2v']                                         0.8813
# Iteration 1 current model:  ['char', 'word', 'tag', 'dep', 'pos']                                         0.8429
# Iteration 1 current model:  ['char', 'word', 'tag', 'dep', 'dist']                                        0.8959
# Iteration 2 Best model:     ['char', 'word', 'tag', 'dep']                                                0.9008
# Iteration 2 current model:  ['char', 'word', 'tag', 'dep', 'w2v']                                         0.8813
# Iteration 2 current model:  ['char', 'word', 'tag', 'dep', 'pos']                                         0.8429
# Selected Model: ['char', 'word', 'tag', 'dep']
#
# problem00019
# sorted ['dist', 'char', 'pos', 'word', 'tag', 'dep', 'w2v']
# Iteration 1 Best model:     ['dist']                                                                      0.7479
# Iteration 1 current model:  ['dist', 'word']                                                              0.8553
# Iteration 1 current model:  ['dist', 'word', 'tag']                                                       0.8380
# Iteration 1 current model:  ['dist', 'word', 'dep']                                                       0.9019
# Iteration 1 current model:  ['dist', 'word', 'dep', 'w2v']                                                0.9109
# Iteration 1 current model:  ['dist', 'word', 'dep', 'pos']                                                0.8519
# Iteration 1 current model:  ['dist', 'word', 'dep', 'char']                                               0.8109
# Iteration 2 Best model:     ['dist', 'word', 'dep']                                                       0.9019
# Iteration 2 current model:  ['dist', 'word', 'dep', 'w2v']                                                0.9109
# Iteration 2 current model:  ['dist', 'word', 'dep', 'tag']                                                0.8462
# Iteration 2 current model:  ['dist', 'word', 'dep', 'pos']                                                0.8519
# Selected Model: ['dist', 'word', 'dep']
#
# problem00020
# sorted ['pos', 'dist', 'dep', 'tag', 'char', 'word', 'w2v']
# Iteration 1 Best model:     ['pos']                                                                       0.9143
# Iteration 1 current model:  ['pos', 'word']                                                               0.9332
# Iteration 1 current model:  ['pos', 'word', 'tag']                                                        0.9332
# Iteration 1 current model:  ['pos', 'word', 'dep']                                                        0.9143
# Iteration 1 current model:  ['pos', 'word', 'w2v']                                                        0.9332
# Iteration 1 current model:  ['pos', 'word', 'char']                                                       0.8788
# Iteration 1 current model:  ['pos', 'word', 'dist']                                                       0.9143
# Iteration 2 Best model:     ['pos', 'word']                                                               0.9332
# Iteration 2 current model:  ['pos', 'word', 'w2v']                                                        0.9332
# Iteration 2 current model:  ['pos', 'word', 'tag']                                                        0.9332
# Iteration 2 current model:  ['pos', 'word', 'dep']                                                        0.9143
# Iteration 2 current model:  ['pos', 'word', 'char']                                                       0.8788
# Selected Model: ['pos', 'word']

# %%
pd.concat([dfMetric, pd.DataFrame(resultFinal)]).fillna(value=0) \
    .pivot(index='problem',columns='model',values=['f1','accuracy']).fillna(0)\
    .style.background_gradient(subset=['f1'], axis=1, cmap=plt.cm.Blues)\
    .background_gradient(subset=['accuracy'], axis=1, cmap=plt.cm.Greens)\
    .format('{:,.2f}'.format)
# Out:
# <style  type="text/css" >
# #T_49aafb5c_193a_11eb_87ba_0242ac1c0002row0_col0,#T_49aafb5c_193a_11eb_87ba_0242ac1c0002row0_col1,#T_49aafb5c_193a_11eb_87ba_0242ac1c0002row1_col0,#T_49aafb5c_193a_11eb_87ba_0242ac1c0002row2_col0,#T_49aafb5c_193a_11eb_87ba_0242ac1c0002row3_col0,#T_49aafb5c_193a_11eb_87ba_0242ac1c0002row3_col5,#T_49aafb5c_193a_11eb_87ba_0242ac1c0002row4_col0,#T_49aafb5c_193a_11eb_87ba_0242ac1c0002row5_col0,#T_49aafb5c_193a_11eb_87ba_0242ac1c0002row5_col1,#T_49aafb5c_193a_11eb_87ba_0242ac1c0002row6_col0,#T_49aafb5c_193a_11eb_87ba_0242ac1c0002row7_col0,#T_49aafb5c_193a_11eb_87ba_0242ac1c0002row7_col1,#T_49aafb5c_193a_11eb_87ba_0242ac1c0002row8_col0,#T_49aafb5c_193a_11eb_87ba_0242ac1c0002row9_col0,#T_49aafb5c_193a_11eb_87ba_0242ac1c0002row10_col0,#T_49aafb5c_193a_11eb_87ba_0242ac1c0002row11_col0,#T_49aafb5c_193a_11eb_87ba_0242ac1c0002row12_col0,#T_49aafb5c_193a_11eb_87ba_0242ac1c0002row12_col1,#T_49aafb5c_193a_11eb_87ba_0242ac1c0002row13_col1,#T_49aafb5c_193a_11eb_87ba_0242ac1c0002row14_col0,#T_49aafb5c_193a_11eb_87ba_0242ac1c0002row15_col0,#T_49aafb5c_193a_11eb_87ba_0242ac1c0002row15_col7,#T_49aafb5c_193a_11eb_87ba_0242ac1c0002row16_col0,#T_49aafb5c_193a_11eb_87ba_0242ac1c0002row17_col0,#T_49aafb5c_193a_11eb_87ba_0242ac1c0002row18_col0,#T_49aafb5c_193a_11eb_87ba_0242ac1c0002row19_col0{
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }#T_49aafb5c_193a_11eb_87ba_0242ac1c0002row0_col2,#T_49aafb5c_193a_11eb_87ba_0242ac1c0002row1_col3{
#             background-color:  #d0e2f2;
#             color:  #000000;
#         }#T_49aafb5c_193a_11eb_87ba_0242ac1c0002row0_col3{
#             background-color:  #ccdff1;
#             color:  #000000;
#         }#T_49aafb5c_193a_11eb_87ba_0242ac1c0002row0_col4,#T_49aafb5c_193a_11eb_87ba_0242ac1c0002row13_col6{
#             background-color:  #bfd8ed;
#             color:  #000000;
#         }#T_49aafb5c_193a_11eb_87ba_0242ac1c0002row0_col5{
#             background-color:  #a8cee4;
#             color:  #000000;
#         }#T_49aafb5c_193a_11eb_87ba_0242ac1c0002row0_col6,#T_49aafb5c_193a_11eb_87ba_0242ac1c0002row1_col2,#T_49aafb5c_193a_11eb_87ba_0242ac1c0002row2_col6,#T_49aafb5c_193a_11eb_87ba_0242ac1c0002row3_col6,#T_49aafb5c_193a_11eb_87ba_0242ac1c0002row4_col6,#T_49aafb5c_193a_11eb_87ba_0242ac1c0002row5_col6,#T_49aafb5c_193a_11eb_87ba_0242ac1c0002row6_col6,#T_49aafb5c_193a_11eb_87ba_0242ac1c0002row7_col6,#T_49aafb5c_193a_11eb_87ba_0242ac1c0002row8_col6,#T_49aafb5c_193a_11eb_87ba_0242ac1c0002row9_col6,#T_49aafb5c_193a_11eb_87ba_0242ac1c0002row10_col6,#T_49aafb5c_193a_11eb_87ba_0242ac1c0002row11_col6,#T_49aafb5c_193a_11eb_87ba_0242ac1c0002row12_col2,#T_49aafb5c_193a_11eb_87ba_0242ac1c0002row12_col4,#T_49aafb5c_193a_11eb_87ba_0242ac1c0002row12_col5,#T_49aafb5c_193a_11eb_87ba_0242ac1c0002row13_col2,#T_49aafb5c_193a_11eb_87ba_0242ac1c0002row13_col4,#T_49aafb5c_193a_11eb_87ba_0242ac1c0002row13_col5,#T_49aafb5c_193a_11eb_87ba_0242ac1c0002row14_col2,#T_49aafb5c_193a_11eb_87ba_0242ac1c0002row14_col4,#T_49aafb5c_193a_11eb_87ba_0242ac1c0002row14_col5,#T_49aafb5c_193a_11eb_87ba_0242ac1c0002row15_col2,#T_49aafb5c_193a_11eb_87ba_0242ac1c0002row15_col4,#T_49aafb5c_193a_11eb_87ba_0242ac1c0002row15_col5,#T_49aafb5c_193a_11eb_87ba_0242ac1c0002row16_col6,#T_49aafb5c_193a_11eb_87ba_0242ac1c0002row17_col6,#T_49aafb5c_193a_11eb_87ba_0242ac1c0002row18_col6,#T_49aafb5c_193a_11eb_87ba_0242ac1c0002row19_col6{
#             background-color:  #f7fbff;
#             color:  #000000;
#         }#T_49aafb5c_193a_11eb_87ba_0242ac1c0002row0_col7,#T_49aafb5c_193a_11eb_87ba_0242ac1c0002row18_col7{
#             background-color:  #6caed6;
#             color:  #000000;
#         }#T_49aafb5c_193a_11eb_87ba_0242ac1c0002row0_col8,#T_49aafb5c_193a_11eb_87ba_0242ac1c0002row0_col9,#T_49aafb5c_193a_11eb_87ba_0242ac1c0002row1_col8,#T_49aafb5c_193a_11eb_87ba_0242ac1c0002row1_col9,#T_49aafb5c_193a_11eb_87ba_0242ac1c0002row2_col8,#T_49aafb5c_193a_11eb_87ba_0242ac1c0002row2_col9,#T_49aafb5c_193a_11eb_87ba_0242ac1c0002row3_col8,#T_49aafb5c_193a_11eb_87ba_0242ac1c0002row3_col13,#T_49aafb5c_193a_11eb_87ba_0242ac1c0002row4_col8,#T_49aafb5c_193a_11eb_87ba_0242ac1c0002row5_col8,#T_49aafb5c_193a_11eb_87ba_0242ac1c0002row5_col9,#T_49aafb5c_193a_11eb_87ba_0242ac1c0002row6_col8,#T_49aafb5c_193a_11eb_87ba_0242ac1c0002row6_col9,#T_49aafb5c_193a_11eb_87ba_0242ac1c0002row7_col8,#T_49aafb5c_193a_11eb_87ba_0242ac1c0002row7_col9,#T_49aafb5c_193a_11eb_87ba_0242ac1c0002row8_col8,#T_49aafb5c_193a_11eb_87ba_0242ac1c0002row8_col9,#T_49aafb5c_193a_11eb_87ba_0242ac1c0002row9_col8,#T_49aafb5c_193a_11eb_87ba_0242ac1c0002row10_col8,#T_49aafb5c_193a_11eb_87ba_0242ac1c0002row11_col9,#T_49aafb5c_193a_11eb_87ba_0242ac1c0002row12_col8,#T_49aafb5c_193a_11eb_87ba_0242ac1c0002row12_col9,#T_49aafb5c_193a_11eb_87ba_0242ac1c0002row13_col9,#T_49aafb5c_193a_11eb_87ba_0242ac1c0002row14_col8,#T_49aafb5c_193a_11eb_87ba_0242ac1c0002row15_col9,#T_49aafb5c_193a_11eb_87ba_0242ac1c0002row16_col8,#T_49aafb5c_193a_11eb_87ba_0242ac1c0002row17_col8,#T_49aafb5c_193a_11eb_87ba_0242ac1c0002row18_col8,#T_49aafb5c_193a_11eb_87ba_0242ac1c0002row19_col8{
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }#T_49aafb5c_193a_11eb_87ba_0242ac1c0002row0_col10,#T_49aafb5c_193a_11eb_87ba_0242ac1c0002row0_col11{
#             background-color:  #c9eac2;
#             color:  #000000;
#         }#T_49aafb5c_193a_11eb_87ba_0242ac1c0002row0_col12{
#             background-color:  #90d18d;
#             color:  #000000;
#         }#T_49aafb5c_193a_11eb_87ba_0242ac1c0002row0_col13{
#             background-color:  #62bb6d;
#             color:  #000000;
#         }#T_49aafb5c_193a_11eb_87ba_0242ac1c0002row0_col14,#T_49aafb5c_193a_11eb_87ba_0242ac1c0002row1_col14,#T_49aafb5c_193a_11eb_87ba_0242ac1c0002row2_col14,#T_49aafb5c_193a_11eb_87ba_0242ac1c0002row3_col11,#T_49aafb5c_193a_11eb_87ba_0242ac1c0002row3_col14,#T_49aafb5c_193a_11eb_87ba_0242ac1c0002row4_col14,#T_49aafb5c_193a_11eb_87ba_0242ac1c0002row5_col14,#T_49aafb5c_193a_11eb_87ba_0242ac1c0002row6_col14,#T_49aafb5c_193a_11eb_87ba_0242ac1c0002row7_col14,#T_49aafb5c_193a_11eb_87ba_0242ac1c0002row8_col14,#T_49aafb5c_193a_11eb_87ba_0242ac1c0002row9_col14,#T_49aafb5c_193a_11eb_87ba_0242ac1c0002row10_col10,#T_49aafb5c_193a_11eb_87ba_0242ac1c0002row11_col14,#T_49aafb5c_193a_11eb_87ba_0242ac1c0002row12_col10,#T_49aafb5c_193a_11eb_87ba_0242ac1c0002row12_col12,#T_49aafb5c_193a_11eb_87ba_0242ac1c0002row12_col13,#T_49aafb5c_193a_11eb_87ba_0242ac1c0002row13_col10,#T_49aafb5c_193a_11eb_87ba_0242ac1c0002row13_col12,#T_49aafb5c_193a_11eb_87ba_0242ac1c0002row13_col13,#T_49aafb5c_193a_11eb_87ba_0242ac1c0002row14_col10,#T_49aafb5c_193a_11eb_87ba_0242ac1c0002row14_col12,#T_49aafb5c_193a_11eb_87ba_0242ac1c0002row14_col13,#T_49aafb5c_193a_11eb_87ba_0242ac1c0002row15_col10,#T_49aafb5c_193a_11eb_87ba_0242ac1c0002row15_col12,#T_49aafb5c_193a_11eb_87ba_0242ac1c0002row15_col13,#T_49aafb5c_193a_11eb_87ba_0242ac1c0002row16_col14,#T_49aafb5c_193a_11eb_87ba_0242ac1c0002row17_col14,#T_49aafb5c_193a_11eb_87ba_0242ac1c0002row18_col14,#T_49aafb5c_193a_11eb_87ba_0242ac1c0002row19_col14{
#             background-color:  #f7fcf5;
#             color:  #000000;
#         }#T_49aafb5c_193a_11eb_87ba_0242ac1c0002row0_col15{
#             background-color:  #3ea75a;
#             color:  #000000;
#         }#T_49aafb5c_193a_11eb_87ba_0242ac1c0002row1_col1{
#             background-color:  #084082;
#             color:  #f1f1f1;
#         }#T_49aafb5c_193a_11eb_87ba_0242ac1c0002row1_col4{
#             background-color:  #cfe1f2;
#             color:  #000000;
#         }#T_49aafb5c_193a_11eb_87ba_0242ac1c0002row1_col5,#T_49aafb5c_193a_11eb_87ba_0242ac1c0002row2_col5{
#             background-color:  #3f8fc5;
#             color:  #000000;
#         }#T_49aafb5c_193a_11eb_87ba_0242ac1c0002row1_col6{
#             background-color:  #e3eef9;
#             color:  #000000;
#         }#T_49aafb5c_193a_11eb_87ba_0242ac1c0002row1_col7,#T_49aafb5c_193a_11eb_87ba_0242ac1c0002row17_col5{
#             background-color:  #3e8ec4;
#             color:  #0000

# %% [markdown]
# ### Latex version

# %%
print(pd.concat([dfMetric, pd.DataFrame(resultFinal)]).fillna(value=0) \
    .pivot(index='problem',columns='model',values='f1').reset_index()\
    .fillna(0).to_latex(index=False, float_format='{:,.2f}'.format))
# Out:
# \begin{tabular}{lrrrrrrrr}
# \toprule
#       problem &  0ensemble &  char &  dep &  dist &  pos &  tag &  w2v &  word \\
# \midrule
#  problem00001 &       0.76 &  0.76 & 0.42 &  0.43 & 0.45 & 0.48 & 0.34 &  0.55 \\
#  problem00002 &       0.74 &  0.73 & 0.43 &  0.49 & 0.49 & 0.63 & 0.46 &  0.63 \\
#  problem00003 &       0.87 &  0.81 & 0.63 &  0.55 & 0.53 & 0.69 & 0.39 &  0.65 \\
#  problem00004 &       0.92 &  0.83 & 0.71 &  0.54 & 0.89 & 0.92 & 0.43 &  0.64 \\
#  problem00005 &       0.69 &  0.56 & 0.33 &  0.47 & 0.52 & 0.51 & 0.11 &  0.46 \\
#  problem00006 &       0.68 &  0.68 & 0.30 &  0.47 & 0.46 & 0.44 & 0.12 &  0.46 \\
#  problem00007 &       0.73 &  0.61 & 0.63 &  0.50 & 0.65 & 0.59 & 0.18 &  0.56 \\
#  problem00008 &       0.71 &  0.71 & 0.35 &  0.57 & 0.60 & 0.61 & 0.13 &  0.65 \\
#  problem00009 &       0.69 &  0.67 & 0.30 &  0.56 & 0.36 & 0.40 & 0.25 &  0.50 \\
#  problem00010 &       0.71 &  0.68 & 0.34 &  0.59 & 0.34 & 0.41 & 0.28 &  0.48 \\
#  problem00011 &       0.88 &  0.78 & 0.40 &  0.72 & 0.51 & 0.62 & 0.38 &  0.71 \\
#  problem00012 &       0.58 &  0.54 & 0.23 &  0.49 & 0.32 & 0.42 & 0.20 &  0.45 \\
#  problem00013 &       0.52 &  0.52 & 0.00 &  0.36 & 0.00 & 0.00 & 0.12 &  0.39 \\
#  problem00014 &       0.50 &  0.51 & 0.00 &  0.34 & 0.00 & 0.00 & 0.14 &  0.34 \\
#  problem00015 &       0.43 &  0.34 & 0.00 &  0.28 & 0.00 & 0.00 & 0.33 &  0.34 \\
#  problem00016 &       0.42 &  0.38 & 0.00 &  0.38 & 0.00 & 0.00 & 0.26 &  0.42 \\
#  problem00017 &       0.84 &  0.65 & 0.46 &  0.68 & 0.54 & 0.52 & 0.17 &  0.56 \\
#  problem00018 &       0.88 &  0.75 & 0.54 &  0.70 & 0.57 & 0.64 & 0.21 &  0.63 \\
#  problem00019 &       0.90 &  0.71 & 0.49 &  0.74 & 0.67 & 0.60 & 0.39 &  0.64 \\
#  problem00020 &       0.93 &  0.68 & 0.87 &  0.90 & 0.91 & 0.82 & 0.15 &  0.65 \\
# \bottomrule
# \end{tabular}

# %%
# mean by model
print(pd.concat([dfMetric, pd.DataFrame(resultFinal)]).fillna(value=0) \
    .pivot(index='problem',columns='model',values='f1').reset_index().mean().to_frame().T\
     .to_latex(index=False, float_format='{:,.2f}'.format))
# Out:
# \begin{tabular}{rrrrrrrr}
# \toprule
#  0ensemble &  char &  dep &  dist &  pos &  tag &  w2v &  word \\
# \midrule
#       0.72 &  0.64 & 0.37 &  0.54 & 0.44 & 0.46 & 0.25 &  0.54 \\
# \bottomrule
# \end{tabular}

# %%
for problemIndex, problem in enumerate(df['problem'].unique()):
    lang = df.query(f"problem == '{problem}'")['language'].unique()[0]
    print(problem +' '+lang+' '+ str(bestModels[problemIndex]))
# Out:
# problem00001 en ['char']
# problem00002 en ['char', 'word']
# problem00003 en ['char', 'word']
# problem00004 en ['tag']
# problem00005 fr ['char', 'word', 'tag', 'dist']
# problem00006 fr ['char']
# problem00007 fr ['pos', 'word']
# problem00008 fr ['char']
# problem00009 it ['char', 'pos']
# problem00010 it ['char', 'dist', 'dep']
# problem00011 it ['char', 'dep', 'word']
# problem00012 it ['char', 'tag']
# problem00013 pl ['char']
# problem00014 pl ['char']
# problem00015 pl ['word', 'w2v', 'char']
# problem00016 pl ['word']
# problem00017 sp ['dist', 'word', 'tag', 'dep', 'w2v']
# problem00018 sp ['char', 'word', 'tag', 'dep']
# problem00019 sp ['dist', 'word', 'dep']
# problem00020 sp ['pos', 'word']

# %%
pd.pivot_table(
    pd.concat([dfMetric, pd.DataFrame(resultFinal)]),
    index='model',
    columns='n_authors',
    values='f1',
    aggfunc='mean',
    fill_value=0).T
# Out:
# model      0ensemble   char    dep   dist    pos    tag    w2v   word
# n_authors
# 0             0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000 0.0000
# 5             0.7122 0.6256 0.5410 0.5734 0.6788 0.6923 0.2348 0.5614
# 10            0.7634 0.6494 0.5385 0.5600 0.5875 0.6255 0.3326 0.5798
# 15            0.7020 0.6692 0.4017 0.5190 0.4657 0.5285 0.2428 0.5088
# 20            0.6974 0.6308 0.3775 0.5010 0.4675 0.4765 0.1976 0.4910

# %%
pd.pivot_table(
    pd.concat([dfMetric, pd.DataFrame(resultFinal)]),
    index='model',
    columns='language',
    values='f1',
    aggfunc='mean',
    fill_value=0)
# Out:
# language      en     fr     it     pl     sp
# model
# 0ensemble 0.8227 0.7015 0.7133 0.4682 0.8880
# char      0.7802 0.6385 0.6678 0.4353 0.6970
# dep       0.5487 0.4022 0.3183 0.0000 0.5895
# dist      0.5032 0.5022 0.5930 0.3393 0.7540
# pos       0.5910 0.5555 0.3795 0.0000 0.6735
# tag       0.6813 0.5368 0.4612 0.0000 0.6435
# w2v       0.4055 0.1352 0.2755 0.2115 0.2320
# word      0.6150 0.5312 0.5345 0.3745 0.6210

# %%
pd.pivot_table(
    pd.concat([dfMetric, pd.DataFrame(resultFinal)]),
    index='model',
    columns=['language','n_authors'],
    values='f1',
    aggfunc='mean',
    fill_value=0)
# Out:
# language      en                          fr  ...     pl     sp
# n_authors     5      10     15     20     5   ...     20     5      10     15     20
# model                                         ...
# 0ensemble 0.9180 0.8720 0.7450 0.7560 0.7070  ... 0.5170 0.9330 0.9020 0.8760 0.8410
# char      0.8300 0.8090 0.7260 0.7560 0.7070  ... 0.5170 0.6770 0.7110 0.7500 0.6500
# dep       0.7090 0.6340 0.4310 0.4210 0.3540  ... 0.0000 0.8710 0.4880 0.5360 0.4630
# dist      0.5360 0.5530 0.4930 0.4310 0.5680  ... 0.3640 0.8960 0.7420 0.7020 0.6760
# pos       0.8850 0.5330 0.4950 0.4510 0.5980  ... 0.0000 0.9140 0.6660 0.5740 0.5400
# tag       0.9180 0.6950 0.6300 0.4820 0.6110  ... 0.0000 0.8210 0.5990 0.6370 0.5170
# w2v       0.4350 0.3870 0.4620 0.3380 0.1330  ... 0.1180 0.1500 0.3900 0.2140 0.1740
# word      0.6360 0.6460 0.6320 0.5460 0.6490  ... 0.3880 0.6530 0.6440 0.6270 0.5600
#
# [8 rows x 21 columns]

# %%
pd.pivot_table(
    pd.concat([ pd.DataFrame(resultFinal)]),
    index='model',
    columns=['language','n_authors'],
    values='f1',
    aggfunc='mean',
    fill_value=0)
# Out:
# language      en                          fr  ...     pl     sp
# n_authors     5      10     15     20     5   ...     20     5      10     15     20
# model                                         ...
# 0ensemble 0.9180 0.8720 0.7450 0.7560 0.7070  ... 0.5170 0.9330 0.9020 0.8760 0.8410
#
# [1 rows x 20 columns]

# %%
pd.DataFrame(predictions).round(5).sort_values('row_index')
# Out:
#          dataset       problem  ... candidate00019  candidate00020
# 0     pan18_eval  problem00001  ...         0.0000          0.0000
# 1     pan18_eval  problem00001  ...         0.0000          0.0000
# 2     pan18_eval  problem00001  ...         0.0000          0.0000
# 3     pan18_eval  problem00001  ...         0.0000          0.0000
# 4     pan18_eval  problem00001  ...         0.0000          0.0000
# ...          ...           ...  ...            ...             ...
# 3060  pan18_eval  problem00020  ...            nan             nan
# 3061  pan18_eval  problem00020  ...            nan             nan
# 3062  pan18_eval  problem00020  ...            nan             nan
# 3063  pan18_eval  problem00020  ...            nan             nan
# 3064  pan18_eval  problem00020  ...            nan             nan
#
# [3065 rows x 25 columns]

# %% [markdown]
# ## Saving data

# %%
import pickle;
with open(pathjoin(outputDir,f'{currentCorpus}_parcial.pkl'),"wb") as f:
    pickle.dump(results,f)


pd.DataFrame(predictions)\
    .rename(columns={'index':'row_index'}).sort_values('row_index').round(5)\
    .to_csv(pathjoin(outputDir,currentCorpus+'_predictions.csv.zip'), index=False, compression='zip', encoding='utf-8')

# %%
def resultsToTable(results):
    temp = []
    def unfold(r, var):
        return [i for j in r[var] for i in j]
    for model in results:
        r = results[model];
        t = {
            'row_index': unfold(r,'index_train') +unfold(r,'index_test'),
            'pred': unfold(r,'pred_train') +unfold(r,'pred_test')
            
        }
        t['model'] = [model] * len(t['row_index'])
        t['dataset'] = [currentCorpus] * len(t['row_index'])
        
        temp.append(t)

    
    return pd.concat([pd.DataFrame(d) for d in temp]);
        

resultsToTable(results) \
    .merge(datasets[['row_index','problem']], on='row_index', how='left')\
    .to_csv(pathjoin(outputDir,currentCorpus+'_predictions_parcial.csv.zip'), index=False, compression='zip', encoding='utf-8')
