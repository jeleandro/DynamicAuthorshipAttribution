# %% [markdown]
# # AA social

# %%
# %matplotlib inline

# %%
#python basic libs
import os;
from os.path import join as pathjoin;
import re;
import random;
import json;
from collections import defaultdict;
from pprint import pprint
from time import time

# %%
#data analysis libs
import numpy as np;
import pandas as pd;
import seaborn as sns;
import matplotlib.pyplot as plt;

# %%
#machine learning libs
#feature extraction
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn import feature_selection;

#preprocessing and transformation
from sklearn import preprocessing;
from sklearn.preprocessing import MaxAbsScaler;
from sklearn.decomposition import PCA;

from sklearn.base import BaseEstimator, ClassifierMixin

#classifiers
from sklearn.linear_model import LogisticRegression

#
from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import Pipeline

#model valuation
from sklearn.metrics import f1_score, precision_score, recall_score, accuracy_score;

# %% [markdown]
# NLP libraries

# %%
# !pip install spacy=='2.3' gensim
# Out:
# Collecting spacy==2.3
#   Downloading https://files.pythonhosted.org/packages/31/c7/e66e2af1cfa418c3a3917c116c4e00ccffa546f18f59e6acd7953d833c5c/spacy-2.3.0-cp36-cp36m-manylinux1_x86_64.whl (10.0MB)
#      |████████████████████████████████| 10.0MB 2.8MB/s
# Requirement already satisfied: gensim in /usr/local/lib/python3.6/dist-packages (3.6.0)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy==2.3) (1.0.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.6/dist-packages (from spacy==2.3) (2.23.0)
# Collecting thinc==7.4.1
#   Downloading https://files.pythonhosted.org/packages/10/ae/ef3ae5e93639c0ef8e3eb32e3c18341e511b3c515fcfc603f4b808087651/thinc-7.4.1-cp36-cp36m-manylinux1_x86_64.whl (2.1MB)
#      |████████████████████████████████| 2.1MB 34.0MB/s
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from spacy==2.3) (0.8.0)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /usr/local/lib/python3.6/dist-packages (from spacy==2.3) (1.0.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.6/dist-packages (from spacy==2.3) (4.41.1)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.6/dist-packages (from spacy==2.3) (1.0.2)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from spacy==2.3) (0.4.1)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy==2.3) (3.0.2)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /usr/local/lib/python3.6/dist-packages (from spacy==2.3) (1.1.3)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy==2.3) (2.0.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from spacy==2.3) (50.3.0)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.6/dist-packages (from spacy==2.3) (1.18.5)
# Requirement already satisfied: smart-open>=1.2.1 in /usr/local/lib/python3.6/dist-packages (from gensim) (3.0.0)
# Requirement already satisfied: scipy>=0.18.1 in /usr/local/lib/python3.6/dist-packages (from gensim) (1.4.1)
# Requirement already satisfied: six>=1.5.0 in /usr/local/lib/python3.6/dist-packages (from gensim) (1.15.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy==2.3) (2020.6.20)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy==2.3) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy==2.3) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy==2.3) (1.24.3)
# Requirement already satisfied: importlib-metadata>=0.20; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from catalogue<1.1.0,>=0.0.7->spacy==2.3) (2.0.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata>=0.20; python_version < "3.8"->catalogue<1.1.0,>=0.0.7->spacy==2.3) (3.3.1)
# Installing collected packages: thinc, spacy
#   Found existing installation: thinc 7.4.0
#     Uninstalling thinc-7.4.0:
#       Successfully uninstalled thinc-7.4.0
#   Found existing installation: spacy 2.2.4
#     Uninstalling spacy-2.2.4:
#       Successfully uninstalled spacy-2.2.4
# Successfully installed spacy-2.3.0 thinc-7.4.1

# %%
# !python -m spacy download pt  
# !python -m spacy download es
# !python -m spacy download it
# !python -m spacy download en
# !python -m spacy download fr
# Out:
# Collecting pt_core_news_sm==2.3.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/pt_core_news_sm-2.3.0/pt_core_news_sm-2.3.0.tar.gz (19.6MB)
#      |████████████████████████████████| 19.6MB 827kB/s
# Requirement already satisfied: spacy<2.4.0,>=2.3.0 in /usr/local/lib/python3.6/dist-packages (from pt_core_news_sm==2.3.0) (2.3.0)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->pt_core_news_sm==2.3.0) (1.1.3)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->pt_core_news_sm==2.3.0) (1.18.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->pt_core_news_sm==2.3.0) (2.23.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->pt_core_news_sm==2.3.0) (3.0.2)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->pt_core_news_sm==2.3.0) (1.0.2)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->pt_core_news_sm==2.3.0) (1.0.0)
# Requirement already satisfied: thinc==7.4.1 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->pt_core_news_sm==2.3.0) (7.4.1)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->pt_core_news_sm==2.3.0) (2.0.3)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->pt_core_news_sm==2.3.0) (4.41.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->pt_core_news_sm==2.3.0) (50.3.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->pt_core_news_sm==2.3.0) (1.0.2)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->pt_core_news_sm==2.3.0) (0.4.1)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->pt_core_news_sm==2.3.0) (0.8.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0,>=2.3.0->pt_core_news_sm==2.3.0) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0,>=2.3.0->pt_core_news_sm==2.3.0) (2020.6.20)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0,>=2.3.0->pt_core_news_sm==2.3.0) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0,>=2.3.0->pt_core_news_sm==2.3.0) (2.10)
# Requirement already satisfied: importlib-metadata>=0.20; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from catalogue<1.1.0,>=0.0.7->spacy<2.4.0,>=2.3.0->pt_core_news_sm==2.3.0) (2.0.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata>=0.20; python_version < "3.8"->catalogue<1.1.0,>=0.0.7->spacy<2.4.0,>=2.3.0->pt_core_news_sm==2.3.0) (3.3.1)
# Building wheels for collected packages: pt-core-news-sm
#   Building wheel for pt-core-news-sm (setup.py) ... done
#   Created wheel for pt-core-news-sm: filename=pt_core_news_sm-2.3.0-cp36-none-any.whl size=19557499 sha256=a35629e99a8efd484cc664e0c90b403fbfacb86425728930edfedf82d15c17ff
#   Stored in directory: /tmp/pip-ephem-wheel-cache-7t2dyuk4/wheels/f6/43/f6/949b5e2b48df37aa3ed81fc3f4af4154afa276518cc004b990
# Successfully built pt-core-news-sm
# Installing collected packages: pt-core-news-sm
# Successfully installed pt-core-news-sm-2.3.0
# ✔ Download and installation successful
# You can now load the model via spacy.load('pt_core_news_sm')
# ✔ Linking successful
# /usr/local/lib/python3.6/dist-packages/pt_core_news_sm -->
# /usr/local/lib/python3.6/dist-packages/spacy/data/pt
# You can now load the model via spacy.load('pt')
# Collecting es_core_news_sm==2.3.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/es_core_news_sm-2.3.1/es_core_news_sm-2.3.1.tar.gz (16.2MB)
#      |████████████████████████████████| 16.2MB 661kB/s
# Requirement already satisfied: spacy<2.4.0,>=2.3.0 in /usr/local/lib/python3.6/dist-packages (from es_core_news_sm==2.3.1) (2.3.0)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->es_core_news_sm==2.3.1) (1.18.5)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->es_core_news_sm==2.3.1) (50.3.0)
# Requirement already satisfied: thinc==7.4.1 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->es_core_news_sm==2.3.1) (7.4.1)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->es_core_news_sm==2.3.1) (2.0.3)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->es_core_news_sm==2.3.1) (0.4.1)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->es_core_news_sm==2.3.1) (3.0.2)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->es_core_news_sm==2.3.1) (4.41.1)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->es_core_news_sm==2.3.1) (1.0.0)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->es_core_news_sm==2.3.1) (1.0.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->es_core_news_sm==2.3.1) (2.23.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->es_core_news_sm==2.3.1) (1.0.2)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->es_core_news_sm==2.3.1) (0.8.0)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->es_core_news_sm==2.3.1) (1.1.3)
# Requirement already satisfied: importlib-metadata>=0.20; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from catalogue<1.1.0,>=0.0.7->spacy<2.4.0,>=2.3.0->es_core_news_sm==2.3.1) (2.0.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0,>=2.3.0->es_core_news_sm==2.3.1) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0,>=2.3.0->es_core_news_sm==2.3.1) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0,>=2.3.0->es_core_news_sm==2.3.1) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0,>=2.3.0->es_core_news_sm==2.3.1) (2020.6.20)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata>=0.20; python_version < "3.8"->catalogue<1.1.0,>=0.0.7->spacy<2.4.0,>=2.3.0->es_core_news_sm==2.3.1) (3.3.1)
# Building wheels for collected packages: es-core-news-sm
#   Building wheel for es-core-news-sm (setup.py) ... done
#   Created wheel for es-core-news-sm: filename=es_core_news_sm-2.3.1-cp36-none-any.whl size=16217000 sha256=2bbbf3774d9c0eb765b7b380624f2514b93fd768534e00e83cb3f45826d8932c
#   Stored in directory: /tmp/pip-ephem-wheel-cache-gnih_42u/wheels/75/be/34/88bac54b4d3f462835c1802813139afc469f01a6540d7bdc51
# Successfully built es-core-news-sm
# Installing collected packages: es-core-news-sm
# Successfully installed es-core-news-sm-2.3.1
# ✔ Download and installation successful
# You can now load the model via spacy.load('es_core_news_sm')
# ✔ Linking successful
# /usr/local/lib/python3.6/dist-packages/es_core_news_sm -->
# /usr/local/lib/python3.6/dist-packages/spacy/data/es
# You can now load the model via spacy.load('es')
# Collecting it_core_news_sm==2.3.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/it_core_news_sm-2.3.0/it_core_news_sm-2.3.0.tar.gz (14.5MB)
#      |████████████████████████████████| 14.5MB 714kB/s
# Requirement already satisfied: spacy<2.4.0,>=2.3.0 in /usr/local/lib/python3.6/dist-packages (from it_core_news_sm==2.3.0) (2.3.0)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->it_core_news_sm==2.3.0) (0.4.1)
# Requirement already satisfied: thinc==7.4.1 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->it_core_news_sm==2.3.0) (7.4.1)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->it_core_news_sm==2.3.0) (3.0.2)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->it_core_news_sm==2.3.0) (1.0.2)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->it_core_news_sm==2.3.0) (1.0.2)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->it_core_news_sm==2.3.0) (1.0.0)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->it_core_news_sm==2.3.0) (1.18.5)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->it_core_news_sm==2.3.0) (4.41.1)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->it_core_news_sm==2.3.0) (1.1.3)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->it_core_news_sm==2.3.0) (2.0.3)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->it_core_news_sm==2.3.0) (0.8.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->it_core_news_sm==2.3.0) (50.3.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->it_core_news_sm==2.3.0) (2.23.0)
# Requirement already satisfied: importlib-metadata>=0.20; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from catalogue<1.1.0,>=0.0.7->spacy<2.4.0,>=2.3.0->it_core_news_sm==2.3.0) (2.0.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0,>=2.3.0->it_core_news_sm==2.3.0) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0,>=2.3.0->it_core_news_sm==2.3.0) (2020.6.20)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0,>=2.3.0->it_core_news_sm==2.3.0) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0,>=2.3.0->it_core_news_sm==2.3.0) (1.24.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata>=0.20; python_version < "3.8"->catalogue<1.1.0,>=0.0.7->spacy<2.4.0,>=2.3.0->it_core_news_sm==2.3.0) (3.3.1)
# Building wheels for collected packages: it-core-news-sm
#   Building wheel for it-core-news-sm (setup.py) ... done
#   Created wheel for it-core-news-sm: filename=it_core_news_sm-2.3.0-cp36-none-any.whl size=14502462 sha256=a40db288c94bf4ecaf0b771407b5d915b82b3591644f1680a2234a0afb687105
#   Stored in directory: /tmp/pip-ephem-wheel-cache-llc3wnvp/wheels/4b/ba/ff/a127270808d2351d5ff858061d24c4fe7599f45d0920145900
# Successfully built it-core-news-sm
# Installing collected packages: it-core-news-sm
# Successfully installed it-core-news-sm-2.3.0
# ✔ Download and installation successful
# You can now load the model via spacy.load('it_core_news_sm')
# ✔ Linking successful
# /usr/local/lib/python3.6/dist-packages/it_core_news_sm -->
# /usr/local/lib/python3.6/dist-packages/spacy/data/it
# You can now load the model via spacy.load('it')
# Collecting en_core_web_sm==2.3.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.3.0/en_core_web_sm-2.3.0.tar.gz (12.0MB)
#      |████████████████████████████████| 12.1MB 658kB/s
# Requirement already satisfied: spacy<2.4.0,>=2.3.0 in /usr/local/lib/python3.6/dist-packages (from en_core_web_sm==2.3.0) (2.3.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.0) (2.23.0)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.0) (0.8.0)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.0) (1.0.2)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.0) (4.41.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.0) (50.3.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.0) (3.0.2)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.0) (1.18.5)
# Requirement already satisfied: thinc==7.4.1 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.0) (7.4.1)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.0) (1.1.3)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.0) (2.0.3)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.0) (1.0.0)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.0) (0.4.1)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.0) (1.0.2)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.0) (2020.6.20)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.0) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.0) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.0) (3.0.4)
# Requirement already satisfied: importlib-metadata>=0.20; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from catalogue<1.1.0,>=0.0.7->spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.0) (2.0.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata>=0.20; python_version < "3.8"->catalogue<1.1.0,>=0.0.7->spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.0) (3.3.1)
# Building wheels for collected packages: en-core-web-sm
#   Building wheel for en-core-web-sm (setup.py) ... done
#   Created wheel for en-core-web-sm: filename=en_core_web_sm-2.3.0-cp36-none-any.whl size=12048610 sha256=9f11ea2ee80b87d84e8cb75c350b9df5d53572e3407eca88a8626e766a8c707b
#   Stored in directory: /tmp/pip-ephem-wheel-cache-ggmxkzt1/wheels/be/ec/e4/29a68c7de525fcfa2d898cc27d2b945fe7cd966feeb2d85e0b
# Successfully built en-core-web-sm
# Installing collected packages: en-core-web-sm
#   Found existing installation: en-core-web-sm 2.2.5
#     Uninstalling en-core-web-sm-2.2.5:
#       Successfully uninstalled en-core-web-sm-2.2.5
# Successfully installed en-core-web-sm-2.3.0
# ✔ Download and installation successful
# You can now load the model via spacy.load('en_core_web_sm')
# ✔ Linking successful
# /usr/local/lib/python3.6/dist-packages/en_core_web_sm -->
# /usr/local/lib/python3.6/dist-packages/spacy/data/en
# You can now load the model via spacy.load('en')
# Collecting fr_core_news_sm==2.3.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/fr_core_news_sm-2.3.0/fr_core_news_sm-2.3.0.tar.gz (14.7MB)
#      |████████████████████████████████| 14.7MB 667kB/s
# Requirement already satisfied: spacy<2.4.0,>=2.3.0 in /usr/local/lib/python3.6/dist-packages (from fr_core_news_sm==2.3.0) (2.3.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->fr_core_news_sm==2.3.0) (1.0.2)
# Requirement already satisfied: thinc==7.4.1 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->fr_core_news_sm==2.3.0) (7.4.1)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->fr_core_news_sm==2.3.0) (1.0.2)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->fr_core_news_sm==2.3.0) (1.1.3)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->fr_core_news_sm==2.3.0) (1.18.5)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->fr_core_news_sm==2.3.0) (0.8.0)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->fr_core_news_sm==2.3.0) (1.0.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->fr_core_news_sm==2.3.0) (3.0.2)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->fr_core_news_sm==2.3.0) (4.41.1)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->fr_core_news_sm==2.3.0) (0.4.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->fr_core_news_sm==2.3.0) (2.23.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->fr_core_news_sm==2.3.0) (50.3.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->fr_core_news_sm==2.3.0) (2.0.3)
# Requirement already satisfied: importlib-metadata>=0.20; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from catalogue<1.1.0,>=0.0.7->spacy<2.4.0,>=2.3.0->fr_core_news_sm==2.3.0) (2.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0,>=2.3.0->fr_core_news_sm==2.3.0) (2020.6.20)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0,>=2.3.0->fr_core_news_sm==2.3.0) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0,>=2.3.0->fr_core_news_sm==2.3.0) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0,>=2.3.0->fr_core_news_sm==2.3.0) (2.10)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata>=0.20; python_version < "3.8"->catalogue<1.1.0,>=0.0.7->spacy<2.4.0,>=2.3.0->fr_core_news_sm==2.3.0) (3.3.1)
# Building wheels for collected packages: fr-core-news-sm
#   Building wheel for fr-core-news-sm (setup.py) ... done
#   Created wheel for fr-core-news-sm: filename=fr_core_news_sm-2.3.0-cp36-none-any.whl size=14718368 sha256=d92f5a47ac0e64175e07b8645198491f67573702d52a68732c4f5019cecc9c3e
#   Stored in directory: /tmp/pip-ephem-wheel-cache-016afewa/wheels/f4/29/3c/11e2201c8f61d231f09aa32ae3fe885cb0f9d9c0d3a609eea0
# Successfully built fr-core-news-sm
# Installing collected packages: fr-core-news-sm
# Successfully installed fr-core-news-sm-2.3.0
# ✔ Download and installation successful
# You can now load the model via spacy.load('fr_core_news_sm')
# ✔ Linking successful
# /usr/local/lib/python3.6/dist-packages/fr_core_news_sm -->
# /usr/local/lib/python3.6/dist-packages/spacy/data/fr
# You can now load the model via spacy.load('fr')

# %%
import spacy;
import gensim
import logging
from gensim.models import KeyedVectors
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.CRITICAL)

# %%
from IPython.display import Markdown, display, HTML

# %% [markdown]
# libraries configurations

# %%
import warnings
from sklearn.exceptions import UndefinedMetricWarning
warnings.simplefilter(action='ignore', category=UndefinedMetricWarning)
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
np.set_printoptions(precision=4)
pd.options.display.float_format = '{:,.4f}'.format
sns.set(color_codes=True);

# %%
import platform;
import sklearn;
import scipy;

Markdown(
    "|%-15s|%-65s|\n"%("PACK","VERSION") +
    "|%-15s|%-65s|\n"%('-'*15,'-'*65) +
    ('\n'.join(
    "|%-15s|%-45s| " % (pack, version.strip())
    for pack, version in
    zip(['SO','NumPy','SciPy','Scikit-Learn','Seaborn','Spacy','Gensim'],
        [platform.platform(), np.__version__, scipy.__version__,
         sklearn.__version__, spacy.__version__, gensim.__version__])

)))
# Out:
# |PACK           |VERSION                                                          |
# |---------------|-----------------------------------------------------------------|
# |SO             |Linux-4.19.112+-x86_64-with-Ubuntu-18.04-bionic|
# |NumPy          |1.18.5                                       |
# |SciPy          |1.4.1                                        |
# |Scikit-Learn   |0.22.2.post1                                 |
# |Seaborn        |2.3.0                                        |
# |Spacy          |3.6.0                                        |

# %% [markdown]
# ### on google

# %%
from google.colab import drive, files
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
currentCorpus = 'socialaa';

# %%
baseDir = '/content/gdrive/My Drive/Colab Notebooks/AA'
outputDir= pathjoin(baseDir,'ensemble','output_ensemble');

os.makedirs(outputDir, exist_ok=True)

def transferCode(filename):
    with open(os.path.join(baseDir,'ensemble',filename)) as fin:
        with open(filename,'w') as fout:
            fout.write(fin.read());
transferCode('pan.py')
transferCode('sklearnExtensions.py')

# %%
import pan
import sklearnExtensions
from sklearnExtensions import DenseTransformer, POSTagTransformer,FilterTagTransformer;

# %%
# !pip freeze > '/content/gdrive/My Drive/Colab Notebooks/AA/requirements.txt'

# %% [markdown]
# ## Data Ingestion

# %%
datasets = pd.read_json(baseDir+'/data/AllDS.json.zip', orient='records', compression='gzip')
datasets['row_index'] = np.arange(len(datasets));
datasets = datasets[['row_index','dataset','problem','language','set','filename','text','label']]
print(datasets['dataset'].unique())
# Out:
# ['pan18_train' 'pan18_eval' 'lyrics' 'socialaa']

# %%
df = datasets.query(f'dataset == "{currentCorpus}"').copy()

# %%
len(df)
# Out:
# 21080

# %% [markdown]
# # Caching embeddings and POS Tagging

# %% [markdown]
# ### Linguistic anotations

# %%
postaggers = {
    l:POSTagTransformer(language=m)
    for l,m in {'en':'en', 'pt':'pt'}.items()
}

# %% [markdown]
# the POSTagTransformer returns a sequence of tokens and its annotations
# 1. Text
# 2. tag
# 3. pos
# 4. dep

# %%
def cachePOS(row):
    if row['language'] == 'pl':
        return [];
    else:
        return postaggers[row['language']].fit_transform([row['text']])[0]

df['POS']=df.apply(cachePOS,axis=1)

# %%
df
# Out:
#        row_index  ...                                                POS
# 9886        9886  ...  [(I, PRP, PRON, nsubj), (do, VBP, AUX, aux), (...
# 9887        9887  ...  [(REF, NNP, PROPN, nsubj), (this, DT, DET, det...
# 9888        9888  ...  [(“, ``, PUNCT, punct), (REF, NNP, PROPN, comp...
# 9889        9889  ...  [(“, ``, PUNCT, ROOT), (REF, NNP, PROPN, compo...
# 9890        9890  ...  [(A, DT, DET, det), (nap, NN, NOUN, nsubj), (i...
# ...          ...  ...                                                ...
# 30961      30961  ...  [(\n , _SP, SPACE, ), (You, PRP, PRON, nsubj),...
# 30962      30962  ...  [(\n , _SP, SPACE, ), (Sitting, VBG, VERB, ROO...
# 30963      30963  ...  [(\n , _SP, SPACE, ), (REF, NNP, PROPN, ROOT),...
# 30964      30964  ...  [(\n , _SP, SPACE, ), (I, PRP, PRON, nsubj), (...
# 30965      30965  ...  [(\n , _SP, SPACE, ), (Got, VBD, VERB, ROOT), ...
#
# [21080 rows x 9 columns]

# %% [markdown]
# ### Embeddings

# %%
def loadEmbeddings(lang):
    if lang == 'sp':
        lang = 'es';
    model = KeyedVectors.load_word2vec_format(os.path.join(baseDir,'data','embedding_cache','w2v_'+lang+'.txt.gz'), binary=False, unicode_errors='replace')
    return model;

# %%
def problemDoc(df,problem, column='text'):
    df = df.query(f"problem == '{problem}'")

    train = df[df['set'] =='known']
    X_train = np.array([c for c in train[column]])
    y_train = train['label'].values
    index_train = train['row_index'].values

    # The test set is actually the validation set and should not be used in the training processing
    test = df[df['set'] =='unknown']
    X_test = np.array([c for c in test[column]])
    y_test = test['label'].values
    index_test = test['row_index'].values

    return X_train, y_train, index_train, X_test, y_test, index_test;

# %% [markdown]
# It was used embeddings processed by Nordic Language Processing Laboratry
# and availabe on http://vectors.nlpl.eu/repository/. This website was visted in  jan 01 2019

# %%
def fitPipeline(df, problem,language, pipe,params,caching):
    print ("Problem: %s,  language: %s, " %(problem,language), end=' ');
    
    column = 'text';
    if caching == 'POS':
        column = 'POS';
    
    train_docs, train_labels, index_train, test_docs, test_labels,index_test = problemDoc(df, problem,column);
    if caching == 'POS':
        if language == 'pl':
            print("POS tagger not found")
            return {
                'problem':problem,
                'language':language,
                'n_authors': 0,
                'f1'       : 0,
                'precision': 0,
                'recall'   : 0,
                'accuracy' : 0,
            }, [[],[],[],[],[],[]], {};
    elif caching == 'w2v':
        global embeddingsCacheLanguage;
        global embeddingsCache;
        #yes it is uggly to use global var ... but it saved a lot of memory
        if embeddingsCacheLanguage != language:
            embeddingsCache = loadEmbeddings(language);
            embeddingsCacheLanguage = language;
        
    
    #using language specific params
    if language in params:
        pipe.set_params(**params[language])
        
    t0 = time()
    pipe.fit(train_docs, train_labels)
    print("Fitted in %0.3fs" % (time() - t0), end=' ');
    
    t0 = time()
    train_pred=pipe.predict(train_docs);
    train_prob=pipe.predict_proba(train_docs);

    test_pred=pipe.predict(test_docs);
    test_prob=pipe.predict_proba(test_docs);
    print("Predicted in %0.3fs" % (time() - t0));
    
    f1,precision,recall,accuracy = pan.eval_measures2019(test_labels,test_pred)
    
    return {
        'problem':problem,
        'language':language,
        'n_authors':len(set(train_labels)),
        'f1'       : round(f1,3),
        'precision': round(precision,3),
        'recall'   : round(recall,3),
        'accuracy' : round(accuracy,3),
    }, [train_pred, train_prob,index_train, test_pred,  test_prob,index_test], pipe.get_params();

# %% [markdown]
# # Model 1: Character

# %%
pipelineChar = Pipeline([
    ('vect',   TfidfVectorizer(analyzer='char',
                               min_df=0.01,
                               max_df=1.0,
                               norm='l2',
                               ngram_range=(2, 5),
                               sublinear_tf=True,
                               lowercase =False)),
    ('scaler', preprocessing.MaxAbsScaler()),
    ('dense',  DenseTransformer()),
    ('transf', PCA(0.999)),
    ('clf', LogisticRegression(random_state=0,multi_class='multinomial', solver='newton-cg')),
])

# %%
pipelineCharParams= {
    'it':{
        'vect__ngram_range': (3, 5),
    },
    'pl':{
        'vect__ngram_range': (2, 3),
    }
}

# %% [markdown]
# # Model 2: Word

# %%
pipelineWord = Pipeline([
    ('vect',   TfidfVectorizer(analyzer='word',
                               norm='l1',
                               min_df=2,
                               max_df=1.0,
                               ngram_range=(1, 2),
                               smooth_idf=True,
                               lowercase =True,
                               sublinear_tf=True)),
    ('dense',  DenseTransformer()),
    ('scaler', preprocessing.MaxAbsScaler()),
    ('transf', PCA(0.999)),
    ('clf', LogisticRegression(random_state=0,multi_class='multinomial', solver='newton-cg')),
])

# %%
pipelineWordParams= {
    'en':{
        'vect__ngram_range': (1, 3),
        'vect__norm': 'l2',
    },

    'pl':{
        'vect__norm': 'l2',
     },
}

# %% [markdown]
# # Model 3: distortions

# %%
distortions = [
    (r"[A-Z]"          ,'U','Upcase '),
    (r"[a-z]"          ,'l','lowercase'),
    (r"[À-ÿĄ-ż]"       ,'d','Diacrit'),
    (r"\d"             ,'D','Digits'),
    (r"[\n\r\t]"       ,'E','Paragraph control'),
    (r"\–|\-|\_|\—"    ,'H','Hyphen'),
    (r"\"|\'|’|[“”]"   ,'Q','quotation'),
    (r"\s"             ,'S','Spaces'),
    (r"\(|\)|\[|\]\{|\}|\«|\»",'G','Groups'),
    (r"…",'','...'),
    (r"\.|\,|[?]|\!|\:|\;|\„|\*|\/"   ,'P','Punctuation'),
    (r"[^aUldDEHQSGP]", 'X','Unkown'),
]

distortions = [(re.compile(d[0]), d[1],d[2]) for d in distortions]

# %%
class DistortionTransformer(BaseEstimator):
    def __init__(self,verbose=False):
        self.verbose = verbose;
        
    def _distortion(self,doc):
        for d in distortions:
            doc = d[0].sub(d[1],doc);
        return doc;

    def transform(self, X, y=None):
        t0 = time()
        if self.verbose:
            print('filtered in', end=' ')

        X = [self._distortion(doc) for doc in X]
        
        if self.verbose:
            print(" %0.3fs" % (time() - t0))
        return np.array(X);       

    def fit(self, X, y=None):
        self.is_fitted = True
        return self

    def fit_transform(self, X, y=None):
        return self.transform(X=X, y=y)

# %%
pipelineDistortion = Pipeline([
    ('filter',DistortionTransformer()),
    ('vect', TfidfVectorizer(
            analyzer='char',
            min_df=0.01,
            lowercase=False,
            norm='l2',
            sublinear_tf=True,
            ngram_range=(1, 5),
            )
    ),
    ('scaler', MaxAbsScaler()),
    ('dense',  DenseTransformer()),
    ('transf', PCA(0.999)),
    ('clf', LogisticRegression(random_state=0,C=1,multi_class='multinomial', solver='newton-cg')),
])

# %%
pipelineDistortionsParams = {
    'en':{
        'clf__C': 0.1,
        'vect__norm': 'l1',        
    },
    'fr':{
        'vect__norm': 'l1',
        'vect__ngram_range': (2, 5),
    },
    'it':{
        'clf__C': 0.1,
    },
    'sp':{
        'vect__norm': 'l1',
    }
}

# %% [markdown]
# # Model 4: POS

# %%
#train_docs, train_labels, test_docs, test_filename = cachingPOSTAG(problem)

pipelinePOS = Pipeline([
    ('filter',FilterTagTransformer(token='POS')),
    ('vect', TfidfVectorizer(
                        min_df=0.01,
                        lowercase=False,
                        use_idf=True,
                        norm='l1',
                        sublinear_tf=False,
                        ngram_range=(1, 5)
            )),
    ('scaler', MaxAbsScaler()),
    ('dense',  DenseTransformer()),
    ('transf', PCA(0.999)),
    ('clf', LogisticRegression(random_state=0,multi_class='multinomial', solver='newton-cg')),
])

# %% [markdown]
# O parametro sublinear_tf=True apresentou performance ruim em todos os casos de teste exceto o melhor.
# Como o melhor caso não é garantido nos conjuntos de avaliação, foi decidido que ele seria mantido como False.
#
# O parametro L1 apresentou performance melhor nos conjuntos com 5 candidatos. No entendo, o conjunto de validação conterá de 5 a 20 e portanto foi escolhido manter o valor l2

# %% [markdown]
# # Model 5: TAG  (granular POS)

# %%
def spaceTokenizer(x):
    return x.split(" ");

# %%
pipelineTag = Pipeline([
    ('filter',FilterTagTransformer(token='TAG')),
    ('vect', TfidfVectorizer(
                               tokenizer=spaceTokenizer,
                               min_df=0.01,
                               lowercase=False,
                               sublinear_tf=True,
                               use_idf=True,
                               norm='l2',
                                ngram_range=(1,3),
                              )),
    ('scaler', MaxAbsScaler()),
    ('dense',  DenseTransformer()),
    ('transf', PCA(0.999)),
    ('clf', LogisticRegression(random_state=0,C=0.1,multi_class='multinomial', solver='newton-cg')),
])

# %%
pipelineTagParams = {
    'fr':{
        'vect__ngram_range' :(1,5),
    },
    'sp':{
        'vect__ngram_range' :(1,5),
        'clf__C':1,
    }
}

# %% [markdown]
# # Model 6: Sintatic Dependency

# %%
pipelineDEP = Pipeline([
    ('filter',FilterTagTransformer(token='DEP')),
    ('vect', TfidfVectorizer(
                    analyzer='word',
                    min_df=0.01,
                    lowercase=False,
                    use_idf=True,
                    norm='l2',
                    ngram_range=(1,5),
            )),
    ('scaler', MaxAbsScaler()),
    ('dense',  DenseTransformer()),
    ('transf', PCA(0.999)),
    ('clf', LogisticRegression(random_state=0,C=1,multi_class='multinomial', solver='newton-cg')),
])

# %%
pipelineDEPParams = {
    'en':{
        'clf__C':0.1,
    },
    'fr':{
        'clf__C':0.1,
    },
    'it':{
        'vect__ngram_range' :(1,3),
    },
}

# %% [markdown]
# # Model 7: Word Embeddings

# %%
embeddingsCacheLanguage = None;
embeddingsCache = None;

# %%
from scipy import sparse
from sklearn.utils import assert_all_finite

class EmbeddingVectorizer(BaseEstimator):
    def __init__(self,norm=None,analyzer='word',min_df=1,lowercase=False,sublinear_tf=True,use_idf=True,binary=False):
        self.norm        = norm;
        self.analyzer    = analyzer;
        self.min_df      = min_df;
        self.lowercase   = lowercase;
        self.sublinear_tf= sublinear_tf;
        self.use_idf     = use_idf;
        self.binary      = binary;
        
    def fit(self, X, y=None):
        self.dim_ = len(embeddingsCache.vectors[0]);
        #self.dim_ = len(embeddingsCache[list(embeddingsCache.keys())[0]])
        self.vect = TfidfVectorizer(**self.get_params())
        self.vect.fit(X,y);
        self.word_vectors_ = np.zeros((len(self.vect.vocabulary_), self.dim_));
        
        #this arrays says if a word in the vocab has 
        self.missingWord_  = np.zeros(len(self.vect.vocabulary_),dtype=np.int8);
        
        blank = np.zeros(self.dim_);

        for  word, index in self.vect.vocabulary_.items():
            temp = blank.copy();
            for w in [word, word.lower(), word.capitalize()]:
                if w in embeddingsCache:
                    temp = embeddingsCache[w];
                    break;
            if temp.sum() == 0 :
                self.missingWord_[index] = 1;
            self.word_vectors_[index,:] = temp;
        return self
    
    def transform(self, X):
        import gc;
        gc.collect()
        X = self.vect.transform(X);
        
        X = sparse.csc_matrix(X);
        V = sparse.csc_matrix(self.word_vectors_);
        M = sparse.csc_matrix(self.missingWord_).T;
        
        missing = preprocessing.normalize((X>0).dot(M),norm='l1');
        missing = sparse.csc_matrix(missing.reshape(-1,1));
        
        #memory friendly dot product
        X  = preprocessing.normalize(X.dot(V),norm='l1');
        
        #last columns will contain the embedding coverage
        X = sparse.hstack([X,missing]);
        
        return X;
    
    def fit_transform(self, X, y=None):
        self.fit(X,y);
        return self.transform(X)
    
    def get_feature_names():
        return self.vect.get_feature_names();

# %%
pipelineEmbeddings = Pipeline([
    ('vect', EmbeddingVectorizer(
            analyzer='word',
            min_df=0.01,
            lowercase=False,
            sublinear_tf=False,
            norm='l1',
            use_idf=False
            )
    ),
    ('scaler',preprocessing.MaxAbsScaler()),
    ('dense',DenseTransformer()),
    ('pca',PCA(0.999)),
    ('clf', LogisticRegression(random_state=0,C=1,multi_class='multinomial', solver='newton-cg')),
])

# %%
pipelineEmbeddingsParams = {
    'fr':{
        'vect__sublinear_tf': True,
        'vect__use_idf': True,
    },

    'it':{
        'vect__use_idf': True,
    },

    'pl':{
        'clf__C': 0.1,
        'vect__use_idf': False,
        'vect__sublinear_tf': True,
    },
    'sp':{
        'vect__sublinear_tf': True,
        'vect__use_idf': True,
    },
}

# %% [markdown]
# # Applying models

# %%
models =[
    ('char',pipelineChar,pipelineCharParams,None),
    ('word',pipelineWord,pipelineWordParams,None),
    ('dist',pipelineDistortion,pipelineDistortionsParams,None),
    ('pos',pipelinePOS,{},'POS'),
    ('tag',pipelineTag,pipelineTagParams,'POS'),
    ('dep',pipelineDEP,pipelineDEPParams,'POS'),
    ('w2v',pipelineEmbeddings,pipelineEmbeddingsParams,'w2v'),
]

results = {};

for model in models:
    if model[0] in results:
        continue;
    print(('_'*100)+'\n'+model[0]+'\n'+('_'*100))
    result= {
        'metric':[],
        'pred_train':[],
        'pred_test':[],
        'prob_train':[],
        'prob_test':[],
        'index_train':[],
        'index_test':[],
        'params':[],
    }
    for problem in np.sort(df['problem'].unique()):
        language = df.query(f'problem =="{problem}"')['language'].unique()[0]
        metric, vects, params = fitPipeline(df, problem, language, model[1], model[2], caching=model[3]);
        result['metric'].append(metric);

        result['pred_train'].append(vects[0]);
        result['prob_train'].append(vects[1]);
        result['index_train'].append(vects[2]);

        result['pred_test'].append(vects[3]);
        result['prob_test'].append(vects[4]);
        result['index_test'].append(vects[5]);
        result['params'].append(params);
    results[model[0]]=result;
# Out:
# ____________________________________________________________________________________________________
# char
# ____________________________________________________________________________________________________
# Problem: problem00001,  language: en,  Fitted in 0.164s Predicted in 0.064s
# Problem: problem00002,  language: en,  Fitted in 0.448s Predicted in 0.228s
# Problem: problem00003,  language: en,  Fitted in 0.366s Predicted in 0.135s
# Problem: problem00004,  language: en,  Fitted in 1.004s Predicted in 0.444s
# Problem: problem00005,  language: en,  Fitted in 0.459s Predicted in 0.220s
# Problem: problem00006,  language: en,  Fitted in 3.340s Predicted in 1.070s
# Problem: problem00007,  language: en,  Fitted in 1.365s Predicted in 0.540s
# Problem: problem00008,  language: en,  Fitted in 25.910s Predicted in 3.435s
# Problem: problem00009,  language: en,  Fitted in 0.188s Predicted in 0.100s
# Problem: problem00010,  language: en,  Fitted in 0.284s Predicted in 0.207s
# Problem: problem00011,  language: en,  Fitted in 0.483s Predicted in 0.358s
# Problem: problem00012,  language: en,  Fitted in 0.763s Predicted in 0.414s
# Problem: problem00013,  language: en,  Fitted in 1.514s Predicted in 0.727s
# Problem: problem00014,  language: en,  Fitted in 2.988s Predicted in 1.399s
# Problem: problem00015,  language: en,  Fitted in 0.673s Predicted in 0.275s
# Problem: problem00016,  language: en,  Fitted in 1.420s Predicted in 0.491s
# Problem: problem00017,  language: en,  Fitted in 2.362s Predicted in 0.796s
# Problem: problem00018,  language: en,  Fitted in 2.021s Predicted in 0.845s
# Problem: problem00019,  language: en,  Fitted in 3.400s Predicted in 1.635s
# Problem: problem00020,  language: en,  Fitted in 7.568s Predicted in 2.894s
# Problem: problem00021,  language: en,  Fitted in 0.937s Predicted in 0.448s
# Problem: problem00022,  language: en,  Fitted in 1.478s Predicted in 0.739s
# Problem: problem00023,  language: en,  Fitted in 2.838s Predicted in 1.280s
# Problem: problem00024,  language: en,  Fitted in 5.624s Predicted in 1.947s
# Problem: problem00025,  language: en,  Fitted in 9.249s Predicted in 4.208s
# Problem: problem00026,  language: en,  Fitted in 18.282s Predicted in 7.413s
# Problem: problem00027,  language: en,  Fitted in 2.345s Predicted in 0.945s
# Problem: problem00028,  language: en,  Fitted in 4.041s Predicted in 1.869s
# Problem: problem00029,  language: en,  Fitted in 7.887s Predicted in 3.250s
# Problem: problem00030,  language: en,  Fitted in 37.981s Predicted in 7.919s
# Problem: problem00031,  language: en,  Fitted in 55.226s Predicted in 16.208s
# Problem: problem00032,  language: en,  Fitted in 80.952s Predicted in 28.668s
# ____________________________________________________________________________________________________
# word
# ____________________________________________________________________________________________________
# Problem: problem00001,  language: en,  Fitted in 0.026s Predicted in 0.013s
# Problem: problem00002,  language: en,  Fitted in 0.150s Predicted in 0.048s
# Problem: problem00003,  language: en,  Fitted in 0.046s Predicted in 0.020s
# Problem: problem00004,  language: en,  Fitted in 0.496s Predicted in 0.132s
# Problem: problem00005,  language: en,  Fitted in 0.122s Predicted in 0.041s
# Problem: problem00006,  language: en,  Fitted in 2.704s Predicted in 0.550s
# Problem: problem00007,  language: en,  Fitted in 0.672s Predicted in 0.135s
# Problem: problem00008,  language: en,  Fitted in 30.160s Predicted in 4.870s
# Problem: problem00009,  language: en,  Fitted in 0.038s Predicted in 0.019s
# Problem: problem00010,  language: en,  Fitted in 0.054s Predicted in 0.031s
# Problem: problem00011,  language: en,  Fitted in 0.086s Predicted in 0.063s
# Problem: problem00012,  language: en,  Fitted in 0.208s Predicted in 0.082s
# Problem: problem00013,  language: en,  Fitted in 0.368s Predicted in 0.166s
# Problem: problem00014,  language: en,  Fitted in 0.678s Predicted in 0.310s
# Problem: problem00015,  language: en,  Fitted in 0.077s Predicted in 0.048s
# Problem: problem00016,  language: en,  Fitted in 0.113s Predicted in 0.055s
# Problem: problem00017,  language: en,  Fitted in 0.175s Predicted in 0.097s
# Problem: problem00018,  language: en,  Fitted in 0.805s Predicted in 0.264s
# Problem: problem00019,  language: en,  Fitted in 1.380s Predicted in 0.533s
# Problem: problem00020,  language: en,  Fitted in 2.280s Predicted in 0.851s
# Problem: problem00021,  language: en,  Fitted in 0.172s Predicted in 0.074s
# Problem: problem00022,  language: en,  Fitted in 0.271s Predicted in 0.127s
# Problem: problem00023,  language: en,  Fitted in 0.481s Predicted in 0.268s
# Problem: problem00024,  language: en,  Fitted in 3.736s Predicted in 0.985s
# Problem: problem00025,  language: en,  Fitted in 6.669s Predicted in 2.062s
# Problem: problem00026,  language: en,  Fitted in 10.965s Predicted in 3.638s
# Problem: problem00027,  language: en,  Fitted in 0.985s Predicted in 0.256s
# Problem: problem00028,  language: en,  Fitted in 1.414s Predicted in 0.544s
# Problem: problem00029,  language: en,  Fitted in 2.662s Predicted in 0.920s
# Problem: problem00030,  language: en,  Fitted in 47.567s Predicted in 10.791s
# Problem: problem00031,  language: en,  Fitted in 72.987s Predicted in 22.190s
# Problem: problem00032,  language: en,  Fitted in 118.381s Predicted in 41.165s
# ____________________________________________________________________________________________________
# dist
# ____________________________________________________________________________________________________
# Problem: problem00001,  language: en,  Fitted in 0.039s Predicted in 0.043s
# Problem: problem00002,  language: en,  Fitted in 0.144s Predicted in 0.163s
# Problem: problem00003,  language: en,  Fitted in 0.066s Predicted in 0.078s
# Problem: problem00004,  language: en,  Fitted in 0.258s Predicted in 0.278s
# Problem: problem00005,  language: en,  Fitted in 0.144s Predicted in 0.145s
# Problem: problem00006,  language: en,  Fitted in 0.598s Predicted in 0.495s
# Problem: problem00007,  language: en,  Fitted in 0.414s Predicted in 0.338s
# Problem: problem00008,  language: en,  Fitted in 1.689s Predicted in 0.967s
# Problem: problem00009,  language: en,  Fitted in 0.050s Predicted in 0.070s
# Problem: problem00010,  language: en,  Fitted in 0.083s Predicted in 0.149s
# Problem: problem00011,  language: en,  Fitted in 0.117s Predicted in 0.255s
# Problem: problem00012,  language: en,  Fitted in 0.205s Predicted in 0.303s
# Problem: problem00013,  language: en,  Fitted in 0.315s Predicted in 0.472s
# Problem: problem00014,  language: en,  Fitted in 0.446s Predicted in 0.758s
# Problem: problem00015,  language: en,  Fitted in 0.094s Predicted in 0.144s
# Problem: problem00016,  language: en,  Fitted in 0.156s Predicted in 0.272s
# Problem: problem00017,  language: en,  Fitted in 0.208s Predicted in 0.400s
# Problem: problem00018,  language: en,  Fitted in 0.433s Predicted in 0.466s
# Problem: problem00019,  language: en,  Fitted in 0.677s Predicted in 0.802s
# Problem: problem00020,  language: en,  Fitted in 1.009s Predicted in 1.417s
# Problem: problem00021,  language: en,  Fitted in 0.202s Predicted in 0.278s
# Problem: problem00022,  language: en,  Fitted in 0.270s Predicted in 0.434s
# Problem: problem00023,  language: en,  Fitted in 0.386s Predicted in 0.701s
# Problem: problem00024,  language: en,  Fitted in 0.965s Predicted in 0.815s
# Problem: problem00025,  language: en,  Fitted in 1.820s Predicted in 1.546s
# Problem: problem00026,  language: en,  Fitted in 2.993s Predicted in 2.690s
# Problem: problem00027,  language: en,  Fitted in 0.597s Predicted in 0.553s
# Problem: problem00028,  language: en,  Fitted in 0.927s Predicted in 0.933s
# Problem: problem00029,  language: en,  Fitted in 1.271s Predicted in 1.571s
# Problem: problem00030,  language: en,  Fitted in 3.109s Predicted in 1.858s
# Problem: problem00031,  language: en,  Fitted in 5.368s Predicted in 3.689s
# Problem: problem00032,  language: en,  Fitted in 8.374s Predicted in 6.485s
# ____________________________________________________________________________________________________
# pos
# ____________________________________________________________________________________________________
# Problem: problem00001,  language: en,  Fitted in 0.040s Predicted in 0.026s
# Problem: problem00002,  language: en,  Fitted in 0.168s Predicted in 0.075s
# Problem: problem00003,  language: en,  Fitted in 0.092s Predicted in 0.050s
# Problem: problem00004,  language: en,  Fitted in 0.412s Predicted in 0.137s
# Problem: problem00005,  language: en,  Fitted in 0.165s Predicted in 0.072s
# Problem: problem00006,  language: en,  Fitted in 1.121s Predicted in 0.335s
# Problem: problem00007,  language: en,  Fitted in 0.625s Predicted in 0.183s
# Problem: problem00008,  language: en,  Fitted in 3.049s Predicted in 0.595s
# Problem: problem00009,  language: en,  Fitted in 0.062s Predicted in 0.041s
# Problem: problem00010,  language: en,  Fitted in 0.131s Predicted in 0.078s
# Problem: problem00011,  language: en,  Fitted in 0.171s Predicted in 0.129s
# Problem: problem00012,  language: en,  Fitted in 0.260s Predicted in 0.157s
# Problem: problem00013,  language: en,  Fitted in 0.491s Predicted in 0.321s
# Problem: problem00014,  language: en,  Fitted in 0.815s Predicted in 0.528s
# Problem: problem00015,  language: en,  Fitted in 0.204s Predicted in 0.093s
# Problem: problem00016,  language: en,  Fitted in 0.339s Predicted in 0.176s
# Problem: problem00017,  language: en,  Fitted in 0.555s Predicted in 0.296s
# Problem: problem00018,  language: en,  Fitted in 0.720s Predicted in 0.315s
# Problem: problem00019,  language: en,  Fitted in 1.215s Predicted in 0.605s
# Problem: problem00020,  language: en,  Fitted in 1.998s Predicted in 0.992s
# Problem: problem00021,  language: en,  Fitted in 0.291s Predicted in 0.148s
# Problem: problem00022,  language: en,  Fitted in 0.449s Predicted in 0.292s
# Problem: problem00023,  language: en,  Fitted in 0.791s Predicted in 0.482s
# Problem: problem00024,  language: en,  Fitted in 2.486s Predicted in 0.652s
# Problem: problem00025,  language: en,  Fitted in 3.584s Predicted in 1.259s
# Problem: problem00026,  language: en,  Fitted in 4.650s Predicted in 2.265s
# Problem: problem00027,  language: en,  Fitted in 0.832s Predicted in 0.359s
# Problem: problem00028,  language: en,  Fitted in 1.346s Predicted in 0.653s
# Problem: problem00029,  language: en,  Fitted in 2.274s Predicted in 1.087s
# Problem: problem00030,  language: en,  Fitted in 10.331s Predicted in 1.606s
# Problem: problem00031,  language: en,  Fitted in 24.929s Predicted in 4.044s
# Problem: problem00032,  language: en,  Fitted in 36.967s Predicted in 7.665s
# ____________________________________________________________________________________________________
# tag
# ____________________________________________________________________________________________________
# Problem: problem00001,  language: en,  Fitted in 0.037s Predicted in 0.025s
# Problem: problem00002,  language: en,  Fitted in 0.117s Predicted in 0.056s
# Problem: problem00003,  language: en,  Fitted in 0.052s Predicted in 0.033s
# Problem: problem00004,  language: en,  Fitted in 0.262s Predicted in 0.106s
# Problem: problem00005,  language: en,  Fitted in 0.109s Predicted in 0.054s
# Problem: problem00006,  language: en,  Fitted in 0.648s Predicted in 0.228s
# Problem: problem00007,  language: en,  Fitted in 0.410s Predicted in 0.131s
# Problem: problem00008,  language: en,  Fitted in 1.397s Predicted in 0.448s
# Problem: problem00009,  language: en,  Fitted in 0.036s Predicted in 0.028s
# Problem: problem00010,  language: en,  Fitted in 0.051s Predicted in 0.050s
# Problem: problem00011,  language: en,  Fitted in 0.076s Predicted in 0.082s
# Problem: problem00012,  language: en,  Fitted in 0.157s Predicted in 0.116s
# Problem: problem00013,  language: en,  Fitted in 0.252s Predicted in 0.187s
# Problem: problem00014,  language: en,  Fitted in 0.356s Predicted in 0.323s
# Problem: problem00015,  language: en,  Fitted in 0.083s Predicted in 0.052s
# Problem: problem00016,  language: en,  Fitted in 0.140s Predicted in 0.100s
# Problem: problem00017,  language: en,  Fitted in 0.198s Predicted in 0.148s
# Problem: problem00018,  language: en,  Fitted in 0.467s Predicted in 0.216s
# Problem: problem00019,  language: en,  Fitted in 0.722s Predicted in 0.396s
# Problem: problem00020,  language: en,  Fitted in 0.971s Predicted in 0.587s
# Problem: problem00021,  language: en,  Fitted in 0.168s Predicted in 0.106s
# Problem: problem00022,  language: en,  Fitted in 0.260s Predicted in 0.174s
# Problem: problem00023,  language: en,  Fitted in 0.339s Predicted in 0.282s
# Problem: problem00024,  language: en,  Fitted in 1.587s Predicted in 0.457s
# Problem: problem00025,  language: en,  Fitted in 2.533s Predicted in 0.810s
# Problem: problem00026,  language: en,  Fitted in 3.188s Predicted in 1.243s
# Problem: problem00027,  language: en,  Fitted in 0.623s Predicted in 0.249s
# Problem: problem00028,  language: en,  Fitted in 0.910s Predicted in 0.428s
# Problem: problem00029,  language: en,  Fitted in 1.077s Predicted in 0.615s
# Problem: problem00030,  language: en,  Fitted in 4.329s Predicted in 0.982s
# Problem: problem00031,  language: en,  Fitted in 11.896s Predicted in 2.126s
# Problem: problem00032,  language: en,  Fitted in 23.889s Predicted in 3.838s
# ____________________________________________________________________________________________________
# dep
# ____________________________________________________________________________________________________
# Problem: problem00001,  language: en,  Fitted in 0.041s Predicted in 0.026s
# Problem: problem00002,  language: en,  Fitted in 0.148s Predicted in 0.076s
# Problem: problem00003,  language: en,  Fitted in 0.105s Predicted in 0.050s
# Problem: problem00004,  language: en,  Fitted in 0.361s Predicted in 0.138s
# Problem: problem00005,  language: en,  Fitted in 0.132s Predicted in 0.067s
# Problem: problem00006,  language: en,  Fitted in 0.865s Predicted in 0.304s
# Problem: problem00007,  language: en,  Fitted in 0.493s Predicted in 0.170s
# Problem: problem00008,  language: en,  Fitted in 1.938s Predicted in 0.583s
# Problem: problem00009,  language: en,  Fitted in 0.065s Predicted in 0.050s
# Problem: problem00010,  language: en,  Fitted in 0.116s Predicted in 0.076s
# Problem: problem00011,  language: en,  Fitted in 0.175s Predicted in 0.124s
# Problem: problem00012,  language: en,  Fitted in 0.227s Predicted in 0.138s
# Problem: problem00013,  language: en,  Fitted in 0.410s Predicted in 0.302s
# Problem: problem00014,  language: en,  Fitted in 0.727s Predicted in 0.455s
# Problem: problem00015,  language: en,  Fitted in 0.183s Predicted in 0.093s
# Problem: problem00016,  language: en,  Fitted in 0.328s Predicted in 0.175s
# Problem: problem00017,  language: en,  Fitted in 0.882s Predicted in 0.317s
# Problem: problem00018,  language: en,  Fitted in 0.589s Predicted in 0.307s
# Problem: problem00019,  language: en,  Fitted in 1.064s Predicted in 0.595s
# Problem: problem00020,  language: en,  Fitted in 1.901s Predicted in 0.955s
# Problem: problem00021,  language: en,  Fitted in 0.272s Predicted in 0.143s
# Problem: problem00022,  language: en,  Fitted in 0.441s Predicted in 0.281s
# Problem: problem00023,  language: en,  Fitted in 0.816s Predicted in 0.497s
# Problem: problem00024,  language: en,  Fitted in 2.244s Predicted in 0.588s
# Problem: problem00025,  language: en,  Fitted in 3.376s Predicted in 1.192s
# Problem: problem00026,  language: en,  Fitted in 5.178s Predicted in 2.166s
# Problem: problem00027,  language: en,  Fitted in 0.740s Predicted in 0.337s
# Problem: problem00028,  language: en,  Fitted in 1.205s Predicted in 0.610s
# Problem: problem00029,  language: en,  Fitted in 1.981s Predicted in 1.036s
# Problem: problem00030,  language: en,  Fitted in 8.429s Predicted in 1.482s
# Problem: problem00031,  language: en,  Fitted in 22.556s Predicted in 3.961s
# Problem: problem00032,  language: en,  Fitted in 32.347s Predicted in 7.444s
# ____________________________________________________________________________________________________
# w2v
# ____________________________________________________________________________________________________
# Problem: problem00001,  language: en,  Fitted in 0.441s Predicted in 1.386s
# Problem: problem00002,  language: en,  Fitted in 0.439s Predicted in 1.399s
# Problem: problem00003,  language: en,  Fitted in 0.379s Predicted in 1.421s
# Problem: problem00004,  language: en,  Fitted in 0.568s Predicted in 1.485s
# Problem: problem00005,  language: en,  Fitted in 0.468s Predicted in 1.445s
# Problem: problem00006,  language: en,  Fitted in 0.882s Predicted in 1.476s
# Problem: problem00007,  language: en,  Fitted in 0.825s Predicted in 1.488s
# Problem: problem00008,  language: en,  Fitted in 2.567s Predicted in 1.673s
# Problem: problem00009,  language: en,  Fitted in 0.394s Predicted in 1.399s
# Problem: problem00010,  language: en,  Fitted in 0.383s Predicted in 1.441s
# Problem: problem00011,  language: en,  Fitted in 0.424s Predicted in 1.467s
# Problem: problem00012,  language: en,  Fitted in 0.451s Predicted in 1.421s
# Problem: problem00013,  language: en,  Fitted in 0.506s Predicted in 1.453s
# Problem: problem00014,  language: en,  Fitted in 0.543s Predicted in 1.589s
# Problem: problem00015,  language: en,  Fitted in 0.439s Predicted in 1.463s
# Problem: problem00016,  language: en,  Fitted in 0.462s Predicted in 1.534s
# Problem: problem00017,  language: en,  Fitted in 0.516s Predicted in 1.643s
# Problem: problem00018,  language: en,  Fitted in 0.633s Predicted in 1.515s
# Problem: problem00019,  language: en,  Fitted in 0.660s Predicted in 1.593s
# Problem: problem00020,  language: en,  Fitted in 0.811s Predicted in 1.782s
# Problem: problem00021,  language: en,  Fitted in 0.533s Predicted in 1.548s
# Problem: problem00022,  language: en,  Fitted in 0.543s Predicted in 1.551s
# Problem: problem00023,  language: en,  Fitted in 0.561s Predicted in 1.574s
# Problem: problem00024,  language: en,  Fitted in 1.055s Predicted in 1.562s
# Problem: problem00025,  language: en,  Fitted in 1.058s Predicted in 1.683s
# Problem: problem00026,  language: en,  Fitted in 1.175s Predicted in 1.814s
# Problem: problem00027,  language: en,  Fitted in 0.819s Predicted in 1.478s
# Problem: problem00028,  language: en,  Fitted in 0.880s Predicted in 1.535s
# Problem: problem00029,  language: en,  Fitted in 0.978s Predicted in 1.671s
# Problem: problem00030,  language: en,  Fitted in 3.074s Predicted in 1.761s
# Problem: problem00031,  language: en,  Fitted in 3.716s Predicted in 2.002s
# Problem: problem00032,  language: en,  Fitted in 3.713s Predicted in 2.259s

# %%
dfMetric = pd.DataFrame();
for m in results:
    df_temp = pd.DataFrame(results[m]['metric'])[['problem','n_authors','language','f1','precision','recall','accuracy']]
    df_temp['model']=m
    dfMetric= dfMetric.append(df_temp)

with pd.option_context("display.precision", 3):
    display(dfMetric.fillna(value=0) \
        .pivot(index='problem',columns='model',values=['f1','accuracy']).round(3)\
        .style.background_gradient(subset=['f1'], axis=1, cmap=plt.cm.Blues)\
        .background_gradient(subset=['accuracy'], axis=1, cmap=plt.cm.Greens))
# Out:
# <style  type="text/css" >
# #T_43a2d476_193c_11eb_8c7c_0242ac1c0002row0_col0{
#             background-color:  #2e7ebc;
#             color:  #000000;
#         }#T_43a2d476_193c_11eb_8c7c_0242ac1c0002row0_col1,#T_43a2d476_193c_11eb_8c7c_0242ac1c0002row31_col4{
#             background-color:  #94c4df;
#             color:  #000000;
#         }#T_43a2d476_193c_11eb_8c7c_0242ac1c0002row0_col2,#T_43a2d476_193c_11eb_8c7c_0242ac1c0002row1_col5,#T_43a2d476_193c_11eb_8c7c_0242ac1c0002row2_col0,#T_43a2d476_193c_11eb_8c7c_0242ac1c0002row3_col2,#T_43a2d476_193c_11eb_8c7c_0242ac1c0002row4_col0,#T_43a2d476_193c_11eb_8c7c_0242ac1c0002row5_col0,#T_43a2d476_193c_11eb_8c7c_0242ac1c0002row6_col2,#T_43a2d476_193c_11eb_8c7c_0242ac1c0002row7_col2,#T_43a2d476_193c_11eb_8c7c_0242ac1c0002row8_col0,#T_43a2d476_193c_11eb_8c7c_0242ac1c0002row8_col2,#T_43a2d476_193c_11eb_8c7c_0242ac1c0002row8_col3,#T_43a2d476_193c_11eb_8c7c_0242ac1c0002row8_col4,#T_43a2d476_193c_11eb_8c7c_0242ac1c0002row8_col6,#T_43a2d476_193c_11eb_8c7c_0242ac1c0002row9_col2,#T_43a2d476_193c_11eb_8c7c_0242ac1c0002row10_col2,#T_43a2d476_193c_11eb_8c7c_0242ac1c0002row11_col6,#T_43a2d476_193c_11eb_8c7c_0242ac1c0002row12_col0,#T_43a2d476_193c_11eb_8c7c_0242ac1c0002row12_col1,#T_43a2d476_193c_11eb_8c7c_0242ac1c0002row12_col4,#T_43a2d476_193c_11eb_8c7c_0242ac1c0002row13_col0,#T_43a2d476_193c_11eb_8c7c_0242ac1c0002row13_col1,#T_43a2d476_193c_11eb_8c7c_0242ac1c0002row13_col2,#T_43a2d476_193c_11eb_8c7c_0242ac1c0002row13_col3,#T_43a2d476_193c_11eb_8c7c_0242ac1c0002row13_col4,#T_43a2d476_193c_11eb_8c7c_0242ac1c0002row13_col6,#T_43a2d476_193c_11eb_8c7c_0242ac1c0002row14_col2,#T_43a2d476_193c_11eb_8c7c_0242ac1c0002row15_col0,#T_43a2d476_193c_11eb_8c7c_0242ac1c0002row16_col3,#T_43a2d476_193c_11eb_8c7c_0242ac1c0002row17_col2,#T_43a2d476_193c_11eb_8c7c_0242ac1c0002row18_col0,#T_43a2d476_193c_11eb_8c7c_0242ac1c0002row19_col2,#T_43a2d476_193c_11eb_8c7c_0242ac1c0002row19_col4,#T_43a2d476_193c_11eb_8c7c_0242ac1c0002row20_col0,#T_43a2d476_193c_11eb_8c7c_0242ac1c0002row21_col2,#T_43a2d476_193c_11eb_8c7c_0242ac1c0002row22_col0,#T_43a2d476_193c_11eb_8c7c_0242ac1c0002row23_col0,#T_43a2d476_193c_11eb_8c7c_0242ac1c0002row24_col0,#T_43a2d476_193c_11eb_8c7c_0242ac1c0002row25_col0,#T_43a2d476_193c_11eb_8c7c_0242ac1c0002row25_col2,#T_43a2d476_193c_11eb_8c7c_0242ac1c0002row26_col0,#T_43a2d476_193c_11eb_8c7c_0242ac1c0002row27_col0,#T_43a2d476_193c_11eb_8c7c_0242ac1c0002row28_col0,#T_43a2d476_193c_11eb_8c7c_0242ac1c0002row29_col0,#T_43a2d476_193c_11eb_8c7c_0242ac1c0002row30_col6,#T_43a2d476_193c_11eb_8c7c_0242ac1c0002row31_col0{
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }#T_43a2d476_193c_11eb_8c7c_0242ac1c0002row0_col3,#T_43a2d476_193c_11eb_8c7c_0242ac1c0002row5_col4,#T_43a2d476_193c_11eb_8c7c_0242ac1c0002row15_col4{
#             background-color:  #b7d4ea;
#             color:  #000000;
#         }#T_43a2d476_193c_11eb_8c7c_0242ac1c0002row0_col4,#T_43a2d476_193c_11eb_8c7c_0242ac1c0002row0_col5,#T_43a2d476_193c_11eb_8c7c_0242ac1c0002row0_col6,#T_43a2d476_193c_11eb_8c7c_0242ac1c0002row1_col0,#T_43a2d476_193c_11eb_8c7c_0242ac1c0002row2_col1,#T_43a2d476_193c_11eb_8c7c_0242ac1c0002row3_col3,#T_43a2d476_193c_11eb_8c7c_0242ac1c0002row4_col4,#T_43a2d476_193c_11eb_8c7c_0242ac1c0002row5_col3,#T_43a2d476_193c_11eb_8c7c_0242ac1c0002row6_col5,#T_43a2d476_193c_11eb_8c7c_0242ac1c0002row7_col3,#T_43a2d476_193c_11eb_8c7c_0242ac1c0002row8_col1,#T_43a2d476_193c_11eb_8c7c_0242ac1c0002row9_col6,#T_43a2d476_193c_11eb_8c7c_0242ac1c0002row10_col6,#T_43a2d476_193c_11eb_8c7c_0242ac1c0002row11_col4,#T_43a2d476_193c_11eb_8c7c_0242ac1c0002row12_col3,#T_43a2d476_193c_11eb_8c7c_0242ac1c0002row13_col5,#T_43a2d476_193c_11eb_8c7c_0242ac1c0002row14_col5,#T_43a2d476_193c_11eb_8c7c_0242ac1c0002row15_col1,#T_43a2d476_193c_11eb_8c7c_0242ac1c0002row16_col1,#T_43a2d476_193c_11eb_8c7c_0242ac1c0002row17_col1,#T_43a2d476_193c_11eb_8c7c_0242ac1c0002row18_col4,#T_43a2d476_193c_11eb_8c7c_0242ac1c0002row19_col6,#T_43a2d476_193c_11eb_8c7c_0242ac1c0002row20_col3,#T_43a2d476_193c_11eb_8c7c_0242ac1c0002row21_col1,#T_43a2d476_193c_11eb_8c7c_0242ac1c0002row22_col1,#T_43a2d476_193c_11eb_8c7c_0242ac1c0002row23_col1,#T_43a2d476_193c_11eb_8c7c_0242ac1c0002row24_col1,#T_43a2d476_193c_11eb_8c7c_0242ac1c0002row25_col1,#T_43a2d476_193c_11eb_8c7c_0242ac1c0002row26_col3,#T_43a2d476_193c_11eb_8c7c_0242ac1c0002row27_col3,#T_43a2d476_193c_11eb_8c7c_0242ac1c0002row28_col1,#T_43a2d476_193c_11eb_8c7c_0242ac1c0002row29_col1,#T_43a2d476_193c_11eb_8c7c_0242ac1c0002row30_col1,#T_43a2d476_193c_11eb_8c7c_0242ac1c0002row31_col1{
#             background-color:  #f7fbff;
#             color:  #000000;
#         }#T_43a2d476_193c_11eb_8c7c_0242ac1c0002row0_col7,#T_43a2d476_193c_11eb_8c7c_0242ac1c0002row0_col9,#T_43a2d476_193c_11eb_8c7c_0242ac1c0002row1_col12,#T_43a2d476_193c_11eb_8c7c_0242ac1c0002row2_col7,#T_43a2d476_193c_11eb_8c7c_0242ac1c0002row3_col9,#T_43a2d476_193c_11eb_8c7c_0242ac1c0002row4_col7,#T_43a2d476_193c_11eb_8c7c_0242ac1c0002row5_col7,#T_43a2d476_193c_11eb_8c7c_0242ac1c0002row6_col9,#T_43a2d476_193c_11eb_8c7c_0242ac1c0002row7_col9,#T_43a2d476_193c_11eb_8c7c_0242ac1c0002row8_col7,#T_43a2d476_193c_11eb_8c7c_0242ac1c0002row8_col9,#T_43a2d476_193c_11eb_8c7c_0242ac1c0002row8_col10,#T_43a2d476_193c_11eb_8c7c_0242ac1c0002row8_col11,#T_43a2d476_193c_11eb_8c7c_0242ac1c0002row8_col13,#T_43a2d476_193c_11eb_8c7c_0242ac1c0002row9_col9,#T_43a2d476_193c_11eb_8c7c_0242ac1c0002row10_col9,#T_43a2d476_193c_11eb_8c7c_0242ac1c0002row11_col13,#T_43a2d476_193c_11eb_8c7c_0242ac1c0002row12_col7,#T_43a2d476_193c_11eb_8c7c_0242ac1c0002row12_col8,#T_43a2d476_193c_11eb_8c7c_0242ac1c0002row12_col11,#T_43a2d476_193c_11eb_8c7c_0242ac1c0002row13_col7,#T_43a2d476_193c_11eb_8c7c_0242ac1c0002row13_col8,#T_43a2d476_193c_11eb_8c7c_0242ac1c0002row13_col9,#T_43a2d476_193c_11eb_8c7c_0242ac1c0002row13_col10,#T_43a2d476_193c_11eb_8c7c_0242ac1c0002row13_col11,#T_43a2d476_193c_11eb_8c7c_0242ac1c0002row13_col13,#T_43a2d476_193c_11eb_8c7c_0242ac1c0002row14_col8,#T_43a2d476_193c_11eb_8c7c_0242ac1c0002row14_col9,#T_43a2d476_193c_11eb_8c7c_0242ac1c0002row15_col7,#T_43a2d476_193c_11eb_8c7c_0242ac1c0002row16_col10,#T_43a2d476_193c_11eb_8c7c_0242ac1c0002row17_col9,#T_43a2d476_193c_11eb_8c7c_0242ac1c0002row18_col7,#T_43a2d476_193c_11eb_8c7c_0242ac1c0002row19_col9,#T_43a2d476_193c_11eb_8c7c_0242ac1c0002row19_col11,#T_43a2d476_193c_11eb_8c7c_0242ac1c0002row20_col7,#T_43a2d476_193c_11eb_8c7c_0242ac1c0002row21_col9,#T_43a2d476_193c_11eb_8c7c_0242ac1c0002row22_col7,#T_43a2d476_193c_11eb_8c7c_0242ac1c0002row23_col7,#T_43a2d476_193c_11eb_8c7c_0242ac1c0002row24_col7,#T_43a2d476_193c_11eb_8c7c_0242ac1c0002row25_col7,#T_43a2d476_193c_11eb_8c7c_0242ac1c0002row25_col9,#T_43a2d476_193c_11eb_8c7c_0242ac1c0002row26_col7,#T_43a2d476_193c_11eb_8c7c_0242ac1c0002row27_col7,#T_43a2d476_193c_11eb_8c7c_0242ac1c0002row28_col7,#T_43a2d476_193c_11eb_8c7c_0242ac1c0002row28_col9,#T_43a2d476_193c_11eb_8c7c_0242ac1c0002row29_col7,#T_43a2d476_193c_11eb_8c7c_0242ac1c0002row30_col7,#T_43a2d476_193c_11eb_8c7c_0242ac1c0002row31_col7{
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }#T_43a2d476_193c_11eb_8c7c_0242ac1c0002row0_col8,#T_43a2d476_193c_11eb_8c7c_0242ac1c0002row0_col10,#T_43a2d476_193c_11eb_8c7c_0242ac1c0002row3_col13,#T_43a2d476_193c_11eb_8c7c_0242ac1c0002row12_col9,#T_43a2d476_193c_11eb_8c7c_0242ac1c0002row12_col12,#T_43a2d476_193c_11eb_8c7c_0242ac1c0002row12_col13,#T_43a2d476_193c_11eb_8c7c_0242ac1c0002row20_col12,#T_43a2d476_193c_11eb_8c7c_0242ac1c0002row25_col11,#T_43a2d476_193c_11eb_8c7c_0242ac1c0002row25_col13{
#             background-color:  #73c476;
#             color:  #000000;
#         }#T_43a2d476_193c_11eb_8c7c_0242ac1c0002row0_col11,#T_43a2d476_193c_11eb_8c7c_0242ac1c0002row0_col12,#T_43a2d476_193c_11eb_8c7c_0242ac1c0002row0_col13,#T_43a2d476_193c_11eb_8c7c_0242ac1c0002row1_col7,#T_43a2d476_193c_11eb_8c7c_0242ac1c0002row1_col10,#T_43a2d476_193c_11eb_8c7c_0242ac1c0002row1_col11,#T_43a2d476_193c_11eb_8c7c_0242ac1c0002row1_col13,#T

# %% [markdown]
# # Dynamic Ensemble

# %%
def buildClassifier():
    return Pipeline(steps=[
                ('pca',PCA(0.9999)),
                ('clf', LogisticRegression(random_state=0,C=1, max_iter=3000))
            ])

# %%
def concatenatXVectors(results, problemIndex, models):
    x_train = [results[model]['prob_train'][problemIndex] for model in models];
    x_test  = [results[model]['prob_test'][problemIndex] for model in models];
    
    x_train = [x for x in x_train if len(x) > 1];
    x_test  = [x for x in x_test  if len(x) > 1];
    
    if len(x_train) < 1:
        return None,None;
    
    return np.hstack(x_train),  np.hstack(x_test);

# %%
def sortModels(results, problemIndex,models,train_labels, test_labels):
    f1 = [];
    
    for model in models:
        x_train, x_test = concatenatXVectors(results, problemIndex, [model]);
        if x_train is None:
            f1.append(0);
        else:
            pipe = buildClassifier()
            pred_label = pipe.fit(x_train, train_labels).predict(x_test);
            f1.append(f1_score(test_labels, pred_label,average='macro'));
    models = np.array(models);
    f1 = np.array(f1);
    
    models = models[f1 >0];
    f1 = f1[f1 >0]
    
    return list(models[np.argsort(-f1)]);

# %%
resultFinal = []
bestModels = []
predictions = [];
for problemIndex, problem in enumerate(df['problem'].unique()):
    print('\n'+problem)

    train_docs, train_labels, index_train, test_docs, test_labels,index_test = problemDoc(df, problem);

    #forward step: sorting the models by
    models = sortModels(results, problemIndex,list(results.keys()), train_labels, test_labels);

    print("sorted "+str(models))

    #step 0 - train only the best model.
    bestModel =[ models.pop(0)];
    x_train, x_test = concatenatXVectors(results, problemIndex, bestModel);
    pred_label  = buildClassifier().fit(x_train, train_labels).predict(x_test);
    bestF1      = f1_score(test_labels,pred_label,average='macro')
    models = list(set(models)-set(bestModel)); # removing the current model from the list.
    
    improve = True;
    iteration = 0;
    while (improve):
        improve = False;
        iteration +=1 ;
        print("Iteration "+str(iteration)    +" Best model:     %-77s %.4f"%(str(bestModel),bestF1))
        for model in models:
            currentModel = bestModel +[model];
            print("Iteration "+str(iteration)+" current model:  %-75s "%str(currentModel), end=' ')

            x_train, x_test = concatenatXVectors(results, problemIndex, currentModel);

            pipe = buildClassifier()

            pred_label = pipe.fit(x_train, train_labels).predict(x_test);
            currentF1 = f1_score(test_labels,pred_label,average='macro');
            
            print(" %.4f"%currentF1)


            if currentF1/bestF1 > 1.015:
                improve = True;
                bestF1 = currentF1;
                bestModel = currentModel;
        models = list(set(models)-set(currentModel));
    print("Selected Model: "+str(bestModel))
    bestModels.append(bestModel);
    
    x_train, x_test = concatenatXVectors(results, problemIndex, bestModel);
    
    pipelineFinal = Pipeline(steps=[
        ('pca',PCA(0.9999)),
        ('clf', LogisticRegression(random_state=0,C=100000))
    ])

    pipelineFinal.fit(x_train, train_labels);
    pred_train = pipelineFinal.predict(x_train);
    pred_proba_train = pipelineFinal.predict_proba(x_train);
    pred_test = pipelineFinal.predict(x_test);
    pred_proba_test = pipelineFinal.predict_proba(x_test);

    def appendPrediction(predictions,classes_,index, pred,proba):
        for i,p, pr in  zip(index, pred, proba):
            predictions.append(dict(**{
                    'dataset':currentCorpus,
                    'problem':problem,
                    'model':'dymAA',
                    'row_index':i,
                    'pred':p,
                }, **{
                    cc:pr_ for cc,pr_ in zip(classes_, pr)
                })
            )

    appendPrediction(predictions,pipelineFinal.classes_, index_train, pred_train, pred_proba_train)
    appendPrediction(predictions,pipelineFinal.classes_, index_test, pred_test, pred_proba_test)
    

    resultFinal.append({
        'model':'0ensemble',
        'problem':problem,
        'language':df.query(f"problem == '{problem}'")['language'].unique()[0],
        'n_authors': len(set(train_labels)),
        'f1':round(f1_score(test_labels,pred_test,average='macro'),3),
        'accuracy':round(accuracy_score(test_labels,pred_test),3)
    })
# Out:
# problem00001
# sorted ['dist', 'char', 'dep']
# Iteration 1 Best model:     ['dist']                                                                      0.3333
# Iteration 1 current model:  ['dist', 'char']                                                              0.2333
# Iteration 1 current model:  ['dist', 'dep']                                                               0.1333
# Selected Model: ['dist']
#
# problem00002
# sorted ['w2v', 'dist', 'dep', 'word', 'pos', 'tag', 'char']
# Iteration 1 Best model:     ['w2v']                                                                       0.7333
# Iteration 1 current model:  ['w2v', 'dep']                                                                0.7333
# Iteration 1 current model:  ['w2v', 'tag']                                                                0.7333
# Iteration 1 current model:  ['w2v', 'word']                                                               0.4667
# Iteration 1 current model:  ['w2v', 'pos']                                                                0.4667
# Iteration 1 current model:  ['w2v', 'char']                                                               0.2333
# Iteration 1 current model:  ['w2v', 'dist']                                                               0.7333
# Selected Model: ['w2v']
#
# problem00003
# sorted ['word', 'char', 'dist', 'pos', 'tag', 'w2v', 'dep']
# Iteration 1 Best model:     ['word']                                                                      0.2667
# Iteration 1 current model:  ['word', 'dep']                                                               0.3000
# Iteration 1 current model:  ['word', 'dep', 'tag']                                                        0.2500
# Iteration 1 current model:  ['word', 'dep', 'pos']                                                        0.1000
# Iteration 1 current model:  ['word', 'dep', 'char']                                                       0.3400
# Iteration 1 current model:  ['word', 'dep', 'char', 'dist']                                               0.3400
# Iteration 1 current model:  ['word', 'dep', 'char', 'w2v']                                                0.2500
# Iteration 2 Best model:     ['word', 'dep', 'char']                                                       0.3400
# Iteration 2 current model:  ['word', 'dep', 'char', 'pos']                                                0.1667
# Iteration 2 current model:  ['word', 'dep', 'char', 'tag']                                                0.3400
# Iteration 2 current model:  ['word', 'dep', 'char', 'dist']                                               0.3400
# Selected Model: ['word', 'dep', 'char']
#
# problem00004
# sorted ['dist', 'word', 'w2v', 'char', 'tag', 'dep', 'pos']
# Iteration 1 Best model:     ['dist']                                                                      0.5167
# Iteration 1 current model:  ['dist', 'dep']                                                               0.5167
# Iteration 1 current model:  ['dist', 'tag']                                                               0.6500
# Iteration 1 current model:  ['dist', 'tag', 'word']                                                       0.3500
# Iteration 1 current model:  ['dist', 'tag', 'pos']                                                        0.2400
# Iteration 1 current model:  ['dist', 'tag', 'char']                                                       0.2000
# Iteration 1 current model:  ['dist', 'tag', 'w2v']                                                        0.3333
# Iteration 2 Best model:     ['dist', 'tag']                                                               0.6500
# Iteration 2 current model:  ['dist', 'tag', 'pos']                                                        0.2400
# Iteration 2 current model:  ['dist', 'tag', 'char']                                                       0.2000
# Iteration 2 current model:  ['dist', 'tag', 'word']                                                       0.3500
# Iteration 2 current model:  ['dist', 'tag', 'dep']                                                        0.5167
# Selected Model: ['dist', 'tag']
#
# problem00005
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# sorted ['char', 'dist', 'dep', 'word', 'w2v', 'pos', 'tag']
# Iteration 1 Best model:     ['char']                                                                      0.2083
# Iteration 1 current model:  ['char', 'dep']                                                               0.2083
# Iteration 1 current model:  ['char', 'tag']                                                               0.2083
# Iteration 1 current model:  ['char', 'word']                                                              0.1583
# Iteration 1 current model:  ['char', 'pos']                                                               0.2667
# Iteration 1 current model:  ['char', 'pos', 'dist']                                                       0.2667
# Iteration 1 current model:  ['char', 'pos', 'w2v']                                                        0.2117
# Iteration 2 Best model:     ['char', 'pos']                                                               0.2667
# Iteration 2 current model:  ['char', 'pos', 'tag']                                                        0.2667
# Iteration 2 current model:  ['char', 'pos', 'dist']                                                       0.2667
# Iteration 2 current model:  ['char', 'pos', 'word']                                                       0.2667
# Iteration 2 current model:  ['char', 'pos', 'dep']                                                        0.3167
# Iteration 3 Best model:     ['char', 'pos', 'dep']                                                        0.3167
# Iteration 3 current model:  ['char', 'pos', 'dep', 'tag']                                                 0.3167
# Iteration 3 current model:  ['char', 'pos', 'dep', 'dist']                                                0.3167
# Iteration 3 current model:  ['char', 'pos', 'dep', 'word']                                                0.2500
# Selected Model: ['char', 'pos', 'dep']
#
# problem00006
# sorted ['char', 'word', 'dist', 'tag', 'dep', 'w2v', 'pos']
# Iteration 1 Best model:     ['char']                                                                      0.4000
# Iteration 1 current model:  ['char', 'dep']                                                               0.4000
# Iteration 1 current model:  ['char', 'tag']                                                               0.4000
# Iteration 1 current model:  ['char', 'word']                                                              0.4000
# Iteration 1 current model:  ['char', 'pos']                                                               0.4083
# Iteration 1 current model:  ['char', 'pos', 'dist']                                                       0.4083
# Iteration 1 current model:  ['char', 'pos', 'w2v']                                                        0.4000
# Iteration 2 Best model:     ['char', 'pos']                                                               0.4083
# Iteration 2 current model:  ['char', 'pos', 'tag']                                                        0.4083
# Iteration 2 current model:  ['char', 'pos', 'dist']                                                       0.4083
# Iteration 2 current model:  ['char', 'pos', 'word']                                                       0.4000
# Iteration 2 current model:  ['char', 'pos', 'dep']                                                        0.4083
# Selected Model: ['char', 'pos']
#
# problem00007
# sorted ['char', 'dist', 'word', 'pos', 'tag', 'w2v', 'dep']
# Iteration 1 Best model:     ['char']                                                                      0.1200
# Iteration 1 current model:  ['char', 'dep']                                                               0.1200
# Iteration 1 current model:  ['char', 'tag']                                                               0.1200
# Iteration 1 current model:  ['char', 'word']                                                              0.1000
# Iteration 1 current model:  ['char', 'pos']                                                               0.1000
# Iteration 1 current model:  ['char', 'dist']                                                              0.1200
# Iteration 1 current model:  ['char', 'w2v']                                                               0.1067
# Selected Model: ['char']
#
# problem00008
# sorted ['dist', 'word', 'w2v', 'char', 'dep', 'pos', 'tag']
# Iteration 1 Best model:     ['dist']                                                                      0.1247
# Iteration 1 current model:  ['dist', 'dep']                                                               0.1173
# Iteration 1 current model:  ['dist', 'tag']                                                               0.1160
# Iteration 1 current model:  ['dist', 'word']                                                              0.1033
# Iteration 1 current model:  ['dist', 'pos']                                                               0.1833
# Iteration 1 current model:  ['dist', 'pos', 'char']                                                       0.0613
# Iteration 1 current model:  ['dist', 'pos', 'w2v']                                                        0.1233
# Iteration 2 Best model:     ['dist', 'pos']                                                               0.1833
# Iteration 2 current model:  ['dist', 'pos', 'tag']                                                        0.1867
# Iteration 2 current model:  ['dist', 'pos', 'tag', 'char']                                                0.0613
# Iteration 2 current model:  ['dist', 'pos', 'tag', 'word']                                                0.0967
# Iteration 2 current model:  ['dist', 'pos', 'tag', 'dep']                                                 0.1867
# Iteration 3 Best model:     ['dist', 'pos', 'tag']                                                        0.1867
# Iteration 3 current model:  ['dist', 'pos', 'tag', 'char']                                                0.0613
# Iteration 3 current model:  ['dist', 'pos', 'tag', 'word']                                                0.0967
# Selected Model: ['dist', 'pos', 'tag']
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# problem00009
# sorted ['char', 'word', 'dist', 'pos', 'tag', 'w2v', 'dep']
# Iteration 1 Best model:     ['char']                                                                      0.7333
# Iteration 1 current model:  ['char', 'dep']                                                               0.4667
# Iteration 1 current model:  ['char', 'tag']                                                               0.7333
# Iteration 1 current model:  ['char', 'word']                                                              0.7333
# Iteration 1 current model:  ['char', 'pos']                                                               0.7333
# Iteration 1 current model:  ['char', 'dist']                                                              0.7333
# Iteration 1 current model:  ['char', 'w2v']                                                               0.4667
# Selected Model: ['char']
#
# problem00010
# sorted ['dist', 'pos', 'tag', 'dep', 'w2v', 'char', 'word']
# Iteration 1 Best model:     ['dist']                                                                      1.0000
# Iteration 1 current model:  ['dist', 'dep']                                                               0.7333
# Iteration 1 current model:  ['dist', 'tag']                                                               1.0000
# Iteration 1 current model:  ['dist', 'word']                                                              1.0000
# Iteration 1 current model:  ['dist', 'pos']                                                               0.7333
# Iteration 1 current model:  ['dist', 'char']                                                              0.5000
# Iteration 1 current model:  ['dist', 'w2v']                                                               0.5333
# Selected Model: ['dist']
#
# problem00011
# sorted ['dist', 'char', 'pos', 'dep', 'tag', 'w2v', 'word']
# Iteration 1 Best model:     ['dist']                                                                      1.0000
# Iteration 1 current model:  ['dist', 'dep']                                                               0.7333
# Iteration 1 current model:  ['dist', 'tag']                                                               1.0000
# Iteration 1 current model:  ['dist', 'word']                                                              0.7333
# Iteration 1 current model:  ['dist', 'pos']                                                               0.5000
# Iteration 1 current model:  ['dist', 'char']                                                              1.0000
# Iteration 1 current model:  ['dist', 'w2v']                                                               0.4667
# Selected Model: ['dist']
#
# problem00012
# sorted ['word', 'dist', 'char', 'w2v', 'pos', 'dep', 'tag']
# Iteration 1 Best model:     ['word']                                                                      1.0000
# Iteration 1 current model:  ['word', 'dep']                                                               1.0000
# Iteration 1 current model:  ['word', 'tag']                                                               1.0000
# Iteration 1 current model:  ['word', 'pos']                                                               0.7333
# Iteration 1 current model:  ['word', 'char']                                                              0.7333
# Iteration 1 current model:  ['word', 'dist']                                                              1.0000
# Iteration 1 current model:  ['word', 'w2v']                                                               0.7333
# Selected Model: ['word']
#
# problem00013
# sorted ['char', 'tag', 'dep', 'word', 'dist', 'w2v', 'pos']
# Iteration 1 Best model:     ['char']                                                                      1.0000
# Iteration 1 current model:  ['char', 'dep']                                                               1.0000
# Iteration 1 current model:  ['char', 'tag']                                                               1.0000
# Iteration 1 current model:  ['char', 'word']                                                              1.0000
# Iteration 1 current model:  ['char', 'pos']                                                               0.7333
# Iteration 1 current model:  ['char', 'dist']                                                              1.0000
# Iteration 1 current model:  ['char', 'w2v']                                                               1.0000
# Selected Model: ['char']
#
# problem00014
# sorted ['char', 'word', 'dist', 'pos', 'tag', 'dep', 'w2v']
# Iteration 1 Best model:     ['char']                                                                      1.0000
# Iteration 1 current model:  ['char', 'dep']                                                               1.0000
# Iteration 1 current model:  ['char', 'tag']                                                               1.0000
# Iteration 1 current model:  ['char', 'word']                                                              1.0000
# Iteration 1 current model:  ['char', 'pos']                                                               1.0000
# Iteration 1 current model:  ['char', 'dist']                                                              1.0000
# Iteration 1 current model:  ['char', 'w2v']                                                               1.0000
# Selected Model: ['char']
#
# problem00015
# sorted ['word', 'char', 'tag', 'dist', 'dep', 'pos', 'w2v']
# Iteration 1 Best model:     ['word']                                                                      0.2833
# Iteration 1 current model:  ['word', 'dep']                                                               0.2833
# Iteration 1 current model:  ['word', 'tag']                                                               0.3000
# Iteration 1 current model:  ['word', 'tag', 'pos']                                                        0.2667
# Iteration 1 current model:  ['word', 'tag', 'char']                                                       0.2333
# Iteration 1 current model:  ['word', 'tag', 'dist']                                                       0.3000
# Iteration 1 current model:  ['word', 'tag', 'w2v']                                                        0.3333
# Iteration 2 Best model:     ['word', 'tag', 'w2v']                                                        0.3333
# Iteration 2 current model:  ['word', 'tag', 'w2v', 'pos']                                                 0.3333
# Iteration 2 current model:  ['word', 'tag', 'w2v', 'char']                                                0.3333
# Iteration 2 current model:  ['word', 'tag', 'w2v', 'dist']                                                0.4333
# Iteration 2 current model:  ['word', 'tag', 'w2v', 'dist', 'dep']                                         0.4333
# Iteration 3 Best model:     ['word', 'tag', 'w2v', 'dist']                                                0.4333
# Iteration 3 current model:  ['word', 'tag', 'w2v', 'dist', 'pos']                                         0.3333
# Iteration 3 current model:  ['word', 'tag', 'w2v', 'dist', 'char']                                        0.3333
# Selected Model: ['word', 'tag', 'w2v', 'dist']
#
# problem00016
# sorted ['char', 'dist', 'w2v', 'tag', 'word', 'pos', 'dep']
# Iteration 1 Best model:     ['char']                                                                      0.8667
# Iteration 1 current model:  ['char', 'dep']                                                               0.8667
# Iteration 1 current model:  ['char', 'tag']                                                               0.8667
# Iteration 1 current model:  ['char', 'word']                                                              0.7333
# Iteration 1 current model:  ['char', 'pos']                                                               0.8667
# Iteration 1 current model:  ['char', 'dist']                                                              0.8667
# Iteration 1 current model:  ['char', 'w2v']                                                               0.6333
# Selected Model: ['char']
#
# problem00017
# sorted ['pos', 'char', 'dist', 'tag', 'w2v', 'word', 'dep']
# Iteration 1 Best model:     ['pos']                                                                       0.8667
# Iteration 1 current model:  ['pos', 'dep']                                                                0.8667
# Iteration 1 current model:  ['pos', 'tag']                                                                1.0000
# Iteration 1 current model:  ['pos', 'tag', 'word']                                                        1.0000
# Iteration 1 current model:  ['pos', 'tag', 'char']                                                        0.8667
# Iteration 1 current model:  ['pos', 'tag', 'dist']                                                        0.7333
# Iteration 1 current model:  ['pos', 'tag', 'w2v']                                                         0.8667
# Iteration 2 Best model:     ['pos', 'tag']                                                                1.0000
# Iteration 2 current model:  ['pos', 'tag', 'char']                                                        0.8667
# Iteration 2 current model:  ['pos', 'tag', 'dist']                                                        0.7333
# Iteration 2 current model:  ['pos', 'tag', 'word']                                                        1.0000
# Iteration 2 current model:  ['pos', 'tag', 'dep']                                                         0.8667
# Selected Model: ['pos', 'tag']
#
# problem00018
# sorted ['dist', 'char', 'pos', 'word', 'w2v', 'tag', 'dep']
# Iteration 1 Best model:     ['dist']                                                                      0.8667
# Iteration 1 current model:  ['dist', 'dep']                                                               0.6167
# Iteration 1 current model:  ['dist', 'tag']                                                               0.8667
# Iteration 1 current model:  ['dist', 'word']                                                              0.6167
# Iteration 1 current model:  ['dist', 'pos']                                                               0.6667
# Iteration 1 current model:  ['dist', 'char']                                                              0.6333
# Iteration 1 current model:  ['dist', 'w2v']                                                               0.5000
# Selected Model: ['dist']
#
# problem00019
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# sorted ['char', 'dist', 'word', 'pos', 'w2v', 'dep', 'tag']
# Iteration 1 Best model:     ['char']                                                                      1.0000
# Iteration 1 current model:  ['char', 'dep']                                                               1.0000
# Iteration 1 current model:  ['char', 'tag']                                                               1.0000
# Iteration 1 current model:  ['char', 'word']                                                              1.0000
# Iteration 1 current model:  ['char', 'pos']                                                               1.0000
# Iteration 1 current model:  ['char', 'dist']                                                              1.0000
# Iteration 1 current model:  ['char', 'w2v']                                                               1.0000
# Selected Model: ['char']
#
# problem00020
# sorted ['dist', 'tag', 'char', 'pos', 'w2v', 'dep', 'word']
# Iteration 1 Best model:     ['dist']                                                                      1.0000
# Iteration 1 current model:  ['dist', 'dep']                                                               1.0000
# Iteration 1 current model:  ['dist', 'tag']                                                               1.0000
# Iteration 1 current model:  ['dist', 'word']                                                              1.0000
# Iteration 1 current model:  ['dist', 'pos']                                                               1.0000
# Iteration 1 current model:  ['dist', 'char']                                                              1.0000
# Iteration 1 current model:  ['dist', 'w2v']                                                               0.8667
# Selected Model: ['dist']
#
# problem00021
# sorted ['char', 'dist', 'tag', 'w2v', 'dep', 'word', 'pos']
# Iteration 1 Best model:     ['char']                                                                      0.4167
# Iteration 1 current model:  ['char', 'dep']                                                               0.3750
# Iteration 1 current model:  ['char', 'tag']                                                               0.4167
# Iteration 1 current model:  ['char', 'word']                                                              0.3867
# Iteration 1 current model:  ['char', 'pos']                                                               0.3367
# Iteration 1 current model:  ['char', 'dist']                                                              0.4167
# Iteration 1 current model:  ['char', 'w2v']                                                               0.3833
# Selected Model: ['char']
#
# problem00022
# sorted ['dist', 'char', 'tag', 'word', 'w2v', 'pos', 'dep']
# Iteration 1 Best model:     ['dist']                                                                      0.8000
# Iteration 1 current model:  ['dist', 'dep']                                                               0.7583
# Iteration 1 current model:  ['dist', 'tag']                                                               0.7500
# Iteration 1 current model:  ['dist', 'word']                                                              0.8833
# Iteration 1 current model:  ['dist', 'word', 'pos']                                                       0.6833
# Iteration 1 current model:  ['dist', 'word', 'char']                                                      0.8667
# Iteration 1 current model:  ['dist', 'word', 'w2v']                                                       0.6000
# Iteration 2 Best model:     ['dist', 'word']                                                              0.8833
# Iteration 2 current model:  ['dist', 'word', 'pos']                                                       0.6833
# Iteration 2 current model:  ['dist', 'word', 'tag']                                                       0.8667
# Iteration 2 current model:  ['dist', 'word', 'char']                                                      0.8667
# Iteration 2 current model:  ['dist', 'word', 'dep']                                                       0.8667
# Selected Model: ['dist', 'word']
#
# problem00023
# sorted ['char', 'dist', 'word', 'w2v', 'tag', 'pos', 'dep']
# Iteration 1 Best model:     ['char']                                                                      0.8667
# Iteration 1 current model:  ['char', 'dep']                                                               0.8167
# Iteration 1 current model:  ['char', 'tag']                                                               0.8667
# Iteration 1 current model:  ['char', 'word']                                                              0.8667
# Iteration 1 current model:  ['char', 'pos']                                                               0.8167
# Iteration 1 current model:  ['char', 'dist']                                                              1.0000
# Iteration 1 current model:  ['char', 'dist', 'w2v']                                                       0.9333
# Iteration 2 Best model:     ['char', 'dist']                                                              1.0000
# Iteration 2 current model:  ['char', 'dist', 'pos']                                                       1.0000
# Iteration 2 current model:  ['char', 'dist', 'tag']                                                       1.0000
# Iteration 2 current model:  ['char', 'dist', 'word']                                                      1.0000
# Iteration 2 current model:  ['char', 'dist', 'dep']                                                       0.9333
# Selected Model: ['char', 'dist']
#
# problem00024
# sorted ['char', 'word', 'dist', 'tag', 'w2v', 'pos', 'dep']
# Iteration 1 Best model:     ['char']                                                                      0.5200
# Iteration 1 current model:  ['char', 'dep']                                                               0.4667
# Iteration 1 current model:  ['char', 'tag']                                                               0.4667
# Iteration 1 current model:  ['char', 'word']                                                              0.5583
# Iteration 1 current model:  ['char', 'word', 'pos']                                                       0.5033
# Iteration 1 current model:  ['char', 'word', 'dist']                                                      0.5417
# Iteration 1 current model:  ['char', 'word', 'w2v']                                                       0.5167
# Iteration 2 Best model:     ['char', 'word']                                                              0.5583
# Iteration 2 current model:  ['char', 'word', 'pos']                                                       0.5033
# Iteration 2 current model:  ['char', 'word', 'tag']                                                       0.5583
# Iteration 2 current model:  ['char', 'word', 'dist']                                                      0.5417
# Iteration 2 current model:  ['char', 'word', 'dep']                                                       0.5583
# Selected Model: ['char', 'word']
#
# problem00025
# sorted ['char', 'word', 'dist', 'tag', 'w2v', 'pos', 'dep']
# Iteration 1 Best model:     ['char']                                                                      0.8667
# Iteration 1 current model:  ['char', 'dep']                                                               0.8667
# Iteration 1 current model:  ['char', 'tag']                                                               0.8667
# Iteration 1 current model:  ['char', 'word']                                                              0.8667
# Iteration 1 current model:  ['char', 'pos']                                                               0.8167
# Iteration 1 current model:  ['char', 'dist']                                                              0.9333
# Iteration 1 current model:  ['char', 'dist', 'w2v']                                                       0.8667
# Iteration 2 Best model:     ['char', 'dist']                                                              0.9333
# Iteration 2 current model:  ['char', 'dist', 'pos']                                                       0.8833
# Iteration 2 current model:  ['char', 'dist', 'tag']                                                       0.8833
# Iteration 2 current model:  ['char', 'dist', 'word']                                                      0.8833
# Iteration 2 current model:  ['char', 'dist', 'dep']                                                       0.8833
# Selected Model: ['char', 'dist']
#
# problem00026
# sorted ['char', 'dist', 'word', 'tag', 'pos', 'w2v', 'dep']
# Iteration 1 Best model:     ['char']                                                                      1.0000
# Iteration 1 current model:  ['char', 'dep']                                                               1.0000
# Iteration 1 current model:  ['char', 'tag']                                                               1.0000
# Iteration 1 current model:  ['char', 'word']                                                              0.9333
# Iteration 1 current model:  ['char', 'pos']                                                               0.9333
# Iteration 1 current model:  ['char', 'dist']                                                              1.0000
# Iteration 1 current model:  ['char', 'w2v']                                                               1.0000
# Selected Model: ['char']
#
# problem00027
# sorted ['char', 'word', 'dist', 'w2v', 'tag', 'dep']
# Iteration 1 Best model:     ['char']                                                                      0.3147
# Iteration 1 current model:  ['char', 'dep']                                                               0.3147
# Iteration 1 current model:  ['char', 'tag']                                                               0.3147
# Iteration 1 current model:  ['char', 'word']                                                              0.3213
# Iteration 1 current model:  ['char', 'word', 'dist']                                                      0.3347
# Iteration 1 current model:  ['char', 'word', 'dist', 'w2v']                                               0.2813
# Iteration 2 Best model:     ['char', 'word', 'dist']                                                      0.3347
# Iteration 2 current model:  ['char', 'word', 'dist', 'tag']                                               0.3413
# Iteration 2 current model:  ['char', 'word', 'dist', 'tag', 'dep']                                        0.3480
# Iteration 3 Best model:     ['char', 'word', 'dist', 'tag', 'dep']                                        0.3480
# Selected Model: ['char', 'word', 'dist', 'tag', 'dep']
#
# problem00028
# sorted ['char', 'dist', 'word', 'tag', 'w2v', 'dep', 'pos']
# Iteration 1 Best model:     ['char']                                                                      0.7000
# Iteration 1 current model:  ['char', 'dep']                                                               0.7133
# Iteration 1 current model:  ['char', 'dep', 'tag']                                                        0.7200
# Iteration 1 current model:  ['char', 'dep', 'word']                                                       0.6733
# Iteration 1 current model:  ['char', 'dep', 'pos']                                                        0.6033
# Iteration 1 current model:  ['char', 'dep', 'dist']                                                       0.7733
# Iteration 1 current model:  ['char', 'dep', 'dist', 'w2v']                                                0.6700
# Iteration 2 Best model:     ['char', 'dep', 'dist']                                                       0.7733
# Iteration 2 current model:  ['char', 'dep', 'dist', 'pos']                                                0.7100
# Iteration 2 current model:  ['char', 'dep', 'dist', 'tag']                                                0.7600
# Iteration 2 current model:  ['char', 'dep', 'dist', 'word']                                               0.7433
# Selected Model: ['char', 'dep', 'dist']
#
# problem00029
# sorted ['char', 'dist', 'word', 'tag', 'w2v', 'pos', 'dep']
# Iteration 1 Best model:     ['char']                                                                      0.6800
# Iteration 1 current model:  ['char', 'dep']                                                               0.6667
# Iteration 1 current model:  ['char', 'tag']                                                               0.6933
# Iteration 1 current model:  ['char', 'tag', 'word']                                                       0.6633
# Iteration 1 current model:  ['char', 'tag', 'pos']                                                        0.7067
# Iteration 1 current model:  ['char', 'tag', 'pos', 'dist']                                                0.7767
# Iteration 1 current model:  ['char', 'tag', 'pos', 'dist', 'w2v']                                         0.7267
# Iteration 2 Best model:     ['char', 'tag', 'pos', 'dist']                                                0.7767
# Iteration 2 current model:  ['char', 'tag', 'pos', 'dist', 'word']                                        0.8267
# Iteration 2 current model:  ['char', 'tag', 'pos', 'dist', 'word', 'dep']                                 0.8267
# Iteration 3 Best model:     ['char', 'tag', 'pos', 'dist', 'word']                                        0.8267
# Selected Model: ['char', 'tag', 'pos', 'dist', 'word']
#
# problem00030
# sorted ['char', 'word', 'dist', 'w2v', 'tag', 'pos', 'dep']
# Iteration 1 Best model:     ['char']                                                                      0.4313
# Iteration 1 current model:  ['char', 'dep']                                                               0.4313
# Iteration 1 current model:  ['char', 'tag']                                                               0.4313
# Iteration 1 current model:  ['char', 'word']                                                              0.4547
# Iteration 1 current model:  ['char', 'word', 'pos']                                                       0.4333
# Iteration 1 current model:  ['char', 'word', 'dist']                                                      0.5013
# Iteration 1 current model:  ['char', 'word', 'dist', 'w2v']                                               0.4567
# Iteration 2 Best model:     ['char', 'word', 'dist']                                                      0.5013
# Iteration 2 current model:  ['char', 'word', 'dist', 'pos']                                               0.4867
# Iteration 2 current model:  ['char', 'word', 'dist', 'tag']                                               0.5013
# Iteration 2 current model:  ['char', 'word', 'dist', 'dep']                                               0.5000
# Selected Model: ['char', 'word', 'dist']
#
# problem00031
# sorted ['char', 'word', 'dist', 'w2v', 'tag', 'pos', 'dep']
# Iteration 1 Best model:     ['char']                                                                      0.6747
# Iteration 1 current model:  ['char', 'dep']                                                               0.6733
# Iteration 1 current model:  ['char', 'tag']                                                               0.6980
# Iteration 1 current model:  ['char', 'tag', 'word']                                                       0.6767
# Iteration 1 current model:  ['char', 'tag', 'pos']                                                        0.6333
# Iteration 1 current model:  ['char', 'tag', 'dist']                                                       0.7247
# Iteration 1 current model:  ['char', 'tag', 'dist', 'w2v']                                                0.7100
# Iteration 2 Best model:     ['char', 'tag', 'dist']                                                       0.7247
# Iteration 2 current model:  ['char', 'tag', 'dist', 'pos']                                                0.6567
# Iteration 2 current model:  ['char', 'tag', 'dist', 'word']                                               0.7433
# Iteration 2 current model:  ['char', 'tag', 'dist', 'word', 'dep']                                        0.7433
# Iteration 3 Best model:     ['char', 'tag', 'dist', 'word']                                               0.7433
# Iteration 3 current model:  ['char', 'tag', 'dist', 'word', 'pos']                                        0.6900
# Selected Model: ['char', 'tag', 'dist', 'word']
#
# problem00032
# sorted ['char', 'word', 'dist', 'tag', 'w2v', 'pos', 'dep']
# Iteration 1 Best model:     ['char']                                                                      0.9000
# Iteration 1 current model:  ['char', 'dep']                                                               0.9200
# Iteration 1 current model:  ['char', 'dep', 'tag']                                                        0.9467
# Iteration 1 current model:  ['char', 'dep', 'tag', 'word']                                                0.9733
# Iteration 1 current model:  ['char', 'dep', 'tag', 'word', 'pos']                                         0.9467
# Iteration 1 current model:  ['char', 'dep', 'tag', 'word', 'dist']                                        0.9733
# Iteration 1 current model:  ['char', 'dep', 'tag', 'word', 'w2v']                                         0.9200
# Iteration 2 Best model:     ['char', 'dep', 'tag', 'word']                                                0.9733
# Iteration 2 current model:  ['char', 'dep', 'tag', 'word', 'pos']                                         0.9467
# Iteration 2 current model:  ['char', 'dep', 'tag', 'word', 'dist']                                        0.9733
# Selected Model: ['char', 'dep', 'tag', 'word']

# %%
pd.DataFrame(predictions)
# Out:
#         dataset       problem  ... candidate00049  candidate00050
# 0      socialaa  problem00001  ...            nan             nan
# 1      socialaa  problem00001  ...            nan             nan
# 2      socialaa  problem00001  ...            nan             nan
# 3      socialaa  problem00001  ...            nan             nan
# 4      socialaa  problem00001  ...            nan             nan
# ...         ...           ...  ...            ...             ...
# 21075  socialaa  problem00032  ...         0.0000          0.0000
# 21076  socialaa  problem00032  ...         0.0238          0.0131
# 21077  socialaa  problem00032  ...         0.0000          0.0000
# 21078  socialaa  problem00032  ...         0.9882          0.0002
# 21079  socialaa  problem00032  ...         0.0034          0.8194
#
# [21080 rows x 55 columns]

# %%
pd.concat([dfMetric, pd.DataFrame(resultFinal)]).fillna(value=0) \
    .pivot(index='problem',columns='model',values=['f1','accuracy']).fillna(0)\
    .style.background_gradient(subset=['f1'], axis=1, cmap=plt.cm.Blues)\
    .background_gradient(subset=['accuracy'], axis=1, cmap=plt.cm.Greens)\
    .format('{:,.2f}'.format)
# Out:
# <style  type="text/css" >
# #T_66fe1656_193c_11eb_8c7c_0242ac1c0002row0_col0,#T_66fe1656_193c_11eb_8c7c_0242ac1c0002row0_col3,#T_66fe1656_193c_11eb_8c7c_0242ac1c0002row1_col0,#T_66fe1656_193c_11eb_8c7c_0242ac1c0002row1_col6,#T_66fe1656_193c_11eb_8c7c_0242ac1c0002row2_col0,#T_66fe1656_193c_11eb_8c7c_0242ac1c0002row2_col1,#T_66fe1656_193c_11eb_8c7c_0242ac1c0002row3_col3,#T_66fe1656_193c_11eb_8c7c_0242ac1c0002row4_col0,#T_66fe1656_193c_11eb_8c7c_0242ac1c0002row5_col0,#T_66fe1656_193c_11eb_8c7c_0242ac1c0002row5_col1,#T_66fe1656_193c_11eb_8c7c_0242ac1c0002row6_col3,#T_66fe1656_193c_11eb_8c7c_0242ac1c0002row7_col3,#T_66fe1656_193c_11eb_8c7c_0242ac1c0002row8_col0,#T_66fe1656_193c_11eb_8c7c_0242ac1c0002row8_col1,#T_66fe1656_193c_11eb_8c7c_0242ac1c0002row8_col3,#T_66fe1656_193c_11eb_8c7c_0242ac1c0002row8_col4,#T_66fe1656_193c_11eb_8c7c_0242ac1c0002row8_col5,#T_66fe1656_193c_11eb_8c7c_0242ac1c0002row8_col7,#T_66fe1656_193c_11eb_8c7c_0242ac1c0002row9_col0,#T_66fe1656_193c_11eb_8c7c_0242ac1c0002row9_col3,#T_66fe1656_193c_11eb_8c7c_0242ac1c0002row10_col0,#T_66fe1656_193c_11eb_8c7c_0242ac1c0002row10_col3,#T_66fe1656_193c_11eb_8c7c_0242ac1c0002row11_col0,#T_66fe1656_193c_11eb_8c7c_0242ac1c0002row11_col7,#T_66fe1656_193c_11eb_8c7c_0242ac1c0002row12_col0,#T_66fe1656_193c_11eb_8c7c_0242ac1c0002row12_col1,#T_66fe1656_193c_11eb_8c7c_0242ac1c0002row12_col2,#T_66fe1656_193c_11eb_8c7c_0242ac1c0002row12_col5,#T_66fe1656_193c_11eb_8c7c_0242ac1c0002row13_col0,#T_66fe1656_193c_11eb_8c7c_0242ac1c0002row13_col1,#T_66fe1656_193c_11eb_8c7c_0242ac1c0002row13_col2,#T_66fe1656_193c_11eb_8c7c_0242ac1c0002row13_col3,#T_66fe1656_193c_11eb_8c7c_0242ac1c0002row13_col4,#T_66fe1656_193c_11eb_8c7c_0242ac1c0002row13_col5,#T_66fe1656_193c_11eb_8c7c_0242ac1c0002row13_col7,#T_66fe1656_193c_11eb_8c7c_0242ac1c0002row14_col0,#T_66fe1656_193c_11eb_8c7c_0242ac1c0002row15_col0,#T_66fe1656_193c_11eb_8c7c_0242ac1c0002row15_col1,#T_66fe1656_193c_11eb_8c7c_0242ac1c0002row16_col0,#T_66fe1656_193c_11eb_8c7c_0242ac1c0002row16_col4,#T_66fe1656_193c_11eb_8c7c_0242ac1c0002row17_col0,#T_66fe1656_193c_11eb_8c7c_0242ac1c0002row18_col0,#T_66fe1656_193c_11eb_8c7c_0242ac1c0002row18_col1,#T_66fe1656_193c_11eb_8c7c_0242ac1c0002row19_col0,#T_66fe1656_193c_11eb_8c7c_0242ac1c0002row19_col3,#T_66fe1656_193c_11eb_8c7c_0242ac1c0002row19_col5,#T_66fe1656_193c_11eb_8c7c_0242ac1c0002row20_col0,#T_66fe1656_193c_11eb_8c7c_0242ac1c0002row20_col1,#T_66fe1656_193c_11eb_8c7c_0242ac1c0002row21_col0,#T_66fe1656_193c_11eb_8c7c_0242ac1c0002row22_col0,#T_66fe1656_193c_11eb_8c7c_0242ac1c0002row23_col1,#T_66fe1656_193c_11eb_8c7c_0242ac1c0002row24_col0,#T_66fe1656_193c_11eb_8c7c_0242ac1c0002row25_col0,#T_66fe1656_193c_11eb_8c7c_0242ac1c0002row25_col1,#T_66fe1656_193c_11eb_8c7c_0242ac1c0002row25_col3,#T_66fe1656_193c_11eb_8c7c_0242ac1c0002row26_col0,#T_66fe1656_193c_11eb_8c7c_0242ac1c0002row27_col0,#T_66fe1656_193c_11eb_8c7c_0242ac1c0002row28_col0,#T_66fe1656_193c_11eb_8c7c_0242ac1c0002row29_col0,#T_66fe1656_193c_11eb_8c7c_0242ac1c0002row30_col0,#T_66fe1656_193c_11eb_8c7c_0242ac1c0002row31_col0{
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }#T_66fe1656_193c_11eb_8c7c_0242ac1c0002row0_col1{
#             background-color:  #2e7ebc;
#             color:  #000000;
#         }#T_66fe1656_193c_11eb_8c7c_0242ac1c0002row0_col2{
#             background-color:  #94c4df;
#             color:  #000000;
#         }#T_66fe1656_193c_11eb_8c7c_0242ac1c0002row0_col4,#T_66fe1656_193c_11eb_8c7c_0242ac1c0002row5_col5,#T_66fe1656_193c_11eb_8c7c_0242ac1c0002row15_col5{
#             background-color:  #b7d4ea;
#             color:  #000000;
#         }#T_66fe1656_193c_11eb_8c7c_0242ac1c0002row0_col5,#T_66fe1656_193c_11eb_8c7c_0242ac1c0002row0_col6,#T_66fe1656_193c_11eb_8c7c_0242ac1c0002row0_col7,#T_66fe1656_193c_11eb_8c7c_0242ac1c0002row1_col1,#T_66fe1656_193c_11eb_8c7c_0242ac1c0002row2_col2,#T_66fe1656_193c_11eb_8c7c_0242ac1c0002row3_col4,#T_66fe1656_193c_11eb_8c7c_0242ac1c0002row4_col5,#T_66fe1656_193c_11eb_8c7c_0242ac1c0002row5_col4,#T_66fe1656_193c_11eb_8c7c_0242ac1c0002row6_col6,#T_66fe1656_193c_11eb_8c7c_0242ac1c0002row7_col4,#T_66fe1656_193c_11eb_8c7c_0242ac1c0002row8_col2,#T_66fe1656_193c_11eb_8c7c_0242ac1c0002row9_col7,#T_66fe1656_193c_11eb_8c7c_0242ac1c0002row10_col7,#T_66fe1656_193c_11eb_8c7c_0242ac1c0002row11_col5,#T_66fe1656_193c_11eb_8c7c_0242ac1c0002row12_col4,#T_66fe1656_193c_11eb_8c7c_0242ac1c0002row13_col6,#T_66fe1656_193c_11eb_8c7c_0242ac1c0002row14_col6,#T_66fe1656_193c_11eb_8c7c_0242ac1c0002row15_col2,#T_66fe1656_193c_11eb_8c7c_0242ac1c0002row16_col2,#T_66fe1656_193c_11eb_8c7c_0242ac1c0002row17_col2,#T_66fe1656_193c_11eb_8c7c_0242ac1c0002row18_col5,#T_66fe1656_193c_11eb_8c7c_0242ac1c0002row19_col7,#T_66fe1656_193c_11eb_8c7c_0242ac1c0002row20_col4,#T_66fe1656_193c_11eb_8c7c_0242ac1c0002row21_col2,#T_66fe1656_193c_11eb_8c7c_0242ac1c0002row22_col2,#T_66fe1656_193c_11eb_8c7c_0242ac1c0002row23_col2,#T_66fe1656_193c_11eb_8c7c_0242ac1c0002row24_col2,#T_66fe1656_193c_11eb_8c7c_0242ac1c0002row25_col2,#T_66fe1656_193c_11eb_8c7c_0242ac1c0002row26_col4,#T_66fe1656_193c_11eb_8c7c_0242ac1c0002row27_col4,#T_66fe1656_193c_11eb_8c7c_0242ac1c0002row28_col2,#T_66fe1656_193c_11eb_8c7c_0242ac1c0002row29_col2,#T_66fe1656_193c_11eb_8c7c_0242ac1c0002row30_col2,#T_66fe1656_193c_11eb_8c7c_0242ac1c0002row31_col2{
#             background-color:  #f7fbff;
#             color:  #000000;
#         }#T_66fe1656_193c_11eb_8c7c_0242ac1c0002row0_col8,#T_66fe1656_193c_11eb_8c7c_0242ac1c0002row0_col9,#T_66fe1656_193c_11eb_8c7c_0242ac1c0002row0_col11,#T_66fe1656_193c_11eb_8c7c_0242ac1c0002row1_col8,#T_66fe1656_193c_11eb_8c7c_0242ac1c0002row1_col14,#T_66fe1656_193c_11eb_8c7c_0242ac1c0002row2_col8,#T_66fe1656_193c_11eb_8c7c_0242ac1c0002row2_col9,#T_66fe1656_193c_11eb_8c7c_0242ac1c0002row3_col11,#T_66fe1656_193c_11eb_8c7c_0242ac1c0002row4_col8,#T_66fe1656_193c_11eb_8c7c_0242ac1c0002row5_col8,#T_66fe1656_193c_11eb_8c7c_0242ac1c0002row5_col9,#T_66fe1656_193c_11eb_8c7c_0242ac1c0002row6_col11,#T_66fe1656_193c_11eb_8c7c_0242ac1c0002row7_col11,#T_66fe1656_193c_11eb_8c7c_0242ac1c0002row8_col8,#T_66fe1656_193c_11eb_8c7c_0242ac1c0002row8_col9,#T_66fe1656_193c_11eb_8c7c_0242ac1c0002row8_col11,#T_66fe1656_193c_11eb_8c7c_0242ac1c0002row8_col12,#T_66fe1656_193c_11eb_8c7c_0242ac1c0002row8_col13,#T_66fe1656_193c_11eb_8c7c_0242ac1c0002row8_col15,#T_66fe1656_193c_11eb_8c7c_0242ac1c0002row9_col8,#T_66fe1656_193c_11eb_8c7c_0242ac1c0002row9_col11,#T_66fe1656_193c_11eb_8c7c_0242ac1c0002row10_col8,#T_66fe1656_193c_11eb_8c7c_0242ac1c0002row10_col11,#T_66fe1656_193c_11eb_8c7c_0242ac1c0002row11_col8,#T_66fe1656_193c_11eb_8c7c_0242ac1c0002row11_col15,#T_66fe1656_193c_11eb_8c7c_0242ac1c0002row12_col8,#T_66fe1656_193c_11eb_8c7c_0242ac1c0002row12_col9,#T_66fe1656_193c_11eb_8c7c_0242ac1c0002row12_col10,#T_66fe1656_193c_11eb_8c7c_0242ac1c0002row12_col13,#T_66fe1656_193c_11eb_8c7c_0242ac1c0002row13_col8,#T_66fe1656_193c_11eb_8c7c_0242ac1c0002row13_col9,#T_66fe1656_193c_11eb_8c7c_0242ac1c0002row13_col10,#T_66fe1656_193c_11eb_8c7c_0242ac1c0002row13_col11,#T_66fe1656_193c_11eb_8c7c_0242ac1c0002row13_col12,#T_66fe1656_193c_11eb_8c7c_0242ac1c0002row13_col13,#T_66fe1656_193c_11eb_8c7c_0242ac1c0002row13_col15,#T_66fe1656_193c_11eb_8c7c_0242ac1c0002row14_col8,#T_66fe1656_193c_11eb_8c7c_0242ac1c0002row15_col8,#T_66fe1656_193c_11eb_8c7c_0242ac1c0002row15_col9,#T_66fe1656_193c_11eb_8c7c_0242ac1c0002row16_col8,#T_66fe1656_193c_11eb_8c7c_0242ac1c0002row16_col12,#T_66fe1656_193c_11eb_8c7c_0242ac1c0002row17_col8,#T_66fe1656_193c_11eb_8c7c_0242ac1c0002row18_col8,#T_66fe1656_193c_11eb_8c7c_0242ac1c0002row18_col9,#T_66fe1656_193c_11eb_8c7c_0242ac1c0002row19_col8,#T_66fe1656_193c_11eb_8c7c_0242ac1c0002row19_col11,#T_66fe1656_193c_11eb_8c7c_0242ac1c0002row19_col13,#T_66fe1656_193c_11eb_8c7c_0242ac1c0002row20_col8,#T_66fe1656_193c_11eb_8c7c_0242ac1c0002row20_col9,#T_66fe1656_193c_11eb_8c7c_0242ac1c0002row21_col8,#T_66fe1656_193c_11eb_8c7c_0242ac1c0002row22_col8,#T_66fe1656_193c_11eb_8c7c_0242ac1c0002row23_col8,#T_66fe1656_19

# %% [markdown]
# ### Latex version

# %%
print(pd.concat([dfMetric, pd.DataFrame(resultFinal)]).fillna(value=0) \
    .pivot(index='problem',columns='model',values='f1').reset_index()\
    .fillna(0).to_latex(index=False, float_format='{:,.2f}'.format))
# Out:
# \begin{tabular}{lrrrrrrrr}
# \toprule
#       problem &  0ensemble &  char &  dep &  dist &  pos &  tag &  w2v &  word \\
# \midrule
#  problem00001 &       0.33 &  0.23 & 0.13 &  0.33 & 0.10 & 0.00 & 0.00 &  0.00 \\
#  problem00002 &       0.73 &  0.08 & 0.30 &  0.50 & 0.13 & 0.10 & 0.73 &  0.13 \\
#  problem00003 &       0.34 &  0.34 & 0.05 &  0.13 & 0.10 & 0.07 & 0.07 &  0.27 \\
#  problem00004 &       0.31 &  0.20 & 0.27 &  0.65 & 0.07 & 0.22 & 0.23 &  0.35 \\
#  problem00005 &       0.30 &  0.22 & 0.12 &  0.15 & 0.08 & 0.07 & 0.10 &  0.11 \\
#  problem00006 &       0.40 &  0.40 & 0.14 &  0.25 & 0.08 & 0.18 & 0.15 &  0.31 \\
#  problem00007 &       0.10 &  0.12 & 0.10 &  0.20 & 0.07 & 0.07 & 0.06 &  0.08 \\
#  problem00008 &       0.16 &  0.07 & 0.08 &  0.18 & 0.03 & 0.07 & 0.08 &  0.08 \\
#  problem00009 &       0.73 &  0.73 & 0.33 &  0.73 & 0.73 & 0.73 & 0.47 &  0.73 \\
#  problem00010 &       1.00 &  0.50 & 0.53 &  1.00 & 0.73 & 0.53 & 0.53 &  0.28 \\
#  problem00011 &       1.00 &  0.73 & 0.33 &  1.00 & 0.50 & 0.30 & 0.27 &  0.23 \\
#  problem00012 &       1.00 &  0.73 & 0.47 &  0.73 & 0.47 & 0.33 & 0.73 &  1.00 \\
#  problem00013 &       1.00 &  1.00 & 1.00 &  0.73 & 0.53 & 1.00 & 0.73 &  0.73 \\
#  problem00014 &       1.00 &  1.00 & 1.00 &  1.00 & 1.00 & 1.00 & 0.73 &  1.00 \\
#  problem00015 &       0.43 &  0.23 & 0.24 &  0.32 & 0.07 & 0.23 & 0.04 &  0.23 \\
#  problem00016 &       0.87 &  0.87 & 0.20 &  0.65 & 0.23 & 0.40 & 0.45 &  0.50 \\
#  problem00017 &       0.87 &  0.80 & 0.17 &  0.73 & 0.87 & 0.73 & 0.60 &  0.60 \\
#  problem00018 &       1.00 &  0.63 & 0.13 &  0.87 & 0.53 & 0.21 & 0.42 &  0.37 \\
#  problem00019 &       1.00 &  1.00 & 0.62 &  0.87 & 0.87 & 0.50 & 0.87 &  0.87 \\
#  problem00020 &       1.00 &  0.87 & 0.73 &  1.00 & 0.87 & 1.00 & 0.75 &  0.63 \\
#  problem00021 &       0.42 &  0.42 & 0.20 &  0.36 & 0.17 & 0.24 & 0.27 &  0.18 \\
#  problem00022 &       0.88 &  0.57 & 0.13 &  0.80 & 0.23 & 0.49 & 0.38 &  0.45 \\
#  problem00023 &       1.00 &  0.87 & 0.26 &  0.80 & 0.53 & 0.57 & 0.63 &  0.71 \\
#  problem00024 &       0.50 &  0.52 & 0.18 &  0.33 & 0.20 & 0.30 & 0.24 &  0.36 \\
#  problem00025 &       0.93 &  0.87 & 0.28 &  0.68 & 0.33 & 0.64 & 0.53 &  0.77 \\
#  problem00026 &       1.00 &  1.00 & 0.51 &  1.00 & 0.61 & 0.73 & 0.56 &  0.75 \\
#  problem00027 &       0.32 &  0.32 & 0.07 &  0.20 & 0.00 & 0.16 & 0.17 &  0.17 \\
#  problem00028 &       0.72 &  0.70 & 0.23 &  0.63 & 0.19 & 0.33 & 0.35 &  0.42 \\
#  problem00029 &       0.80 &  0.68 & 0.17 &  0.67 & 0.32 & 0.41 & 0.40 &  0.57 \\
#  problem00030 &       0.50 &  0.43 & 0.05 &  0.33 & 0.19 & 0.18 & 0.21 &  0.35 \\
#  problem00031 &       0.74 &  0.66 & 0.15 &  0.47 & 0.20 & 0.36 & 0.29 &  0.66 \\
#  problem00032 &       0.97 &  0.90 & 0.42 &  0.75 & 0.45 & 0.61 & 0.61 &  0.83 \\
# \bottomrule
# \end{tabular}

# %%
# mean by model
print(pd.concat([dfMetric, pd.DataFrame(resultFinal)]).fillna(value=0) \
    .pivot(index='problem',columns='model',values='f1').reset_index().mean().to_frame().T\
     .to_latex(index=False, float_format='{:,.2f}'.format))
# Out:
# \begin{tabular}{rrrrrrrr}
# \toprule
#  0ensemble &  char &  dep &  dist &  pos &  tag &  w2v &  word \\
# \midrule
#       0.70 &  0.58 & 0.30 &  0.60 & 0.36 & 0.40 & 0.40 &  0.46 \\
# \bottomrule
# \end{tabular}

# %%
for problemIndex, problem in enumerate(df['problem'].unique()):
    lang = df.query(f"problem == '{problem}'")['language'].unique()[0]
    print(problem +' '+lang+' '+ str(bestModels[problemIndex]))
# Out:
# problem00001 en ['dist']
# problem00002 en ['w2v']
# problem00003 en ['word', 'dep', 'char']
# problem00004 en ['dist', 'tag']
# problem00005 en ['char', 'pos', 'dep']
# problem00006 en ['char', 'pos']
# problem00007 en ['char']
# problem00008 en ['dist', 'pos', 'tag']
# problem00009 en ['char']
# problem00010 en ['dist']
# problem00011 en ['dist']
# problem00012 en ['word']
# problem00013 en ['char']
# problem00014 en ['char']
# problem00015 en ['word', 'tag', 'w2v', 'dist']
# problem00016 en ['char']
# problem00017 en ['pos', 'tag']
# problem00018 en ['dist']
# problem00019 en ['char']
# problem00020 en ['dist']
# problem00021 en ['char']
# problem00022 en ['dist', 'word']
# problem00023 en ['char', 'dist']
# problem00024 en ['char', 'word']
# problem00025 en ['char', 'dist']
# problem00026 en ['char']
# problem00027 en ['char', 'word', 'dist', 'tag', 'dep']
# problem00028 en ['char', 'dep', 'dist']
# problem00029 en ['char', 'tag', 'pos', 'dist', 'word']
# problem00030 en ['char', 'word', 'dist']
# problem00031 en ['char', 'tag', 'dist', 'word']
# problem00032 en ['char', 'dep', 'tag', 'word']

# %%
pd.pivot_table(
    pd.concat([dfMetric, pd.DataFrame(resultFinal)]),
    index='model',
    columns='n_authors',
    values='f1',
    aggfunc='mean',
    fill_value=0).T
# Out:
# model      0ensemble   char    dep   dist    pos    tag    w2v   word
# n_authors
# 5             0.8499 0.6265 0.5124 0.7540 0.5249 0.4999 0.5249 0.5140
# 10            0.7268 0.6175 0.3009 0.6521 0.4501 0.4196 0.4280 0.4771
# 20            0.6795 0.6079 0.2280 0.5471 0.2794 0.4026 0.3598 0.4545
# 50            0.5394 0.4845 0.1584 0.4272 0.1821 0.2754 0.2694 0.3957

# %%
pd.pivot_table(
    pd.concat([dfMetric, pd.DataFrame(resultFinal)]),
    index='model',
    columns='language',
    values='f1',
    aggfunc='mean',
    fill_value=0)
# Out:
# language      en
# model
# 0ensemble 0.6989
# char      0.5841
# dep       0.2999
# dist      0.5951
# pos       0.3591
# tag       0.3994
# w2v       0.3955
# word      0.4603

# %%
pd.pivot_table(
    pd.concat([dfMetric, pd.DataFrame(resultFinal)]),
    index='model',
    columns=['language','n_authors'],
    values='f1',
    aggfunc='mean',
    fill_value=0)
# Out:
# language      en
# n_authors     5      10     20     50
# model
# 0ensemble 0.8499 0.7268 0.6795 0.5394
# char      0.6265 0.6175 0.6079 0.4845
# dep       0.5124 0.3009 0.2280 0.1584
# dist      0.7540 0.6521 0.5471 0.4272
# pos       0.5249 0.4501 0.2794 0.1821
# tag       0.4999 0.4196 0.4026 0.2754
# w2v       0.5249 0.4280 0.3598 0.2694
# word      0.5140 0.4771 0.4545 0.3957

# %%
pd.pivot_table(
    pd.concat([ pd.DataFrame(resultFinal)]),
    index='model',
    columns=['language','n_authors'],
    values='f1',
    aggfunc='mean',
    fill_value=0)
# Out:
# language      en
# n_authors     5      10     20     50
# model
# 0ensemble 0.8499 0.7268 0.6795 0.5394

# %%
pd.DataFrame(predictions).round(5).sort_values('row_index')
# Out:
#         dataset       problem  ... candidate00049  candidate00050
# 0      socialaa  problem00001  ...            nan             nan
# 1      socialaa  problem00001  ...            nan             nan
# 2      socialaa  problem00001  ...            nan             nan
# 3      socialaa  problem00001  ...            nan             nan
# 4      socialaa  problem00001  ...            nan             nan
# ...         ...           ...  ...            ...             ...
# 21075  socialaa  problem00032  ...         0.0000          0.0000
# 21076  socialaa  problem00032  ...         0.0238          0.0131
# 21077  socialaa  problem00032  ...         0.0000          0.0000
# 21078  socialaa  problem00032  ...         0.9882          0.0002
# 21079  socialaa  problem00032  ...         0.0034          0.8194
#
# [21080 rows x 55 columns]

# %% [markdown]
# ## Saving data

# %%
import pickle;
with open(pathjoin(outputDir,f'{currentCorpus}_parcial.pkl'),"wb") as f:
    pickle.dump(results,f)


pd.DataFrame(predictions)\
    .rename(columns={'index':'row_index'}).sort_values('row_index').round(5)\
    .to_csv(pathjoin(outputDir,currentCorpus+'_predictions.csv.zip'), index=False, compression='zip', encoding='utf-8')

# %%
def resultsToTable(results):
    temp = []
    def unfold(r, var):
        return [i for j in r[var] for i in j]
    for model in results:
        r = results[model];
        t = {
            'row_index': unfold(r,'index_train') +unfold(r,'index_test'),
            'pred': unfold(r,'pred_train') +unfold(r,'pred_test')
            
        }
        t['model'] = [model] * len(t['row_index'])
        t['dataset'] = [currentCorpus] * len(t['row_index'])
        
        temp.append(t)

    
    return pd.concat([pd.DataFrame(d) for d in temp]);
        

resultsToTable(results) \
    .merge(datasets[['row_index','problem']], on='row_index', how='left')\
    .to_csv(pathjoin(outputDir,currentCorpus+'_predictions_parcial.csv.zip'), index=False, compression='zip', encoding='utf-8')
