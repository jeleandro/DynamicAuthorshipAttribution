# %% [markdown]
# # AA lyrics

# %%
# %matplotlib inline

# %%
#python basic libs
import os;
from os.path import join as pathjoin;
import re;
import random;
import json;
from collections import defaultdict;
from pprint import pprint
from time import time

# %%
#data analysis libs
import numpy as np;
import pandas as pd;
import seaborn as sns;
import matplotlib.pyplot as plt;

# %%
#machine learning libs
#feature extraction
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn import feature_selection;

#preprocessing and transformation
from sklearn import preprocessing;
from sklearn.preprocessing import MaxAbsScaler;
from sklearn.decomposition import PCA;

from sklearn.base import BaseEstimator, ClassifierMixin

#classifiers
from sklearn.linear_model import LogisticRegression

#
from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import Pipeline

#model valuation
from sklearn.metrics import f1_score, precision_score, recall_score, accuracy_score;

# %% [markdown]
# NLP libraries

# %%
# !pip install spacy=='2.3' gensim
# Out:
# Requirement already satisfied: spacy==2.3 in /usr/local/lib/python3.6/dist-packages (2.3.0)
# Requirement already satisfied: gensim in /usr/local/lib/python3.6/dist-packages (3.6.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from spacy==2.3) (50.3.0)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from spacy==2.3) (0.4.1)
# Requirement already satisfied: thinc==7.4.1 in /usr/local/lib/python3.6/dist-packages (from spacy==2.3) (7.4.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.6/dist-packages (from spacy==2.3) (4.41.1)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /usr/local/lib/python3.6/dist-packages (from spacy==2.3) (1.0.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy==2.3) (2.0.3)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy==2.3) (3.0.2)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.6/dist-packages (from spacy==2.3) (1.18.5)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /usr/local/lib/python3.6/dist-packages (from spacy==2.3) (1.1.3)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.6/dist-packages (from spacy==2.3) (2.23.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.6/dist-packages (from spacy==2.3) (1.0.2)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy==2.3) (1.0.2)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from spacy==2.3) (0.8.0)
# Requirement already satisfied: scipy>=0.18.1 in /usr/local/lib/python3.6/dist-packages (from gensim) (1.4.1)
# Requirement already satisfied: smart-open>=1.2.1 in /usr/local/lib/python3.6/dist-packages (from gensim) (3.0.0)
# Requirement already satisfied: six>=1.5.0 in /usr/local/lib/python3.6/dist-packages (from gensim) (1.15.0)
# Requirement already satisfied: importlib-metadata>=0.20; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from catalogue<1.1.0,>=0.0.7->spacy==2.3) (2.0.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy==2.3) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy==2.3) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy==2.3) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy==2.3) (2020.6.20)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata>=0.20; python_version < "3.8"->catalogue<1.1.0,>=0.0.7->spacy==2.3) (3.3.1)

# %%
# !python -m spacy download pt  
#!python -m spacy download es
#!python -m spacy download it
# !python -m spacy download en
#!python -m spacy download fr
# Out:
# Requirement already satisfied: pt_core_news_sm==2.3.0 from https://github.com/explosion/spacy-models/releases/download/pt_core_news_sm-2.3.0/pt_core_news_sm-2.3.0.tar.gz#egg=pt_core_news_sm==2.3.0 in /usr/local/lib/python3.6/dist-packages (2.3.0)
# Requirement already satisfied: spacy<2.4.0,>=2.3.0 in /usr/local/lib/python3.6/dist-packages (from pt_core_news_sm==2.3.0) (2.3.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->pt_core_news_sm==2.3.0) (4.41.1)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->pt_core_news_sm==2.3.0) (1.1.3)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->pt_core_news_sm==2.3.0) (1.0.2)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->pt_core_news_sm==2.3.0) (2.0.3)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->pt_core_news_sm==2.3.0) (3.0.2)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->pt_core_news_sm==2.3.0) (0.8.0)
# Requirement already satisfied: thinc==7.4.1 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->pt_core_news_sm==2.3.0) (7.4.1)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->pt_core_news_sm==2.3.0) (1.18.5)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->pt_core_news_sm==2.3.0) (50.3.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->pt_core_news_sm==2.3.0) (1.0.2)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->pt_core_news_sm==2.3.0) (0.4.1)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->pt_core_news_sm==2.3.0) (1.0.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->pt_core_news_sm==2.3.0) (2.23.0)
# Requirement already satisfied: importlib-metadata>=0.20; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from catalogue<1.1.0,>=0.0.7->spacy<2.4.0,>=2.3.0->pt_core_news_sm==2.3.0) (2.0.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0,>=2.3.0->pt_core_news_sm==2.3.0) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0,>=2.3.0->pt_core_news_sm==2.3.0) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0,>=2.3.0->pt_core_news_sm==2.3.0) (2020.6.20)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0,>=2.3.0->pt_core_news_sm==2.3.0) (3.0.4)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata>=0.20; python_version < "3.8"->catalogue<1.1.0,>=0.0.7->spacy<2.4.0,>=2.3.0->pt_core_news_sm==2.3.0) (3.3.1)
# ✔ Download and installation successful
# You can now load the model via spacy.load('pt_core_news_sm')
# ✔ Linking successful
# /usr/local/lib/python3.6/dist-packages/pt_core_news_sm -->
# /usr/local/lib/python3.6/dist-packages/spacy/data/pt
# You can now load the model via spacy.load('pt')
# Requirement already satisfied: en_core_web_sm==2.3.0 from https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.3.0/en_core_web_sm-2.3.0.tar.gz#egg=en_core_web_sm==2.3.0 in /usr/local/lib/python3.6/dist-packages (2.3.0)
# Requirement already satisfied: spacy<2.4.0,>=2.3.0 in /usr/local/lib/python3.6/dist-packages (from en_core_web_sm==2.3.0) (2.3.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.0) (1.0.2)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.0) (1.0.0)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.0) (1.1.3)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.0) (3.0.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.0) (2.23.0)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.0) (0.8.0)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.0) (1.18.5)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.0) (0.4.1)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.0) (1.0.2)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.0) (2.0.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.0) (50.3.0)
# Requirement already satisfied: thinc==7.4.1 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.0) (7.4.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.0) (4.41.1)
# Requirement already satisfied: importlib-metadata>=0.20; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from catalogue<1.1.0,>=0.0.7->spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.0) (2.0.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.0) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.0) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.0) (2020.6.20)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.0) (2.10)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata>=0.20; python_version < "3.8"->catalogue<1.1.0,>=0.0.7->spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.0) (3.3.1)
# ✔ Download and installation successful
# You can now load the model via spacy.load('en_core_web_sm')
# ✔ Linking successful
# /usr/local/lib/python3.6/dist-packages/en_core_web_sm -->
# /usr/local/lib/python3.6/dist-packages/spacy/data/en
# You can now load the model via spacy.load('en')

# %%
import spacy;
import gensim
import logging
from gensim.models import KeyedVectors
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.CRITICAL)

# %%
from IPython.display import Markdown, display, HTML

# %% [markdown]
# libraries configurations

# %%
import warnings
from sklearn.exceptions import UndefinedMetricWarning
warnings.simplefilter(action='ignore', category=UndefinedMetricWarning)
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
np.set_printoptions(precision=4)
pd.options.display.float_format = '{:,.4f}'.format
sns.set(color_codes=True);

# %%
import platform;
import sklearn;
import scipy;

Markdown(
    "|%-15s|%-65s|\n"%("PACK","VERSION") +
    "|%-15s|%-65s|\n"%('-'*15,'-'*65) +
    ('\n'.join(
    "|%-15s|%-45s| " % (pack, version.strip())
    for pack, version in
    zip(['SO','NumPy','SciPy','Scikit-Learn','Seaborn','Spacy','Gensim'],
        [platform.platform(), np.__version__, scipy.__version__,
         sklearn.__version__, spacy.__version__, gensim.__version__])

)))
# Out:
# |PACK           |VERSION                                                          |
# |---------------|-----------------------------------------------------------------|
# |SO             |Linux-4.19.112+-x86_64-with-Ubuntu-18.04-bionic|
# |NumPy          |1.18.5                                       |
# |SciPy          |1.4.1                                        |
# |Scikit-Learn   |0.22.2.post1                                 |
# |Seaborn        |2.3.0                                        |
# |Spacy          |3.6.0                                        |

# %% [markdown]
# ### on google

# %%
from google.colab import drive, files
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
currentCorpus = 'lyrics';

# %%
baseDir = '/content/gdrive/My Drive/Colab Notebooks/AA'
outputDir= pathjoin(baseDir,'ensemble','output_ensemble');

os.makedirs(outputDir, exist_ok=True)

def transferCode(filename):
    with open(os.path.join(baseDir,'ensemble',filename)) as fin:
        with open(filename,'w') as fout:
            fout.write(fin.read());
transferCode('pan.py')
transferCode('sklearnExtensions.py')

# %%
import pan
import sklearnExtensions
from sklearnExtensions import DenseTransformer, POSTagTransformer,FilterTagTransformer;

# %% [markdown]
# ## Data Ingestion

# %%
datasets = pd.read_json(baseDir+'/data/AllDS.json.zip', orient='records', compression='gzip')
datasets['row_index'] = np.arange(len(datasets));
datasets = datasets[['row_index','dataset','problem','language','set','filename','text','label']]
print(datasets['dataset'].unique())
# Out:
# ['pan18_train' 'pan18_eval' 'lyrics' 'socialaa']

# %%
df = datasets.query(f'dataset == "{currentCorpus}"').copy()

# %%
df[['set','row_index']].groupby('set').count()
# Out:
#          row_index
# set
# known         3688
# unknown       1637

# %% [markdown]
# # Caching embeddings and POS Tagging

# %% [markdown]
# ### Linguistic anotations

# %%
postaggers = {
    l:POSTagTransformer(language=m)
    for l,m in {'en':'en', 'pt':'pt'}.items()
}

# %% [markdown]
# the POSTagTransformer returns a sequence of tokens and its annotations
# 1. Text
# 2. tag
# 3. pos
# 4. dep

# %%
def cachePOS(row):
    if row['language'] == 'pl':
        return [];
    else:
        return postaggers[row['language']].fit_transform([row['text']])[0]

df['POS']=df.apply(cachePOS,axis=1)

# %%
df
# Out:
#       row_index  ...                                                POS
# 4561       4561  ...  [(Chega, VERB__Mood=Ind|Number=Sing|Person=3|T...
# 4562       4562  ...  [(Houve, VERB__Mood=Ind|Number=Sing|Person=3|T...
# 4563       4563  ...  [(Te, PROPN__Gender=Masc|Number=Sing, PROPN, R...
# 4564       4564  ...  [(Eu, PRON__Case=Nom|Gender=Fem|Number=Sing|Pe...
# 4565       4565  ...  [(O, DET__Definite=Def|Gender=Masc|Number=Sing...
# ...         ...  ...                                                ...
# 9881       9881  ...  [(Took, VBD, VERB, ROOT), (a, DT, DET, det), (...
# 9882       9882  ...  [(Jzero, NNP, PROPN, ROOT), (:, :, PUNCT, punc...
# 9883       9883  ...  [(Put, VB, VERB, ROOT), (on, RP, ADP, prt), (y...
# 9884       9884  ...  [([, -LRB-, PUNCT, punct), (], -RRB-, PUNCT, p...
# 9885       9885  ...  [(Sometimes, RB, ADV, advmod), (I, PRP, PRON, ...
#
# [5325 rows x 9 columns]

# %% [markdown]
# ### Embeddings

# %%
def loadEmbeddings(lang):
    if lang == 'sp':
        lang = 'es';
    model = KeyedVectors.load_word2vec_format(os.path.join(baseDir,'data','embedding_cache','w2v_'+lang+'.txt.gz'), binary=False, unicode_errors='replace')
    return model;

# %%
def problemDoc(df,problem, column='text'):
    df = df.query(f"problem == '{problem}'")

    train = df[df['set'] =='known']
    X_train = np.array([c for c in train[column]])
    y_train = train['label'].values
    index_train = train['row_index'].values

    # The test set is actually the validation set and should not be used in the training processing
    test = df[df['set'] =='unknown']
    X_test = np.array([c for c in test[column]])
    y_test = test['label'].values
    index_test = test['row_index'].values

    return X_train, y_train, index_train, X_test, y_test, index_test;

# %% [markdown]
# It was used embeddings processed by Nordic Language Processing Laboratry
# and availabe on http://vectors.nlpl.eu/repository/. This website was visted in  jan 01 2019

# %%
def fitPipeline(df, problem,language, pipe,params,caching):
    print ("Problem: %s,  language: %s, " %(problem,language), end=' ');
    
    column = 'text';
    if caching == 'POS':
        column = 'POS';
    
    train_docs, train_labels, index_train, test_docs, test_labels,index_test = problemDoc(df, problem,column);
    if caching == 'POS':
        if language == 'pl':
            print("POS tagger not found")
            return {
                'problem':problem,
                'language':language,
                'n_authors': 0,
                'f1'       : 0,
                'precision': 0,
                'recall'   : 0,
                'accuracy' : 0,
            }, [[],[],[],[],[],[]], {};
    elif caching == 'w2v':
        global embeddingsCacheLanguage;
        global embeddingsCache;
        #yes it is uggly to use global var ... but it saved a lot of memory
        if embeddingsCacheLanguage != language:
            embeddingsCache = loadEmbeddings(language);
            embeddingsCacheLanguage = language;
        
    
    #using language specific params
    if language in params:
        pipe.set_params(**params[language])
        
    t0 = time()
    pipe.fit(train_docs, train_labels)
    print("Fitted in %0.3fs" % (time() - t0), end=' ');
    
    t0 = time()
    train_pred=pipe.predict(train_docs);
    train_prob=pipe.predict_proba(train_docs);

    test_pred=pipe.predict(test_docs);
    test_prob=pipe.predict_proba(test_docs);
    print("Predicted in %0.3fs" % (time() - t0));
    
    f1,precision,recall,accuracy = pan.eval_measures2019(test_labels,test_pred)
    
    return {
        'problem':problem,
        'language':language,
        'n_authors':len(set(train_labels)),
        'f1'       : round(f1,3),
        'precision': round(precision,3),
        'recall'   : round(recall,3),
        'accuracy' : round(accuracy,3),
    }, [train_pred, train_prob,index_train, test_pred,  test_prob,index_test], pipe.get_params(False);

# %% [markdown]
# # Model 1: Character

# %%
pipelineChar = Pipeline([
    ('vect',   TfidfVectorizer(analyzer='char',
                               min_df=0.01,
                               max_df=1.0,
                               norm='l2',
                               ngram_range=(2, 5),
                               sublinear_tf=True,
                               lowercase =False)),
    ('scaler', preprocessing.MaxAbsScaler()),
    ('dense',  DenseTransformer()),
    ('transf', PCA(0.999)),
    ('clf', LogisticRegression(random_state=0,multi_class='multinomial', solver='newton-cg')),
])

# %%
pipelineCharParams= {
    'it':{
        'vect__ngram_range': (3, 5),
    },
    'pl':{
        'vect__ngram_range': (2, 3),
    }
}

# %% [markdown]
# # Model 2: Word

# %%
pipelineWord = Pipeline([
    ('vect',   TfidfVectorizer(analyzer='word',
                               norm='l1',
                               min_df=2,
                               max_df=1.0,
                               ngram_range=(1, 2),
                               smooth_idf=True,
                               lowercase =True,
                               sublinear_tf=True)),
    ('dense',  DenseTransformer()),
    ('scaler', preprocessing.MaxAbsScaler()),
    ('transf', PCA(0.999)),
    ('clf', LogisticRegression(random_state=0,multi_class='multinomial', solver='newton-cg')),
])

# %%
pipelineWordParams= {
    'en':{
        'vect__ngram_range': (1, 3),
        'vect__norm': 'l2',
    },

    'pl':{
        'vect__norm': 'l2',
     },
}

# %% [markdown]
# # Model 3: distortions

# %%
distortions = [
    (r"[A-Z]"          ,'U','Upcase '),
    (r"[a-z]"          ,'l','lowercase'),
    (r"[À-ÿĄ-ż]"       ,'d','Diacrit'),
    (r"\d"             ,'D','Digits'),
    (r"[\n\r\t]"       ,'E','Paragraph control'),
    (r"\–|\-|\_|\—"    ,'H','Hyphen'),
    (r"\"|\'|’|[“”]"   ,'Q','quotation'),
    (r"\s"             ,'S','Spaces'),
    (r"\(|\)|\[|\]\{|\}|\«|\»",'G','Groups'),
    (r"…",'','...'),
    (r"\.|\,|[?]|\!|\:|\;|\„|\*|\/"   ,'P','Punctuation'),
    (r"[^aUldDEHQSGP]", 'X','Unkown'),
]

distortions = [(re.compile(d[0]), d[1],d[2]) for d in distortions]

# %%
class DistortionTransformer(BaseEstimator):
    def __init__(self,verbose=False):
        self.verbose = verbose;
        
    def _distortion(self,doc):
        for d in distortions:
            doc = d[0].sub(d[1],doc);
        return doc;

    def transform(self, X, y=None):
        t0 = time()
        if self.verbose:
            print('filtered in', end=' ')

        X = [self._distortion(doc) for doc in X]
        
        if self.verbose:
            print(" %0.3fs" % (time() - t0))
        return np.array(X);       

    def fit(self, X, y=None):
        self.is_fitted = True
        return self

    def fit_transform(self, X, y=None):
        return self.transform(X=X, y=y)

# %%
pipelineDistortion = Pipeline([
    ('filter',DistortionTransformer()),
    ('vect', TfidfVectorizer(
            analyzer='char',
            min_df=0.01,
            lowercase=False,
            norm='l2',
            sublinear_tf=True,
            ngram_range=(1, 5),
            )
    ),
    ('scaler', MaxAbsScaler()),
    ('dense',  DenseTransformer()),
    ('transf', PCA(0.999)),
    ('clf', LogisticRegression(random_state=0,C=1,multi_class='multinomial', solver='newton-cg')),
])

# %%
pipelineDistortionsParams = {
    'en':{
        'clf__C': 0.1,
        'vect__norm': 'l1',        
    },
    'fr':{
        'vect__norm': 'l1',
        'vect__ngram_range': (2, 5),
    },
    'it':{
        'clf__C': 0.1,
    },
    'sp':{
        'vect__norm': 'l1',
    }
}

# %% [markdown]
# # Model 4: POS

# %%
#train_docs, train_labels, test_docs, test_filename = cachingPOSTAG(problem)

pipelinePOS = Pipeline([
    ('filter',FilterTagTransformer(token='POS')),
    ('vect', TfidfVectorizer(
                        min_df=0.01,
                        lowercase=False,
                        use_idf=True,
                        norm='l1',
                        sublinear_tf=False,
                        ngram_range=(1, 5)
            )),
    ('scaler', MaxAbsScaler()),
    ('dense',  DenseTransformer()),
    ('transf', PCA(0.999)),
    ('clf', LogisticRegression(random_state=0,multi_class='multinomial', solver='newton-cg')),
])

# %% [markdown]
# O parametro sublinear_tf=True apresentou performance ruim em todos os casos de teste exceto o melhor.
# Como o melhor caso não é garantido nos conjuntos de avaliação, foi decidido que ele seria mantido como False.
#
# O parametro L1 apresentou performance melhor nos conjuntos com 5 candidatos. No entendo, o conjunto de validação conterá de 5 a 20 e portanto foi escolhido manter o valor l2

# %% [markdown]
# # Model 5: TAG  (granular POS)

# %%
def spaceTokenizer(x):
    return x.split(" ");

# %%
pipelineTag = Pipeline([
    ('filter',FilterTagTransformer(token='TAG')),
    ('vect', TfidfVectorizer(
                               tokenizer=spaceTokenizer,
                               min_df=0.01,
                               lowercase=False,
                               sublinear_tf=True,
                               use_idf=True,
                               norm='l2',
                                ngram_range=(1,3),
                              )),
    ('scaler', MaxAbsScaler()),
    ('dense',  DenseTransformer()),
    ('transf', PCA(0.999)),
    ('clf', LogisticRegression(random_state=0,C=0.1,multi_class='multinomial', solver='newton-cg')),
])

# %%
pipelineTagParams = {
    'fr':{
        'vect__ngram_range' :(1,5),
    },
    'sp':{
        'vect__ngram_range' :(1,5),
        'clf__C':1,
    }
}

# %% [markdown]
# # Model 6: Sintatic Dependency

# %%
pipelineDEP = Pipeline([
    ('filter',FilterTagTransformer(token='DEP')),
    ('vect', TfidfVectorizer(
                    analyzer='word',
                    min_df=0.01,
                    lowercase=False,
                    use_idf=True,
                    norm='l2',
                    ngram_range=(1,5),
            )),
    ('scaler', MaxAbsScaler()),
    ('dense',  DenseTransformer()),
    ('transf', PCA(0.999)),
    ('clf', LogisticRegression(random_state=0,C=1,multi_class='multinomial', solver='newton-cg')),
])

# %%
pipelineDEPParams = {
    'en':{
        'clf__C':0.1,
    },
    'fr':{
        'clf__C':0.1,
    },
    'it':{
        'vect__ngram_range' :(1,3),
    },
}

# %% [markdown]
# # Model 7: Word Embeddings

# %%
embeddingsCacheLanguage = None;
embeddingsCache = None;

# %%
from scipy import sparse
from sklearn.utils import assert_all_finite

class EmbeddingVectorizer(BaseEstimator):
    def __init__(self,norm=None,analyzer='word',min_df=1,lowercase=False,sublinear_tf=True,use_idf=True,binary=False):
        self.norm        = norm;
        self.analyzer    = analyzer;
        self.min_df      = min_df;
        self.lowercase   = lowercase;
        self.sublinear_tf= sublinear_tf;
        self.use_idf     = use_idf;
        self.binary      = binary;
        
    def fit(self, X, y=None):
        self.dim_ = len(embeddingsCache.vectors[0]);
        #self.dim_ = len(embeddingsCache[list(embeddingsCache.keys())[0]])
        self.vect = TfidfVectorizer(**self.get_params())
        self.vect.fit(X,y);
        self.word_vectors_ = np.zeros((len(self.vect.vocabulary_), self.dim_));
        
        #this arrays says if a word in the vocab has 
        self.missingWord_  = np.zeros(len(self.vect.vocabulary_),dtype=np.int8);
        
        blank = np.zeros(self.dim_);

        for  word, index in self.vect.vocabulary_.items():
            temp = blank.copy();
            for w in [word, word.lower(), word.capitalize()]:
                if w in embeddingsCache:
                    temp = embeddingsCache[w];
                    break;
            if temp.sum() == 0 :
                self.missingWord_[index] = 1;
            self.word_vectors_[index,:] = temp;
        return self
    
    def transform(self, X):
        import gc;
        gc.collect()
        X = self.vect.transform(X);
        
        X = sparse.csc_matrix(X);
        V = sparse.csc_matrix(self.word_vectors_);
        M = sparse.csc_matrix(self.missingWord_).T;
        
        missing = preprocessing.normalize((X>0).dot(M),norm='l1');
        missing = sparse.csc_matrix(missing.reshape(-1,1));
        
        #memory friendly dot product
        X  = preprocessing.normalize(X.dot(V),norm='l1');
        
        #last columns will contain the embedding coverage
        X = sparse.hstack([X,missing]);
        
        return X;
    
    def fit_transform(self, X, y=None):
        self.fit(X,y);
        return self.transform(X)
    
    def get_feature_names():
        return self.vect.get_feature_names();

# %%
pipelineEmbeddings = Pipeline([
    ('vect', EmbeddingVectorizer(
            analyzer='word',
            min_df=0.01,
            lowercase=False,
            sublinear_tf=False,
            norm='l1',
            use_idf=False
            )
    ),
    ('scaler',preprocessing.MaxAbsScaler()),
    ('dense',DenseTransformer()),
    ('pca',PCA(0.999)),
    ('clf', LogisticRegression(random_state=0,C=1,multi_class='multinomial', solver='newton-cg')),
])

# %%
pipelineEmbeddingsParams = {
    'fr':{
        'vect__sublinear_tf': True,
        'vect__use_idf': True,
    },

    'it':{
        'vect__use_idf': True,
    },

    'pl':{
        'clf__C': 0.1,
        'vect__use_idf': False,
        'vect__sublinear_tf': True,
    },
    'sp':{
        'vect__sublinear_tf': True,
        'vect__use_idf': True,
    },
}

# %% [markdown]
# # Applying models

# %%
models =[
    ('char',pipelineChar,pipelineCharParams,None),
    ('word',pipelineWord,pipelineWordParams,None),
    ('dist',pipelineDistortion,pipelineDistortionsParams,None),
    ('pos',pipelinePOS,{},'POS'),
    ('tag',pipelineTag,pipelineTagParams,'POS'),
    ('dep',pipelineDEP,pipelineDEPParams,'POS'),
    ('w2v',pipelineEmbeddings,pipelineEmbeddingsParams,'w2v'),
]

results = {};

for model in models:
    if model[0] in results:
        continue;
    print(('_'*100)+'\n'+model[0]+'\n'+('_'*100))
    result= {
        'metric':[],
        'pred_train':[],
        'pred_test':[],
        'prob_train':[],
        'prob_test':[],
        'index_train':[],
        'index_test':[],
        'params':[],
    }
    for problem in np.sort(df['problem'].unique()):
        language = df.query(f'problem =="{problem}"')['language'].unique()[0]
        metric, vects, params = fitPipeline(df, problem, language, model[1], model[2], caching=model[3]);
        result['metric'].append(metric);

        result['pred_train'].append(vects[0]);
        result['prob_train'].append(vects[1]);
        result['index_train'].append(vects[2]);

        result['pred_test'].append(vects[3]);
        result['prob_test'].append(vects[4]);
        result['index_test'].append(vects[5]);
        result['params'].append(params);
    results[model[0]]=result;
# Out:
# ____________________________________________________________________________________________________
# char
# ____________________________________________________________________________________________________
# Problem: problem00001,  language: pt,  Fitted in 1.412s Predicted in 1.428s
# Problem: problem00002,  language: pt,  Fitted in 3.697s Predicted in 2.982s
# Problem: problem00003,  language: pt,  Fitted in 4.569s Predicted in 3.878s
# Problem: problem00004,  language: pt,  Fitted in 7.527s Predicted in 6.312s
# Problem: problem00005,  language: pt,  Fitted in 9.069s Predicted in 7.648s
# Problem: problem00006,  language: en,  Fitted in 1.943s Predicted in 1.788s
# Problem: problem00007,  language: en,  Fitted in 4.064s Predicted in 3.729s
# Problem: problem00008,  language: en,  Fitted in 6.115s Predicted in 5.352s
# Problem: problem00009,  language: en,  Fitted in 8.589s Predicted in 7.551s
# Problem: problem00010,  language: en,  Fitted in 10.343s Predicted in 8.721s
# ____________________________________________________________________________________________________
# word
# ____________________________________________________________________________________________________
# Problem: problem00001,  language: pt,  Fitted in 0.197s Predicted in 0.215s
# Problem: problem00002,  language: pt,  Fitted in 0.607s Predicted in 0.520s
# Problem: problem00003,  language: pt,  Fitted in 0.974s Predicted in 0.734s
# Problem: problem00004,  language: pt,  Fitted in 2.484s Predicted in 1.304s
# Problem: problem00005,  language: pt,  Fitted in 3.250s Predicted in 1.727s
# Problem: problem00006,  language: en,  Fitted in 0.431s Predicted in 0.412s
# Problem: problem00007,  language: en,  Fitted in 1.311s Predicted in 0.900s
# Problem: problem00008,  language: en,  Fitted in 2.560s Predicted in 1.433s
# Problem: problem00009,  language: en,  Fitted in 4.597s Predicted in 2.439s
# Problem: problem00010,  language: en,  Fitted in 6.207s Predicted in 2.898s
# ____________________________________________________________________________________________________
# dist
# ____________________________________________________________________________________________________
# Problem: problem00001,  language: pt,  Fitted in 0.384s Predicted in 1.117s
# Problem: problem00002,  language: pt,  Fitted in 0.774s Predicted in 2.116s
# Problem: problem00003,  language: pt,  Fitted in 1.040s Predicted in 2.669s
# Problem: problem00004,  language: pt,  Fitted in 1.579s Predicted in 3.881s
# Problem: problem00005,  language: pt,  Fitted in 1.993s Predicted in 4.568s
# Problem: problem00006,  language: en,  Fitted in 0.452s Predicted in 1.408s
# Problem: problem00007,  language: en,  Fitted in 0.878s Predicted in 2.645s
# Problem: problem00008,  language: en,  Fitted in 1.288s Predicted in 3.667s
# Problem: problem00009,  language: en,  Fitted in 1.892s Predicted in 4.973s
# Problem: problem00010,  language: en,  Fitted in 2.187s Predicted in 5.396s
# ____________________________________________________________________________________________________
# pos
# ____________________________________________________________________________________________________
# Problem: problem00001,  language: pt,  Fitted in 0.410s Predicted in 0.568s
# Problem: problem00002,  language: pt,  Fitted in 1.022s Predicted in 1.134s
# Problem: problem00003,  language: pt,  Fitted in 1.309s Predicted in 1.392s
# Problem: problem00004,  language: pt,  Fitted in 2.326s Predicted in 2.117s
# Problem: problem00005,  language: pt,  Fitted in 2.962s Predicted in 2.518s
# Problem: problem00006,  language: en,  Fitted in 0.593s Predicted in 0.773s
# Problem: problem00007,  language: en,  Fitted in 1.342s Predicted in 1.458s
# Problem: problem00008,  language: en,  Fitted in 2.139s Predicted in 2.045s
# Problem: problem00009,  language: en,  Fitted in 2.965s Predicted in 2.849s
# Problem: problem00010,  language: en,  Fitted in 3.708s Predicted in 3.202s
# ____________________________________________________________________________________________________
# tag
# ____________________________________________________________________________________________________
# Problem: problem00001,  language: pt,  Fitted in 0.169s Predicted in 0.350s
# Problem: problem00002,  language: pt,  Fitted in 0.327s Predicted in 0.662s
# Problem: problem00003,  language: pt,  Fitted in 0.461s Predicted in 0.801s
# Problem: problem00004,  language: pt,  Fitted in 0.763s Predicted in 1.106s
# Problem: problem00005,  language: pt,  Fitted in 1.033s Predicted in 1.284s
# Problem: problem00006,  language: en,  Fitted in 0.246s Predicted in 0.458s
# Problem: problem00007,  language: en,  Fitted in 0.505s Predicted in 0.841s
# Problem: problem00008,  language: en,  Fitted in 0.823s Predicted in 1.131s
# Problem: problem00009,  language: en,  Fitted in 1.289s Predicted in 1.537s
# Problem: problem00010,  language: en,  Fitted in 1.636s Predicted in 1.703s
# ____________________________________________________________________________________________________
# dep
# ____________________________________________________________________________________________________
# Problem: problem00001,  language: pt,  Fitted in 0.481s Predicted in 0.549s
# Problem: problem00002,  language: pt,  Fitted in 1.188s Predicted in 1.102s
# Problem: problem00003,  language: pt,  Fitted in 1.612s Predicted in 1.359s
# Problem: problem00004,  language: pt,  Fitted in 2.517s Predicted in 2.137s
# Problem: problem00005,  language: pt,  Fitted in 2.960s Predicted in 2.499s
# Problem: problem00006,  language: en,  Fitted in 0.673s Predicted in 0.749s
# Problem: problem00007,  language: en,  Fitted in 1.492s Predicted in 1.413s
# Problem: problem00008,  language: en,  Fitted in 2.188s Predicted in 1.978s
# Problem: problem00009,  language: en,  Fitted in 3.184s Predicted in 2.766s
# Problem: problem00010,  language: en,  Fitted in 3.799s Predicted in 3.115s
# ____________________________________________________________________________________________________
# w2v
# ____________________________________________________________________________________________________
# Problem: problem00001,  language: pt,  Fitted in 0.389s Predicted in 1.036s
# Problem: problem00002,  language: pt,  Fitted in 0.439s Predicted in 1.093s
# Problem: problem00003,  language: pt,  Fitted in 0.495s Predicted in 1.133s
# Problem: problem00004,  language: pt,  Fitted in 0.592s Predicted in 1.261s
# Problem: problem00005,  language: pt,  Fitted in 0.657s Predicted in 1.306s
# Problem: problem00006,  language: en,  Fitted in 0.381s Predicted in 1.189s
# Problem: problem00007,  language: en,  Fitted in 0.552s Predicted in 1.327s
# Problem: problem00008,  language: en,  Fitted in 0.668s Predicted in 1.424s
# Problem: problem00009,  language: en,  Fitted in 0.819s Predicted in 1.537s
# Problem: problem00010,  language: en,  Fitted in 0.898s Predicted in 1.603s

# %%
dfMetric = pd.DataFrame();
for m in results:
    df_temp = pd.DataFrame(results[m]['metric'])[['problem','n_authors','language','f1','precision','recall','accuracy']]
    df_temp['model']=m
    dfMetric= dfMetric.append(df_temp)

with pd.option_context("display.precision", 3):
    display(dfMetric.fillna(value=0) \
        .pivot(index='problem',columns='model',values=['f1','accuracy']).round(3)\
        .style.background_gradient(subset=['f1'], axis=1, cmap=plt.cm.Blues)\
        .background_gradient(subset=['accuracy'], axis=1, cmap=plt.cm.Greens))
# Out:
# <style  type="text/css" >
# #T_0b4db5ba_193b_11eb_8c95_0242ac1c0002row0_col0{
#             background-color:  #083877;
#             color:  #f1f1f1;
#         }#T_0b4db5ba_193b_11eb_8c95_0242ac1c0002row0_col1{
#             background-color:  #f4f9fe;
#             color:  #000000;
#         }#T_0b4db5ba_193b_11eb_8c95_0242ac1c0002row0_col2,#T_0b4db5ba_193b_11eb_8c95_0242ac1c0002row8_col3{
#             background-color:  #d6e6f4;
#             color:  #000000;
#         }#T_0b4db5ba_193b_11eb_8c95_0242ac1c0002row0_col3,#T_0b4db5ba_193b_11eb_8c95_0242ac1c0002row1_col3,#T_0b4db5ba_193b_11eb_8c95_0242ac1c0002row2_col2,#T_0b4db5ba_193b_11eb_8c95_0242ac1c0002row3_col2,#T_0b4db5ba_193b_11eb_8c95_0242ac1c0002row4_col1,#T_0b4db5ba_193b_11eb_8c95_0242ac1c0002row5_col1,#T_0b4db5ba_193b_11eb_8c95_0242ac1c0002row6_col1,#T_0b4db5ba_193b_11eb_8c95_0242ac1c0002row7_col1,#T_0b4db5ba_193b_11eb_8c95_0242ac1c0002row8_col1,#T_0b4db5ba_193b_11eb_8c95_0242ac1c0002row9_col1{
#             background-color:  #f7fbff;
#             color:  #000000;
#         }#T_0b4db5ba_193b_11eb_8c95_0242ac1c0002row0_col4{
#             background-color:  #b7d4ea;
#             color:  #000000;
#         }#T_0b4db5ba_193b_11eb_8c95_0242ac1c0002row0_col5,#T_0b4db5ba_193b_11eb_8c95_0242ac1c0002row1_col0,#T_0b4db5ba_193b_11eb_8c95_0242ac1c0002row2_col0,#T_0b4db5ba_193b_11eb_8c95_0242ac1c0002row3_col0,#T_0b4db5ba_193b_11eb_8c95_0242ac1c0002row4_col0,#T_0b4db5ba_193b_11eb_8c95_0242ac1c0002row5_col0,#T_0b4db5ba_193b_11eb_8c95_0242ac1c0002row6_col0,#T_0b4db5ba_193b_11eb_8c95_0242ac1c0002row7_col0,#T_0b4db5ba_193b_11eb_8c95_0242ac1c0002row8_col0,#T_0b4db5ba_193b_11eb_8c95_0242ac1c0002row9_col0{
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }#T_0b4db5ba_193b_11eb_8c95_0242ac1c0002row0_col6{
#             background-color:  #1b69af;
#             color:  #f1f1f1;
#         }#T_0b4db5ba_193b_11eb_8c95_0242ac1c0002row0_col7,#T_0b4db5ba_193b_11eb_8c95_0242ac1c0002row1_col7,#T_0b4db5ba_193b_11eb_8c95_0242ac1c0002row2_col7,#T_0b4db5ba_193b_11eb_8c95_0242ac1c0002row3_col7,#T_0b4db5ba_193b_11eb_8c95_0242ac1c0002row4_col7,#T_0b4db5ba_193b_11eb_8c95_0242ac1c0002row5_col7,#T_0b4db5ba_193b_11eb_8c95_0242ac1c0002row6_col7,#T_0b4db5ba_193b_11eb_8c95_0242ac1c0002row7_col7,#T_0b4db5ba_193b_11eb_8c95_0242ac1c0002row8_col7,#T_0b4db5ba_193b_11eb_8c95_0242ac1c0002row9_col7{
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }#T_0b4db5ba_193b_11eb_8c95_0242ac1c0002row0_col8,#T_0b4db5ba_193b_11eb_8c95_0242ac1c0002row0_col9{
#             background-color:  #e2f4dd;
#             color:  #000000;
#         }#T_0b4db5ba_193b_11eb_8c95_0242ac1c0002row0_col10,#T_0b4db5ba_193b_11eb_8c95_0242ac1c0002row1_col10,#T_0b4db5ba_193b_11eb_8c95_0242ac1c0002row2_col9,#T_0b4db5ba_193b_11eb_8c95_0242ac1c0002row3_col9,#T_0b4db5ba_193b_11eb_8c95_0242ac1c0002row4_col9,#T_0b4db5ba_193b_11eb_8c95_0242ac1c0002row5_col9,#T_0b4db5ba_193b_11eb_8c95_0242ac1c0002row6_col8,#T_0b4db5ba_193b_11eb_8c95_0242ac1c0002row7_col8,#T_0b4db5ba_193b_11eb_8c95_0242ac1c0002row8_col8,#T_0b4db5ba_193b_11eb_8c95_0242ac1c0002row9_col8{
#             background-color:  #f7fcf5;
#             color:  #000000;
#         }#T_0b4db5ba_193b_11eb_8c95_0242ac1c0002row0_col11,#T_0b4db5ba_193b_11eb_8c95_0242ac1c0002row2_col8{
#             background-color:  #bde5b6;
#             color:  #000000;
#         }#T_0b4db5ba_193b_11eb_8c95_0242ac1c0002row0_col12{
#             background-color:  #05712f;
#             color:  #f1f1f1;
#         }#T_0b4db5ba_193b_11eb_8c95_0242ac1c0002row0_col13{
#             background-color:  #19833e;
#             color:  #f1f1f1;
#         }#T_0b4db5ba_193b_11eb_8c95_0242ac1c0002row1_col1{
#             background-color:  #dae8f6;
#             color:  #000000;
#         }#T_0b4db5ba_193b_11eb_8c95_0242ac1c0002row1_col2,#T_0b4db5ba_193b_11eb_8c95_0242ac1c0002row6_col3{
#             background-color:  #c7dbef;
#             color:  #000000;
#         }#T_0b4db5ba_193b_11eb_8c95_0242ac1c0002row1_col4{
#             background-color:  #cee0f2;
#             color:  #000000;
#         }#T_0b4db5ba_193b_11eb_8c95_0242ac1c0002row1_col5{
#             background-color:  #7fb9da;
#             color:  #000000;
#         }#T_0b4db5ba_193b_11eb_8c95_0242ac1c0002row1_col6{
#             background-color:  #1865ac;
#             color:  #f1f1f1;
#         }#T_0b4db5ba_193b_11eb_8c95_0242ac1c0002row1_col8{
#             background-color:  #ebf7e7;
#             color:  #000000;
#         }#T_0b4db5ba_193b_11eb_8c95_0242ac1c0002row1_col9,#T_0b4db5ba_193b_11eb_8c95_0242ac1c0002row5_col12{
#             background-color:  #d3eecd;
#             color:  #000000;
#         }#T_0b4db5ba_193b_11eb_8c95_0242ac1c0002row1_col11{
#             background-color:  #c6e8bf;
#             color:  #000000;
#         }#T_0b4db5ba_193b_11eb_8c95_0242ac1c0002row1_col12{
#             background-color:  #8ed08b;
#             color:  #000000;
#         }#T_0b4db5ba_193b_11eb_8c95_0242ac1c0002row1_col13{
#             background-color:  #0c7735;
#             color:  #f1f1f1;
#         }#T_0b4db5ba_193b_11eb_8c95_0242ac1c0002row2_col1{
#             background-color:  #d3e3f3;
#             color:  #000000;
#         }#T_0b4db5ba_193b_11eb_8c95_0242ac1c0002row2_col3{
#             background-color:  #b0d2e7;
#             color:  #000000;
#         }#T_0b4db5ba_193b_11eb_8c95_0242ac1c0002row2_col4{
#             background-color:  #bfd8ed;
#             color:  #000000;
#         }#T_0b4db5ba_193b_11eb_8c95_0242ac1c0002row2_col5{
#             background-color:  #2676b8;
#             color:  #000000;
#         }#T_0b4db5ba_193b_11eb_8c95_0242ac1c0002row2_col6{
#             background-color:  #125ea6;
#             color:  #f1f1f1;
#         }#T_0b4db5ba_193b_11eb_8c95_0242ac1c0002row2_col10{
#             background-color:  #9fd899;
#             color:  #000000;
#         }#T_0b4db5ba_193b_11eb_8c95_0242ac1c0002row2_col11{
#             background-color:  #94d390;
#             color:  #000000;
#         }#T_0b4db5ba_193b_11eb_8c95_0242ac1c0002row2_col12{
#             background-color:  #45ad5f;
#             color:  #000000;
#         }#T_0b4db5ba_193b_11eb_8c95_0242ac1c0002row2_col13{
#             background-color:  #309950;
#             color:  #000000;
#         }#T_0b4db5ba_193b_11eb_8c95_0242ac1c0002row3_col1{
#             background-color:  #e6f0f9;
#             color:  #000000;
#         }#T_0b4db5ba_193b_11eb_8c95_0242ac1c0002row3_col3,#T_0b4db5ba_193b_11eb_8c95_0242ac1c0002row7_col3{
#             background-color:  #f2f7fd;
#             color:  #000000;
#         }#T_0b4db5ba_193b_11eb_8c95_0242ac1c0002row3_col4,#T_0b4db5ba_193b_11eb_8c95_0242ac1c0002row9_col3{
#             background-color:  #bad6eb;
#             color:  #000000;
#         }#T_0b4db5ba_193b_11eb_8c95_0242ac1c0002row3_col5,#T_0b4db5ba_193b_11eb_8c95_0242ac1c0002row9_col6{
#             background-color:  #3f8fc5;
#             color:  #000000;
#         }#T_0b4db5ba_193b_11eb_8c95_0242ac1c0002row3_col6{
#             background-color:  #3a8ac2;
#             color:  #000000;
#         }#T_0b4db5ba_193b_11eb_8c95_0242ac1c0002row3_col8{
#             background-color:  #ceecc8;
#             color:  #000000;
#         }#T_0b4db5ba_193b_11eb_8c95_0242ac1c0002row3_col10,#T_0b4db5ba_193b_11eb_8c95_0242ac1c0002row9_col12{
#             background-color:  #d2edcc;
#             color:  #000000;
#         }#T_0b4db5ba_193b_11eb_8c95_0242ac1c0002row3_col11{
#             background-color:  #88ce87;
#             color:  #000000;
#         }#T_0b4db5ba_193b_11eb_8c95_0242ac1c0002row3_col12,#T_0b4db5ba_193b_11eb_8c95_0242ac1c0002row7_col11{
#             background-color:  #6bc072;
#             color:  #000000;
#         }#T_0b4db5ba_193b_11eb_8c95_0242ac1c0002row3_col13{
#             background-color:  #2a924a;
#             color:  #000000;
#         }#T_0b4db5ba_193b_11eb_8c95_0242ac1c0002row4_col2{
#             background-color:  #edf4fc;
#             color:  #000000;
#         }#T_0b4db5ba_193b_11eb_8c95_0242ac1c0002row4_col3{
#             background-color:  #e0ecf8;
#             color:  #000000;
#         }#T_0b4db5ba_193b_11eb_8c95_0242ac1c0002row4_col4{
#             backgro

# %% [markdown]
# # Dynamic Ensemble

# %%
def buildClassifier():
    return Pipeline(steps=[
                ('pca',PCA(0.9999)),
                ('clf', LogisticRegression(random_state=0,C=1, max_iter=3000))
            ])

# %%
def concatenatXVectors(results, problemIndex, models):
    x_train = [results[model]['prob_train'][problemIndex] for model in models];
    x_test  = [results[model]['prob_test'][problemIndex] for model in models];
    
    x_train = [x for x in x_train if len(x) > 1];
    x_test  = [x for x in x_test  if len(x) > 1];
    
    if len(x_train) < 1:
        return None,None;
    
    return np.hstack(x_train),  np.hstack(x_test);

# %%
def sortModels(results, problemIndex,models,train_labels, test_labels):
    f1 = [];
    
    for model in models:
        x_train, x_test = concatenatXVectors(results, problemIndex, [model]);
        if x_train is None:
            f1.append(0);
        else:
            pipe = buildClassifier()
            pred_label = pipe.fit(x_train, train_labels).predict(x_test);
            f1.append(f1_score(test_labels, pred_label,average='macro'));
    models = np.array(models);
    f1 = np.array(f1);
    
    models = models[f1 >0];
    f1 = f1[f1 >0]
    
    return list(models[np.argsort(-f1)]);

# %%
resultFinal = []
bestModels = []
predictions = [];
for problemIndex, problem in enumerate(df['problem'].unique()):
    print('\n'+problem)

    train_docs, train_labels, index_train, test_docs, test_labels,index_test = problemDoc(df, problem);

    #forward step: sorting the models by
    models = sortModels(results, problemIndex,list(results.keys()), train_labels, test_labels);

    print("sorted "+str(models))

    #step 0 - train only the best model.
    bestModel =[ models.pop(0)];
    x_train, x_test = concatenatXVectors(results, problemIndex, bestModel);
    pred_label  = buildClassifier().fit(x_train, train_labels).predict(x_test);
    bestF1      = f1_score(test_labels,pred_label,average='macro')
    models = list(set(models)-set(bestModel)); # removing the current model from the list.
    
    improve = True;
    iteration = 0;
    while (improve):
        improve = False;
        iteration +=1 ;
        print("Iteration "+str(iteration)    +" Best model:     %-77s %.4f"%(str(bestModel),bestF1))
        for model in models:
            currentModel = bestModel +[model];
            print("Iteration "+str(iteration)+" current model:  %-75s "%str(currentModel), end=' ')

            x_train, x_test = concatenatXVectors(results, problemIndex, currentModel);

            pipe = buildClassifier()

            pred_label = pipe.fit(x_train, train_labels).predict(x_test);
            currentF1 = f1_score(test_labels,pred_label,average='macro');
            
            print(" %.4f"%currentF1)


            if currentF1/bestF1 > 1.015:
                improve = True;
                bestF1 = currentF1;
                bestModel = currentModel;
        models = list(set(models)-set(currentModel));
    print("Selected Model: "+str(bestModel))
    bestModels.append(bestModel);
    
    x_train, x_test = concatenatXVectors(results, problemIndex, bestModel);
    
    pipelineFinal = Pipeline(steps=[
        ('pca',PCA(0.9999)),
        ('clf', LogisticRegression(random_state=0,C=100000))
    ])

    pipelineFinal.fit(x_train, train_labels);
    pred_train = pipelineFinal.predict(x_train);
    pred_proba_train = pipelineFinal.predict_proba(x_train);
    pred_test = pipelineFinal.predict(x_test);
    pred_proba_test = pipelineFinal.predict_proba(x_test);

    def appendPrediction(predictions,classes_,index, pred,proba):
        for i,p, pr in  zip(index, pred, proba):
            predictions.append(dict(**{
                    'dataset':currentCorpus,
                    'problem':problem,
                    'model':'dymAA',
                    'row_index':i,
                    'pred':p,
                }, **{
                    cc:pr_ for cc,pr_ in zip(classes_, pr)
                })
            )

    appendPrediction(predictions,pipelineFinal.classes_, index_train, pred_train, pred_proba_train)
    appendPrediction(predictions,pipelineFinal.classes_, index_test, pred_test, pred_proba_test)
    

    resultFinal.append({
        'model':'0ensemble',
        'problem':problem,
        'language':df.query(f"problem == '{problem}'")['language'].unique()[0],
        'n_authors': len(set(train_labels)),
        'f1':round(f1_score(test_labels,pred_test,average='macro'),3),
        'accuracy':round(accuracy_score(test_labels,pred_test),3)
    })
# Out:
# problem00001
# sorted ['w2v', 'word', 'char', 'tag', 'dist', 'dep', 'pos']
# Iteration 1 Best model:     ['w2v']                                                                       0.6234
# Iteration 1 current model:  ['w2v', 'dist']                                                               0.4717
# Iteration 1 current model:  ['w2v', 'dep']                                                                0.4569
# Iteration 1 current model:  ['w2v', 'word']                                                               0.6474
# Iteration 1 current model:  ['w2v', 'word', 'char']                                                       0.6070
# Iteration 1 current model:  ['w2v', 'word', 'tag']                                                        0.6314
# Iteration 1 current model:  ['w2v', 'word', 'pos']                                                        0.4859
# Iteration 2 Best model:     ['w2v', 'word']                                                               0.6474
# Iteration 2 current model:  ['w2v', 'word', 'dep']                                                        0.5671
# Iteration 2 current model:  ['w2v', 'word', 'tag']                                                        0.6314
# Iteration 2 current model:  ['w2v', 'word', 'dist']                                                       0.5960
# Iteration 2 current model:  ['w2v', 'word', 'char']                                                       0.6070
# Selected Model: ['w2v', 'word']
#
# problem00002
# sorted ['char', 'word', 'tag', 'dist', 'w2v', 'dep', 'pos']
# Iteration 1 Best model:     ['char']                                                                      0.4534
# Iteration 1 current model:  ['char', 'dist']                                                              0.3817
# Iteration 1 current model:  ['char', 'dep']                                                               0.3797
# Iteration 1 current model:  ['char', 'word']                                                              0.5151
# Iteration 1 current model:  ['char', 'word', 'w2v']                                                       0.5283
# Iteration 1 current model:  ['char', 'word', 'w2v', 'tag']                                                0.5263
# Iteration 1 current model:  ['char', 'word', 'w2v', 'pos']                                                0.4723
# Iteration 2 Best model:     ['char', 'word', 'w2v']                                                       0.5283
# Iteration 2 current model:  ['char', 'word', 'w2v', 'dep']                                                0.4213
# Iteration 2 current model:  ['char', 'word', 'w2v', 'tag']                                                0.5263
# Iteration 2 current model:  ['char', 'word', 'w2v', 'dist']                                               0.4760
# Selected Model: ['char', 'word', 'w2v']
#
# problem00003
# sorted ['char', 'word', 'w2v', 'tag', 'dep', 'dist', 'pos']
# Iteration 1 Best model:     ['char']                                                                      0.3216
# Iteration 1 current model:  ['char', 'dist']                                                              0.2832
# Iteration 1 current model:  ['char', 'dep']                                                               0.2635
# Iteration 1 current model:  ['char', 'word']                                                              0.3117
# Iteration 1 current model:  ['char', 'w2v']                                                               0.3520
# Iteration 1 current model:  ['char', 'w2v', 'tag']                                                        0.3433
# Iteration 1 current model:  ['char', 'w2v', 'pos']                                                        0.3276
# Iteration 2 Best model:     ['char', 'w2v']                                                               0.3520
# Iteration 2 current model:  ['char', 'w2v', 'dep']                                                        0.2791
# Iteration 2 current model:  ['char', 'w2v', 'word']                                                       0.3214
# Iteration 2 current model:  ['char', 'w2v', 'tag']                                                        0.3433
# Iteration 2 current model:  ['char', 'w2v', 'dist']                                                       0.2943
# Selected Model: ['char', 'w2v']
#
# problem00004
# sorted ['char', 'word', 'tag', 'w2v', 'dep', 'pos', 'dist']
# Iteration 1 Best model:     ['char']                                                                      0.3227
# Iteration 1 current model:  ['char', 'dist']                                                              0.2899
# Iteration 1 current model:  ['char', 'dep']                                                               0.2486
# Iteration 1 current model:  ['char', 'word']                                                              0.3308
# Iteration 1 current model:  ['char', 'word', 'w2v']                                                       0.3327
# Iteration 1 current model:  ['char', 'word', 'tag']                                                       0.3393
# Iteration 1 current model:  ['char', 'word', 'tag', 'pos']                                                0.2948
# Iteration 2 Best model:     ['char', 'word', 'tag']                                                       0.3393
# Iteration 2 current model:  ['char', 'word', 'tag', 'dep']                                                0.2748
# Iteration 2 current model:  ['char', 'word', 'tag', 'w2v']                                                0.3548
# Iteration 2 current model:  ['char', 'word', 'tag', 'w2v', 'dist']                                        0.3127
# Iteration 3 Best model:     ['char', 'word', 'tag', 'w2v']                                                0.3548
# Iteration 3 current model:  ['char', 'word', 'tag', 'w2v', 'dep']                                         0.2776
# Selected Model: ['char', 'word', 'tag', 'w2v']
#
# problem00005
# sorted ['char', 'word', 'tag', 'pos', 'w2v', 'dep', 'dist']
# Iteration 1 Best model:     ['char']                                                                      0.3426
# Iteration 1 current model:  ['char', 'dist']                                                              0.2388
# Iteration 1 current model:  ['char', 'dep']                                                               0.2711
# Iteration 1 current model:  ['char', 'word']                                                              0.3183
# Iteration 1 current model:  ['char', 'w2v']                                                               0.3562
# Iteration 1 current model:  ['char', 'w2v', 'tag']                                                        0.3450
# Iteration 1 current model:  ['char', 'w2v', 'pos']                                                        0.2723
# Iteration 2 Best model:     ['char', 'w2v']                                                               0.3562
# Iteration 2 current model:  ['char', 'w2v', 'dep']                                                        0.2698
# Iteration 2 current model:  ['char', 'w2v', 'word']                                                       0.3320
# Iteration 2 current model:  ['char', 'w2v', 'tag']                                                        0.3450
# Iteration 2 current model:  ['char', 'w2v', 'dist']                                                       0.2517
# Selected Model: ['char', 'w2v']
#
# problem00006
# sorted ['char', 'word', 'tag', 'w2v', 'dist', 'pos', 'dep']
# Iteration 1 Best model:     ['char']                                                                      0.6118
# Iteration 1 current model:  ['char', 'dist']                                                              0.5478
# Iteration 1 current model:  ['char', 'dep']                                                               0.5713
# Iteration 1 current model:  ['char', 'word']                                                              0.6182
# Iteration 1 current model:  ['char', 'w2v']                                                               0.5995
# Iteration 1 current model:  ['char', 'tag']                                                               0.6123
# Iteration 1 current model:  ['char', 'pos']                                                               0.6081
# Selected Model: ['char']
#
# problem00007
# sorted ['char', 'word', 'tag', 'w2v', 'pos', 'dist', 'dep']
# Iteration 1 Best model:     ['char']                                                                      0.5717
# Iteration 1 current model:  ['char', 'dist']                                                              0.5558
# Iteration 1 current model:  ['char', 'dep']                                                               0.5816
# Iteration 1 current model:  ['char', 'dep', 'word']                                                       0.5618
# Iteration 1 current model:  ['char', 'dep', 'w2v']                                                        0.5501
# Iteration 1 current model:  ['char', 'dep', 'tag']                                                        0.5538
# Iteration 1 current model:  ['char', 'dep', 'pos']                                                        0.4990
# Iteration 2 Best model:     ['char', 'dep']                                                               0.5816
# Iteration 2 current model:  ['char', 'dep', 'word']                                                       0.5618
# Iteration 2 current model:  ['char', 'dep', 'w2v']                                                        0.5501
# Iteration 2 current model:  ['char', 'dep', 'dist']                                                       0.5500
# Iteration 2 current model:  ['char', 'dep', 'tag']                                                        0.5538
# Selected Model: ['char', 'dep']
#
# problem00008
# sorted ['char', 'w2v', 'tag', 'word', 'dist', 'pos', 'dep']
# Iteration 1 Best model:     ['char']                                                                      0.3937
# Iteration 1 current model:  ['char', 'dist']                                                              0.4026
# Iteration 1 current model:  ['char', 'dist', 'dep']                                                       0.4151
# Iteration 1 current model:  ['char', 'dist', 'dep', 'word']                                               0.3746
# Iteration 1 current model:  ['char', 'dist', 'dep', 'w2v']                                                0.4861
# Iteration 1 current model:  ['char', 'dist', 'dep', 'w2v', 'tag']                                         0.4866
# Iteration 1 current model:  ['char', 'dist', 'dep', 'w2v', 'pos']                                         0.4268
# Iteration 2 Best model:     ['char', 'dist', 'dep', 'w2v']                                                0.4861
# Iteration 2 current model:  ['char', 'dist', 'dep', 'w2v', 'word']                                        0.4414
# Iteration 2 current model:  ['char', 'dist', 'dep', 'w2v', 'tag']                                         0.4866
# Selected Model: ['char', 'dist', 'dep', 'w2v']
#
# problem00009
# sorted ['char', 'word', 'tag', 'w2v', 'pos', 'dist', 'dep']
# Iteration 1 Best model:     ['char']                                                                      0.4749
# Iteration 1 current model:  ['char', 'dist']                                                              0.4835
# Iteration 1 current model:  ['char', 'dist', 'dep']                                                       0.4728
# Iteration 1 current model:  ['char', 'dist', 'word']                                                      0.4625
# Iteration 1 current model:  ['char', 'dist', 'w2v']                                                       0.4618
# Iteration 1 current model:  ['char', 'dist', 'tag']                                                       0.4640
# Iteration 1 current model:  ['char', 'dist', 'pos']                                                       0.4734
# Iteration 2 Best model:     ['char', 'dist']                                                              0.4835
# Iteration 2 current model:  ['char', 'dist', 'dep']                                                       0.4728
# Iteration 2 current model:  ['char', 'dist', 'word']                                                      0.4625
# Iteration 2 current model:  ['char', 'dist', 'w2v']                                                       0.4618
# Iteration 2 current model:  ['char', 'dist', 'tag']                                                       0.4640
# Selected Model: ['char', 'dist']
#
# problem00010
# sorted ['char', 'word', 'tag', 'w2v', 'pos', 'dist', 'dep']
# Iteration 1 Best model:     ['char']                                                                      0.3365
# Iteration 1 current model:  ['char', 'dist']                                                              0.3468
# Iteration 1 current model:  ['char', 'dist', 'dep']                                                       0.3625
# Iteration 1 current model:  ['char', 'dist', 'dep', 'word']                                               0.3544
# Iteration 1 current model:  ['char', 'dist', 'dep', 'w2v']                                                0.3492
# Iteration 1 current model:  ['char', 'dist', 'dep', 'tag']                                                0.3492
# Iteration 1 current model:  ['char', 'dist', 'dep', 'pos']                                                0.2989
# Iteration 2 Best model:     ['char', 'dist', 'dep']                                                       0.3625
# Iteration 2 current model:  ['char', 'dist', 'dep', 'word']                                               0.3544
# Iteration 2 current model:  ['char', 'dist', 'dep', 'w2v']                                                0.3492
# Iteration 2 current model:  ['char', 'dist', 'dep', 'tag']                                                0.3492
# Selected Model: ['char', 'dist', 'dep']

# %%
pd.concat([dfMetric, pd.DataFrame(resultFinal)]).fillna(value=0) \
    .pivot(index='problem',columns='model',values=['f1','accuracy']).fillna(0)\
    .style.background_gradient(subset=['f1'], axis=1, cmap=plt.cm.Blues)\
    .background_gradient(subset=['accuracy'], axis=1, cmap=plt.cm.Greens)\
    .format('{:,.2f}'.format)
# Out:
# <style  type="text/css" >
# #T_0f5aae74_193b_11eb_8c95_0242ac1c0002row0_col0{
#             background-color:  #083979;
#             color:  #f1f1f1;
#         }#T_0f5aae74_193b_11eb_8c95_0242ac1c0002row0_col1{
#             background-color:  #083877;
#             color:  #f1f1f1;
#         }#T_0f5aae74_193b_11eb_8c95_0242ac1c0002row0_col2{
#             background-color:  #f4f9fe;
#             color:  #000000;
#         }#T_0f5aae74_193b_11eb_8c95_0242ac1c0002row0_col3,#T_0f5aae74_193b_11eb_8c95_0242ac1c0002row8_col4{
#             background-color:  #d6e6f4;
#             color:  #000000;
#         }#T_0f5aae74_193b_11eb_8c95_0242ac1c0002row0_col4,#T_0f5aae74_193b_11eb_8c95_0242ac1c0002row1_col4,#T_0f5aae74_193b_11eb_8c95_0242ac1c0002row2_col3,#T_0f5aae74_193b_11eb_8c95_0242ac1c0002row3_col3,#T_0f5aae74_193b_11eb_8c95_0242ac1c0002row4_col2,#T_0f5aae74_193b_11eb_8c95_0242ac1c0002row5_col2,#T_0f5aae74_193b_11eb_8c95_0242ac1c0002row6_col2,#T_0f5aae74_193b_11eb_8c95_0242ac1c0002row7_col2,#T_0f5aae74_193b_11eb_8c95_0242ac1c0002row8_col2,#T_0f5aae74_193b_11eb_8c95_0242ac1c0002row9_col2{
#             background-color:  #f7fbff;
#             color:  #000000;
#         }#T_0f5aae74_193b_11eb_8c95_0242ac1c0002row0_col5{
#             background-color:  #b7d4ea;
#             color:  #000000;
#         }#T_0f5aae74_193b_11eb_8c95_0242ac1c0002row0_col6,#T_0f5aae74_193b_11eb_8c95_0242ac1c0002row1_col0,#T_0f5aae74_193b_11eb_8c95_0242ac1c0002row2_col0,#T_0f5aae74_193b_11eb_8c95_0242ac1c0002row3_col0,#T_0f5aae74_193b_11eb_8c95_0242ac1c0002row4_col0,#T_0f5aae74_193b_11eb_8c95_0242ac1c0002row4_col1,#T_0f5aae74_193b_11eb_8c95_0242ac1c0002row5_col0,#T_0f5aae74_193b_11eb_8c95_0242ac1c0002row5_col1,#T_0f5aae74_193b_11eb_8c95_0242ac1c0002row6_col1,#T_0f5aae74_193b_11eb_8c95_0242ac1c0002row7_col0,#T_0f5aae74_193b_11eb_8c95_0242ac1c0002row8_col1,#T_0f5aae74_193b_11eb_8c95_0242ac1c0002row9_col1{
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }#T_0f5aae74_193b_11eb_8c95_0242ac1c0002row0_col7{
#             background-color:  #1b69af;
#             color:  #f1f1f1;
#         }#T_0f5aae74_193b_11eb_8c95_0242ac1c0002row0_col8,#T_0f5aae74_193b_11eb_8c95_0242ac1c0002row0_col9,#T_0f5aae74_193b_11eb_8c95_0242ac1c0002row1_col8,#T_0f5aae74_193b_11eb_8c95_0242ac1c0002row2_col8,#T_0f5aae74_193b_11eb_8c95_0242ac1c0002row3_col8,#T_0f5aae74_193b_11eb_8c95_0242ac1c0002row4_col8,#T_0f5aae74_193b_11eb_8c95_0242ac1c0002row4_col9,#T_0f5aae74_193b_11eb_8c95_0242ac1c0002row5_col8,#T_0f5aae74_193b_11eb_8c95_0242ac1c0002row5_col9,#T_0f5aae74_193b_11eb_8c95_0242ac1c0002row6_col9,#T_0f5aae74_193b_11eb_8c95_0242ac1c0002row7_col8,#T_0f5aae74_193b_11eb_8c95_0242ac1c0002row8_col9,#T_0f5aae74_193b_11eb_8c95_0242ac1c0002row9_col9{
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }#T_0f5aae74_193b_11eb_8c95_0242ac1c0002row0_col10,#T_0f5aae74_193b_11eb_8c95_0242ac1c0002row0_col11{
#             background-color:  #e2f4dd;
#             color:  #000000;
#         }#T_0f5aae74_193b_11eb_8c95_0242ac1c0002row0_col12,#T_0f5aae74_193b_11eb_8c95_0242ac1c0002row1_col12,#T_0f5aae74_193b_11eb_8c95_0242ac1c0002row2_col11,#T_0f5aae74_193b_11eb_8c95_0242ac1c0002row3_col11,#T_0f5aae74_193b_11eb_8c95_0242ac1c0002row4_col11,#T_0f5aae74_193b_11eb_8c95_0242ac1c0002row5_col11,#T_0f5aae74_193b_11eb_8c95_0242ac1c0002row6_col10,#T_0f5aae74_193b_11eb_8c95_0242ac1c0002row7_col10,#T_0f5aae74_193b_11eb_8c95_0242ac1c0002row8_col10,#T_0f5aae74_193b_11eb_8c95_0242ac1c0002row9_col10{
#             background-color:  #f7fcf5;
#             color:  #000000;
#         }#T_0f5aae74_193b_11eb_8c95_0242ac1c0002row0_col13{
#             background-color:  #bde5b6;
#             color:  #000000;
#         }#T_0f5aae74_193b_11eb_8c95_0242ac1c0002row0_col14{
#             background-color:  #05712f;
#             color:  #f1f1f1;
#         }#T_0f5aae74_193b_11eb_8c95_0242ac1c0002row0_col15{
#             background-color:  #19833e;
#             color:  #f1f1f1;
#         }#T_0f5aae74_193b_11eb_8c95_0242ac1c0002row1_col1,#T_0f5aae74_193b_11eb_8c95_0242ac1c0002row9_col0{
#             background-color:  #09529d;
#             color:  #f1f1f1;
#         }#T_0f5aae74_193b_11eb_8c95_0242ac1c0002row1_col2,#T_0f5aae74_193b_11eb_8c95_0242ac1c0002row5_col3{
#             background-color:  #deebf7;
#             color:  #000000;
#         }#T_0f5aae74_193b_11eb_8c95_0242ac1c0002row1_col3{
#             background-color:  #cddff1;
#             color:  #000000;
#         }#T_0f5aae74_193b_11eb_8c95_0242ac1c0002row1_col5{
#             background-color:  #d3e4f3;
#             color:  #000000;
#         }#T_0f5aae74_193b_11eb_8c95_0242ac1c0002row1_col6{
#             background-color:  #97c6df;
#             color:  #000000;
#         }#T_0f5aae74_193b_11eb_8c95_0242ac1c0002row1_col7{
#             background-color:  #3080bd;
#             color:  #000000;
#         }#T_0f5aae74_193b_11eb_8c95_0242ac1c0002row1_col9{
#             background-color:  #006c2c;
#             color:  #f1f1f1;
#         }#T_0f5aae74_193b_11eb_8c95_0242ac1c0002row1_col10{
#             background-color:  #ecf8e8;
#             color:  #000000;
#         }#T_0f5aae74_193b_11eb_8c95_0242ac1c0002row1_col11{
#             background-color:  #d9f0d3;
#             color:  #000000;
#         }#T_0f5aae74_193b_11eb_8c95_0242ac1c0002row1_col13{
#             background-color:  #cdecc7;
#             color:  #000000;
#         }#T_0f5aae74_193b_11eb_8c95_0242ac1c0002row1_col14{
#             background-color:  #a2d99c;
#             color:  #000000;
#         }#T_0f5aae74_193b_11eb_8c95_0242ac1c0002row1_col15{
#             background-color:  #29914a;
#             color:  #000000;
#         }#T_0f5aae74_193b_11eb_8c95_0242ac1c0002row2_col1{
#             background-color:  #0a539e;
#             color:  #f1f1f1;
#         }#T_0f5aae74_193b_11eb_8c95_0242ac1c0002row2_col2{
#             background-color:  #d7e6f5;
#             color:  #000000;
#         }#T_0f5aae74_193b_11eb_8c95_0242ac1c0002row2_col4{
#             background-color:  #bed8ec;
#             color:  #000000;
#         }#T_0f5aae74_193b_11eb_8c95_0242ac1c0002row2_col5{
#             background-color:  #c9ddf0;
#             color:  #000000;
#         }#T_0f5aae74_193b_11eb_8c95_0242ac1c0002row2_col6{
#             background-color:  #4090c5;
#             color:  #000000;
#         }#T_0f5aae74_193b_11eb_8c95_0242ac1c0002row2_col7{
#             background-color:  #2b7bba;
#             color:  #000000;
#         }#T_0f5aae74_193b_11eb_8c95_0242ac1c0002row2_col9{
#             background-color:  #005b25;
#             color:  #f1f1f1;
#         }#T_0f5aae74_193b_11eb_8c95_0242ac1c0002row2_col10,#T_0f5aae74_193b_11eb_8c95_0242ac1c0002row5_col12,#T_0f5aae74_193b_11eb_8c95_0242ac1c0002row6_col12{
#             background-color:  #c3e7bc;
#             color:  #000000;
#         }#T_0f5aae74_193b_11eb_8c95_0242ac1c0002row2_col12{
#             background-color:  #a8dca2;
#             color:  #000000;
#         }#T_0f5aae74_193b_11eb_8c95_0242ac1c0002row2_col13{
#             background-color:  #9fd899;
#             color:  #000000;
#         }#T_0f5aae74_193b_11eb_8c95_0242ac1c0002row2_col14{
#             background-color:  #58b668;
#             color:  #000000;
#         }#T_0f5aae74_193b_11eb_8c95_0242ac1c0002row2_col15{
#             background-color:  #3da65a;
#             color:  #000000;
#         }#T_0f5aae74_193b_11eb_8c95_0242ac1c0002row3_col1{
#             background-color:  #084488;
#             color:  #f1f1f1;
#         }#T_0f5aae74_193b_11eb_8c95_0242ac1c0002row3_col2{
#             background-color:  #e7f1fa;
#             color:  #000000;
#         }#T_0f5aae74_193b_11eb_8c95_0242ac1c0002row3_col4{
#             background-color:  #f2f8fd;
#             color:  #000000;
#         }#T_0f5aae74_193b_11eb_8c95_0242ac1c0002row3_col5{
#             background-color:  #c1d9ed;
#             color:  #000000;
#         }#T_0f5aae74_193b_11eb_8c95_0242ac1c0002row3_col6{
#             background-color:  #4f9bcb;
#             color:  #000000;
#         }#T_0f5aae74_193b_11eb_8c95_0242ac1c0002row3_col7{
#             background-color:  #4896c8;
#             color:  #000000;
#         }#T_0f5aae74_

# %% [markdown]
# ### Latex version

# %%
print(pd.concat([dfMetric, pd.DataFrame(resultFinal)]).fillna(value=0) \
    .pivot(index='problem',columns='model',values='f1').reset_index()\
    .fillna(0).to_latex(index=False, float_format='{:,.2f}'.format))
# Out:
# \begin{tabular}{lrrrrrrrr}
# \toprule
#       problem &  0ensemble &  char &  dep &  dist &  pos &  tag &  w2v &  word \\
# \midrule
#  problem00001 &       0.61 &  0.62 & 0.30 &  0.35 & 0.29 & 0.39 & 0.63 &  0.55 \\
#  problem00002 &       0.57 &  0.53 & 0.27 &  0.30 & 0.22 & 0.28 & 0.36 &  0.46 \\
#  problem00003 &       0.39 &  0.36 & 0.19 &  0.15 & 0.22 & 0.21 & 0.30 &  0.32 \\
#  problem00004 &       0.38 &  0.36 & 0.16 &  0.14 & 0.15 & 0.21 & 0.28 &  0.29 \\
#  problem00005 &       0.36 &  0.36 & 0.13 &  0.14 & 0.16 & 0.18 & 0.20 &  0.24 \\
#  problem00006 &       0.58 &  0.58 & 0.37 &  0.40 & 0.46 & 0.54 & 0.44 &  0.55 \\
#  problem00007 &       0.58 &  0.58 & 0.32 &  0.39 & 0.38 & 0.50 & 0.41 &  0.52 \\
#  problem00008 &       0.55 &  0.47 & 0.23 &  0.26 & 0.24 & 0.36 & 0.36 &  0.33 \\
#  problem00009 &       0.48 &  0.48 & 0.19 &  0.20 & 0.24 & 0.37 & 0.29 &  0.43 \\
#  problem00010 &       0.35 &  0.38 & 0.15 &  0.18 & 0.22 & 0.24 & 0.22 &  0.30 \\
# \bottomrule
# \end{tabular}

# %%
# mean by model
print(pd.concat([dfMetric, pd.DataFrame(resultFinal)]).fillna(value=0) \
    .pivot(index='problem',columns='model',values='f1').reset_index().mean().to_frame().T\
     .to_latex(index=False, float_format='{:,.2f}'.format))
# Out:
# \begin{tabular}{rrrrrrrr}
# \toprule
#  0ensemble &  char &  dep &  dist &  pos &  tag &  w2v &  word \\
# \midrule
#       0.49 &  0.47 & 0.23 &  0.25 & 0.26 & 0.33 & 0.35 &  0.40 \\
# \bottomrule
# \end{tabular}

# %%
for problemIndex, problem in enumerate(df['problem'].unique()):
    lang = df.query(f"problem == '{problem}'")['language'].unique()[0]
    print(problem +' '+lang+' '+ str(bestModels[problemIndex]))
# Out:
# problem00001 pt ['w2v', 'word']
# problem00002 pt ['char', 'word', 'w2v']
# problem00003 pt ['char', 'w2v']
# problem00004 pt ['char', 'word', 'tag', 'w2v']
# problem00005 pt ['char', 'w2v']
# problem00006 en ['char']
# problem00007 en ['char', 'dep']
# problem00008 en ['char', 'dist', 'dep', 'w2v']
# problem00009 en ['char', 'dist']
# problem00010 en ['char', 'dist', 'dep']

# %%
pd.pivot_table(
    pd.concat([dfMetric, pd.DataFrame(resultFinal)]),
    index='model',
    columns='n_authors',
    values='f1',
    aggfunc='mean',
    fill_value=0).T
# Out:
# model      0ensemble   char    dep   dist    pos    tag    w2v   word
# n_authors
# 5             0.5995 0.6005 0.3350 0.3730 0.3755 0.4660 0.5325 0.5490
# 10            0.5760 0.5550 0.2910 0.3455 0.3025 0.3930 0.3850 0.4925
# 15            0.4700 0.4170 0.2115 0.2055 0.2290 0.2835 0.3325 0.3260
# 20            0.4280 0.4225 0.1750 0.1725 0.1930 0.2885 0.2885 0.3605
# 25            0.3570 0.3720 0.1420 0.1640 0.1880 0.2090 0.2120 0.2675

# %%
pd.pivot_table(
    pd.concat([dfMetric, pd.DataFrame(resultFinal)]),
    index='model',
    columns='language',
    values='f1',
    aggfunc='mean',
    fill_value=0)
# Out:
# language      en     pt
# model
# 0ensemble 0.5082 0.4640
# char      0.5016 0.4452
# dep       0.2524 0.2094
# dist      0.2880 0.2162
# pos       0.3074 0.2078
# tag       0.4022 0.2538
# w2v       0.3454 0.3548
# word      0.4256 0.3726

# %%
pd.pivot_table(
    pd.concat([dfMetric, pd.DataFrame(resultFinal)]),
    index='model',
    columns=['language','n_authors'],
    values='f1',
    aggfunc='mean',
    fill_value=0)
# Out:
# language      en                                 pt
# n_authors     5      10     15     20     25     5      10     15     20     25
# model
# 0ensemble 0.5850 0.5820 0.5480 0.4760 0.3500 0.6140 0.5700 0.3920 0.3800 0.3640
# char      0.5850 0.5850 0.4750 0.4830 0.3800 0.6160 0.5250 0.3590 0.3620 0.3640
# dep       0.3710 0.3160 0.2350 0.1870 0.1530 0.2990 0.2660 0.1880 0.1630 0.1310
# dist      0.3980 0.3940 0.2620 0.2010 0.1850 0.3480 0.2970 0.1490 0.1440 0.1430
# pos       0.4580 0.3830 0.2420 0.2360 0.2180 0.2930 0.2220 0.2160 0.1500 0.1580
# tag       0.5390 0.5010 0.3610 0.3700 0.2400 0.3930 0.2850 0.2060 0.2070 0.1780
# w2v       0.4380 0.4110 0.3630 0.2950 0.2200 0.6270 0.3590 0.3020 0.2820 0.2040
# word      0.5450 0.5220 0.3300 0.4340 0.2970 0.5530 0.4630 0.3220 0.2870 0.2380

# %%
pd.pivot_table(
    pd.concat([ pd.DataFrame(resultFinal)]),
    index='model',
    columns=['language','n_authors'],
    values='f1',
    aggfunc='mean',
    fill_value=0)
# Out:
# language      en                                 pt
# n_authors     5      10     15     20     25     5      10     15     20     25
# model
# 0ensemble 0.5850 0.5820 0.5480 0.4760 0.3500 0.6140 0.5700 0.3920 0.3800 0.3640

# %%
pd.DataFrame(predictions).round(5).sort_values('row_index')
# Out:
#      dataset       problem  ... candidate00024  candidate00025
# 0     lyrics  problem00001  ...            nan             nan
# 1     lyrics  problem00001  ...            nan             nan
# 2     lyrics  problem00001  ...            nan             nan
# 3     lyrics  problem00001  ...            nan             nan
# 4     lyrics  problem00001  ...            nan             nan
# ...      ...           ...  ...            ...             ...
# 5320  lyrics  problem00010  ...         0.0000          0.0000
# 5321  lyrics  problem00010  ...         0.0001          0.0001
# 5322  lyrics  problem00010  ...         0.0211          0.0219
# 5323  lyrics  problem00010  ...         0.0000          0.0000
# 5324  lyrics  problem00010  ...         0.0101          0.0084
#
# [5325 rows x 30 columns]

# %% [markdown]
# ## Saving data

# %%
import pickle;
with open(pathjoin(outputDir,f'{currentCorpus}_parcial.pkl'),"wb") as f:
    pickle.dump(results,f)


pd.DataFrame(predictions)\
    .rename(columns={'index':'row_index'}).sort_values('row_index').round(5)\
    .to_csv(pathjoin(outputDir,currentCorpus+'_predictions.csv.zip'), index=False, compression='zip', encoding='utf-8')

# %%
def resultsToTable(results):
    temp = []
    def unfold(r, var):
        return [i for j in r[var] for i in j]
    for model in results:
        r = results[model];
        t = {
            'row_index': unfold(r,'index_train') +unfold(r,'index_test'),
            'pred': unfold(r,'pred_train') +unfold(r,'pred_test')
            
        }
        t['model'] = [model] * len(t['row_index'])
        t['dataset'] = [currentCorpus] * len(t['row_index'])
        
        temp.append(t)

    
    return pd.concat([pd.DataFrame(d) for d in temp]);
        

resultsToTable(results) \
    .merge(datasets[['row_index','problem']], on='row_index', how='left')\
    .to_csv(pathjoin(outputDir,currentCorpus+'_predictions_parcial.csv.zip'), index=False, compression='zip', encoding='utf-8')
